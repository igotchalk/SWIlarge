# %%
import flopy
import os
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

if sys.platform.lower()=='linux':
    datadir = Path('/scratch/users/ianpg/SWIlarge/data')
    workdir = Path('/scratch/users/ianpg/SWIlarge/work')
    MPSdir = datadir.joinpath('lith/sgems/MPS')
    GISdir = datadir.joinpath('GIS')
    import mplleaflet
elif sys.platform.lower()=='darwin':
    datadir = Path('../data')
    workdir = Path('../work')
    MPSdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/lith/sgems/MPS')
    GISdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/GIS')

nmgwmdir_empty = datadir.joinpath('nmgwmdir_empty') #<-- removed everything but DIS
nmgwmdir_cal = datadir.joinpath('Calibrated_small') #<-- removed RCH, WEL, GLO, LST from the NAM file to load much faster
figdir = workdir.joinpath('figs')
outputdir = workdir.joinpath('output')

import config
from set_rc import *

import pandas as pd
import shapefile as sf #in case you dont have it, form anaconda prompt: pip install pyshp
from flopy.utils.gridgen import Gridgen
from flopy.utils.reference import SpatialReference
from  pyproj import Proj

p = Proj("epsg:26910")
xll=595855
yll = 4059438
rotation = -13.5
# Out:
# flopy is installed in /Users/ianpg/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy
# system: darwin

# %%
#%% Useful functions
def load_obj(dirname,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'rb') as f:
        return pickle.load(f)

def save_obj(dirname,obj,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

#Create new MC_file
def create_MC_file():
    import datetime
    ts = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
    MC_dir = Path(os.path.join(m.model_ws, 'MC_expt_' + ts))
    if not MC_dir.exists():
        MC_dir.mkdir()
    m.MC_file = MC_dir.joinpath('expt.txt')
    with m.MC_file.open('w') as wf:
        wf.close
    print(m.MC_file)
    return

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

#make a line across the grid
def get_line(start, end,allrows=1,nrow=None):
    """Bresenham's Line Algorithm
    Produces a list of tuples from start and end

    >>> points1 = get_line((0, 0), (3, 4))
    >>> points2 = get_line((3, 4), (0, 0))
    >>> assert(set(points1) == set(points2))
    >>> print points1
    [(0, 0), (1, 1), (1, 2), (2, 3), (3, 4)]
    >>> print points2
    [(3, 4), (2, 3), (1, 2), (1, 1), (0, 0)]
    """
    # Setup initial conditions
    x1, y1 = start
    x2, y2 = end
    dx = x2 - x1
    dy = y2 - y1

    # Determine how steep the line is
    is_steep = abs(dy) > abs(dx)

    # Rotate line
    if is_steep:
        x1, y1 = y1, x1
        x2, y2 = y2, x2

    # Swap start and end points if necessary and store swap state
    swapped = False
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
        swapped = True

    # Recalculate differentials
    dx = x2 - x1
    dy = y2 - y1

    # Calculate error
    error = int(dx / 2.0)
    ystep = 1 if y1 < y2 else -1

    # Iterate over bounding box generating points between start and end
    y = y1
    points = []
    for x in range(x1, x2 + 1):
        if allrows==1:
            if nrow is None:
                nrow = m.nrow
            for row in range(nrow):
                coord = (y, row, x) if is_steep else (x, row, y)
                points.append(coord)
        else:
            coord = (y, x) if is_steep else (x, y)
            points.append(coord)
        error -= abs(dy)
        if error < 0:
            y += ystep
            error += dx

    # Reverse the list if the coordinates were swapped
    if swapped:
        points.reverse()
    return points


#make all cells=0 above the line from get_line()
#Calculate freshwater head based on column of saltwater above each node (rho*g*z)
def shade_above(nlay,nrow,ncol,point_list,third_dim=1):
    import numpy as np
    grd = np.ones((nlay,nrow,ncol),dtype='int')
    ocean_hf = []
    if len(point_list)==0:
        return grd,ocean_hf
    for (lay,row,col) in point_list:
        grd[lay,:,col] = -1 #assign ocean ibound to -1
        grd[:lay,:,col] = 0 #assign cells above ocean to 0
        hf = densefresh/densesalt*ocean_elev - (densesalt - densefresh)/densefresh*(henry_botm[lay] +.5*delv)
        for irow in range(nrow):
            ocean_hf.append((int(lay),int(irow),int(col),hf))
    ocean_hf = tuple(np.array(ocean_hf).T)
    ocean_hf = (ocean_hf[0].astype('int'),
                ocean_hf[1].astype('int'),
                ocean_hf[2].astype('int'),
                ocean_hf[3])
    return grd,ocean_hf

def get_ocean_right_edge(m,ocean_line_tuple,startlay=None,col=None):
    import numpy as np
    point_list = []
    if col is None:
        col = m.ncol-1
    #If there is no vertical side boundary, return bottom-right corner node
    if len(ocean_line_tuple)==0:
        if startlay is None:
            startlay = 0
    elif max(ocean_line_tuple[0])==m.nlay:
        startlay = m.nlay
    elif max(ocean_line_tuple[0])<m.nlay:
        startlay = max(ocean_line_tuple[0])
    for lay in range(startlay,m.nlay):
        for row in range(m.nrow):
            point_list.append((lay,row,col))
    point_list = tuple(np.array(point_list).T)
    return point_list

def add_pumping_wells(wel_data,ssm_data,n_wells,flx,rowcol,kper):
    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    new_weldata = wel_data
    new_ssmdata = ssm_data
    wel_cells = []
    for k in range(n_wells):
        row,col = rowcol[k]
        for i in range(nper):
            if i in kper:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,-flx[k]*delv_weight[j]])
                    wel_cells.append((j,row,col))
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
            else:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,0])
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
                    wel_cells.append((j,row,col))
                continue
    wel_cells = tuple(np.array(list(set(wel_cells))).T)
    return new_weldata, new_ssmdata,wel_cells

#Add recharge if desired
def make_rech_array(low=1e-2,high=1e0):
    import scipy.stats as sts
    llow,lhigh = np.log10((low,high))
    rech = np.exp(sts.uniform.rvs(size=1,loc=llow,scale=lhigh-llow)[0])
    return rech/(nrow*ncol)

def add_recharge_cells(recharge_generator,const=1,*args):
    if const==1:
        rech_data = recharge_generator(*args)
    else:
        rech_data = {}
        for i in range(nper):
            rech_array = recharge_generator(*args)
        rech_data[i] = rech_array
    return rech_data

def sample_dist(distclass,size,*args):
    smp = distclass.rvs(*args,size=size)
    if size==1:
        smp=smp[-1]
    return smp

def write_sample(fname,varname,distclass,sample):
    fout= open(fname,"a")
    fout.write(varname + ',' + str(type(distclass)) + ',' + str(sample) + '\n')
    fout.close()
    return

def truncate_grf(grid,lith_props,hk_vals,log10trans=True,plotyn=False,saveyn=False):
    grid_cutoffs = []
    for q in np.cumsum(lith_props):
        grid_cutoffs.append(np.quantile(grid,q))

    if plotyn:
        h = plt.hist(grid.flatten())
        for cutoff in grid_cutoffs:
            plt.vlines(cutoff,0,14000)
        plt.show()

    outgrid = np.ones(grid.shape,dtype=np.float32)
    for i,cutoff in reversed(list(enumerate(grid_cutoffs))):
        outgrid[np.where(grid<cutoff)] = hk_vals[i]

    if plotyn:
        f,axs = plt.subplots(2,1,sharex=True)
        axs[0].imshow(grid[:,0,:])
        axs[1].imshow(outgrid[:,0,:])
        if saveyn:
            plt.savefig(m.MC_file.parent.joinpath('Truncated_GRF.png').as_posix(),resolution=300)
    if log10trans:
        return np.power(10,outgrid)
    else:
        return outgrid

def make_timestamp(YMD=True,HM=True):
    import datetime
    if YMD:
        ymd = '%Y%m%d'
    else:
        ymd = ''
    if HM:
        hm = '%H%M'
    else:
        hm = ''
    if YMD and HM:
        sep = '_'
    else:
        sep = ''
    return datetime.datetime.now().strftime('{}{}{}'.format(ymd,sep,hm))

def pec_num(delv,delc,delr,al):
    delL = (delv,delc,delr) #length in the lay,row,col directions
    pec_num = [round(d/al,2) for d in delL]
    for num,point  in zip(pec_num,('lay','row','col')):
        print('Pe = {} in the {} direction'.format(num,point))
    return pec_num

#%%

# %%
# %%time
m_nm= flopy.modflow.Modflow.load('nm_cali.nam',version='mf2k',verbose=False,check=False,model_ws=nmgwmdir_cal.as_posix())
# m = flopy.modflow.Modflow.load(nmgwmdir_uncal.joinpath('C1-12_copy.nam').as_posix(),version='mf2k',verbose=False,check=False,model_ws=outputdir.joinpath('C1').as_posix())
m_nm.exe_name = config.mf2000exe
if not m_nm.DIS.lenuni==2:
    m_nm.DIS.delr *= .3048
    m_nm.DIS.delc *= .3048
    m_nm.DIS.top *= .3048
    m_nm.DIS.botm *= .3048
m_nm.DIS.lenuni = 2
m_nm.DIS.itmuni=4
m_nm.DIS.rotation=-13.5
# m_nm.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_nm.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_nm.DIS.proj4_str = p.srs
m_nm.modelgrid.set_coord_info(xoff=xll, yoff=yll, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
# Out:
# CPU times: user 1min 24s, sys: 1.13 s, total: 1min 25s
# Wall time: 1min 29s

# %%
start_nm_yr = 1979
start_nm_mo = 10
start_nm_str = 'Oct 1979'
end_nm_yr = 2011
end_nm_mo = 9
end_nm_str = 'Sep 2011'
Lt_nm = ( (end_nm_yr + end_nm_mo/12)  - (start_nm_yr + start_nm_mo/12) )     *365
start_nm_datetime='{}/1/{}'.format(start_nm_mo,start_nm_yr)



start_m_yr = 1979
start_m_mo = 10
start_m_str = 'Oct 1979'
# end_m_yr = 2011
# end_m_mo = 9
# end_m_str = 'Sep 2011'
# Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
# start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)


start_m_yr = 1980
start_m_mo = 3
start_m_str = 'Mar 1980'
end_m_yr = 2030
end_m_mo = 10
end_m_str = 'Sep 2030'
Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)

# %%
#Name model
modelname = 'NM'
model_ws = workdir.joinpath("NM")
#Name model
sw_exe = config.swexe #set the exe path for seawat

#Model discretization
Lz = 150.

nrow,ncol,nlay,nper = m_nm.nrow_ncol_nlay_nper

# rows = np.arange(100,102)
# rows = np.arange(164,165)
# rows = np.arange(nrow)
# rows = np.arange(m_nm.nrow-159,   m_nm.nrow-132) #SV
rows = np.arange(m_nm.nrow-114,   m_nm.nrow-74) #NM




cols = np.arange(ncol)
nrow =len(rows)
ncol = len(cols)
nlay=20


henry_top = 2
ocean_elev = 0
delv_first = 4
botm_first = henry_top-delv_first


delv = (Lz-delv_first) / (nlay-1)
delr = m_nm.dis.delr.array[0]
delc = m_nm.dis.delc.array[0]

henry_botm = np.hstack(([botm_first],np.linspace(botm_first-delv,henry_top-Lz,nlay-1)))
delv_vec = np.hstack((delv_first,np.repeat(delv,nlay-1)))
delv_weight = [x/np.sum(delv_vec) for x in delv_vec]


topo_grid = np.load(GISdir.joinpath('topo_grid.npy'))
henry_top = topo_grid[(slice(rows[0],rows[-1]+1),slice(cols[0],cols[-1]+1))]


# beachslope = .05
# ocean_col = [np.floor(ncol-1).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn
# ocean_col = [np.floor(ncol/2).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn

# inland_elev = beachslope*ocean_col[0]*delr
# offshore_elev = -beachslope*(ocean_col[1]-ocean_col[0])*delr


#Period data
# nyrs= 2
# Lt = 365*nyrs #Length of time in days

perlen = list(np.repeat(365/2,int(Lt_m/(365/2))))
nper = len(perlen)
nstp = np.ones_like(perlen,dtype=np.int)

# nstp = m_nm.dis.nstp.array
# perlen = m_nm.dis.perlen.array
# nper = m_nm.nper





steady = [False for x in range(len(perlen))] #Never steady
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1.1
ssm_data = None
verbose = True

print('Model setup: \n'
      'nlay: {}\n'
      'nrow: {}\n'
      'ncol: {}\n'
      'Total cells: {}\n'
      'Total time: {} days\n'
      'nper: {}\n'.format(nlay,nrow,ncol,nlay*nrow*ncol,Lt_m,nper))
# In[4]:

#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws.as_posix(),verbose=verbose)
# SGD.ModelSGD.Seawat2SGD(m)  #convert to subclass ModelSGD
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,
                               start_datetime=start_m_datetime)

xll=595855
yll = 4059438
rotation=-13.5
# p = Proj(proj='utm',zone='10n',ellps='WGS84',units='meters', preserve_units=False)

m.DIS.lenuni = 2
m.DIS.itmuni=4
m.DIS.rotation=-13.5
# m.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m.DIS.proj4_str = p.srs
xll_m,yll_m = m_nm.modelgrid.xvertices[rows[-1]+1,0],m_nm.modelgrid.yvertices[rows[-1]+1,0]


m.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
print(m.modelgrid)
# Out:
# Model setup:
# nlay: 20
# nrow: 40
# ncol: 345
# Total cells: 276000
# Total time: 18462.91666666664 days
# nper: 101
#
# NM.nam
# adding Package:  DIS
# xll:596908.072036354; yll:4063824.360710914; rotation:-13.5; proj4_str:+proj=utm +zone=10 +datum=NAD83 +units=m +no_defs; units:undefined; lenuni:0

# %%
m_empty = flopy.modflow.Modflow('m_empty', model_ws=model_ws.joinpath('m_empty').as_posix())


flopy.modflow.ModflowDis(m_empty, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,start_datetime=start_m_datetime)

m_empty.DIS.lenuni = 2
m_empty.DIS.itmuni=4
m_empty.DIS.rotation=-13.5
# m_empty.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_empty.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_empty.DIS.proj4_str = p.srs
m_empty.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')

# %%
# %%time
gridgen_ws = model_ws.joinpath('gridgen')
if not gridgen_ws.exists():
    gridgen_ws.mkdir()
g = Gridgen(m_empty.dis, model_ws=gridgen_ws.as_posix(),exe_name=config.gridgenexe,surface_interpolation='replicate')
g.build(verbose=False)
# Out:
# CPU times: user 20.2 s, sys: 1.43 s, total: 21.6 s
# Wall time: 51.9 s

# %%
f_swi_180 = GISdir.joinpath("chloride_contours",'SWI_180_lines_noz.shp').as_posix()
swi_180 = sf.Reader(f_swi_180)
yrs_180 = [ int(r[-1]) for r in swi_180.records()]


for yr in yrs_180:
    f_exp = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_180.fields[1:] # skip first deletion field
        for feature in swi_180.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

f_swi_400 = GISdir.joinpath("chloride_contours",'SWI_400_lines_noz.shp').as_posix()
swi_400 = sf.Reader(f_swi_400)
yrs_400 = [ int(r[-1]) for r in swi_400.records()]


for yr in yrs_400:
    f_exp = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_400.fields[1:] # skip first deletion field
        for feature in swi_400.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

# %%
layer =3
yr = yrs_180[-1]
f_shp_180 = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
int_180 = g.intersect(f_shp_180,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_180.nodenumber] = 1
a180 = a.reshape((nlay,nrow,ncol),order='C')


yr = yrs_400[-1]
f_shp_400 = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
int_400 = g.intersect(f_shp_400,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_400.nodenumber] = 1
a400 = a.reshape((nlay,nrow,ncol),order='C')

# %% [raw]
# df_TDS = pd.read_excel(datadir.joinpath('WQ','export_TDS_data.xlsx'))
# TDSij =[]
# for x,y in zip(df_TDS.X_NAD83_UTM10N.values,df_TDS.Y_NAD83_UTM10N.values):
#     try:
#         TDSij.append(m_empty.modelgrid.intersect(x,y))
#     except:
#         TDSij.append((np.nan,np.nan))
# df_TDS = df_TDS.assign(rowi=np.array(TDSij)[:,0])
# df_TDS = df_TDS.assign(colj=np.array(TDSij)[:,1])

# %%
def intersect_swi_contour(aquifer=180,yr_ind=None):
    if aquifer==180:
        yr = yrs_180[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    elif aquifer==400:
        yr = yrs_400[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    else:
        raise('enter either 180 or 400')
    int_obj = g.intersect(f,'polygon',layer=layer)
    a = np.zeros((g.nodes), dtype=np.int)
    a[int_obj.nodenumber] = 1
    return a.reshape((nlay,nrow,ncol),order='C')


from scipy.interpolate import interp2d,RectBivariateSpline,NearestNDInterpolator,griddata
def make_surf(grid_old,m_old,m_new,method='nearest'):
    points = np.stack((m_old.modelgrid.xcellcenters.flatten(),m_old.modelgrid.ycellcenters.flatten())).T
    values = grid_old.flatten()
    grid_x=  m_new.modelgrid.xcellcenters
    grid_y=  m_new.modelgrid.ycellcenters
    return griddata(points, values, (grid_x, grid_y), method=method)

# %%
botm_orig= m_nm.DIS.botm.array[:6]
layer_mapping = np.zeros((7,nlay,nrow,ncol),dtype=bool)
for lay in range(7):
    if lay==0:
        ind_inlay = np.zeros((nlay,nrow,ncol),dtype=np.bool)
        ind_inlay[0,:,:] = True
    elif lay==6:
#         botm_orig_lay = interp_surf2newgrid(botm_orig[lay-1])
        botm_orig_lay = make_surf(botm_orig[-1],m_nm,m_empty)
        ind_inlay = m_empty.dis.botm.array<botm_orig_lay
    else:
        botm_orig_lay = make_surf(botm_orig[lay],m_nm,m_empty)
        top_orig_lay = make_surf(botm_orig[lay-1],m_nm,m_empty)
        ind_inlay =np.logical_and(m_empty.dis.botm.array>=botm_orig_lay,m_empty.dis.botm.array<top_orig_lay)
    layer_mapping[lay,:,:,:] = ind_inlay
    
    
    
layer_mapping_ind = np.zeros((nlay,nrow,ncol),dtype=int)
for lay in range(7):
    if lay==0:
        val=-50
    if lay==6:
        val=50
    else:
        val=lay
    layer_mapping_ind+=layer_mapping[lay].astype(int)*val
    
layer_mapping_ind[layer_mapping_ind<=0]= 0
layer_mapping_ind[layer_mapping_ind>=6]=6

# %%
hk_nm = m_nm.lpf.hk.array
x_nm = m_nm.modelgrid.xcellcenters
y_nm = m_nm.modelgrid.ycellcenters
z_nm = m_nm.modelgrid.zcellcenters
x_m = m_empty.modelgrid.xcellcenters
y_m = m_empty.modelgrid.ycellcenters
z_m = m_empty.modelgrid.zcellcenters

hk_new = griddata(points=(np.tile(x_nm,(m_nm.dis.nlay,1,1)).flatten(),np.tile(y_nm,(m_nm.dis.nlay,1,1)).flatten(),z_nm.flatten()),
               values=hk_nm.flatten(),
               xi=(x_m,y_m,z_m),method='nearest')
hk_new[np.isnan(hk_new)] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])
hk_new[hk_new>10000] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])



#Hydraulic conductivity field
hkSand = 1e2 #horizontal hydraulic conductivity m/day
hkClay = hkSand*.001

# heterogenous = 0 #0:homogenous,1:variogram,2:MPS

# hk = np.ones((nlay,nrow,ncol), dtype=np.float)
# hk[np.isin(layer_mapping_ind,(0,1,3,5))] = hkSand
# hk[np.isin(layer_mapping_ind,(2,4,6))] = hkClay


hk = hk_new 
#plt.figure(),plt.imshow((hk[:,0,:])),plt.colorbar(),plt.title('Sill:{}'.format(sill)),plt.show()

#Set Hydraulic properties
sy = 0.15
ss = 1e-5
por = 0.3
vka = .5 # = vk/hk
al = 20 #longitudinal dispersivity (m) from Walther et al. 2017
dmcoef = 2e-9 #m2/day

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)
#denseslp = 0 #trick for testing constant density

# %%
plt.figure()


mps180 = np.load(MPSdir.joinpath('reals','mps180_16node.npy'))
mps180[mps180==1]=hkSand
mps180[mps180==0]=hkClay
hk2 = hk.copy()
hk2[np.where(layer_mapping_ind==3)] = mps180[np.where(layer_mapping_ind==3)] 
plt.imshow(np.ma.masked_where(hk2>600,hk2)[:,0,:])
plt.gca().set_aspect(10)

# %% [markdown]
# ### BCs

# %%
def find_ocean(m,layer_mapping_ind):
    ocean_line = []

    for lay in range(m.dis.nlay):
        for row in range(m.dis.nrow):
            thislay = (lay,row,np.where(layer_mapping_ind[lay,row,:]!=0)[0][0])
            ocean_line.append(thislay)
            if lay==m.dis.nlay-1:
                pass
            else:
                nextlay = (lay+1,row,np.where(layer_mapping_ind[lay+1,row,:]!=0)[0][0])
                for col in np.arange(thislay[2],nextlay[2],-1):
                    ocean_line.append((lay,row,col))
    ocean_line = np.array(ocean_line).T


    ocean_grid = np.zeros((nlay,nrow,ncol),dtype=np.bool)
    ocean_grid[tuple(ocean_line)]=True
    ocean_grid[m.modelgrid.zvertices[1:,:,:]>ocean_elev]=False
    return ocean_line,ocean_grid

ocean_line,ocean_grid = find_ocean(m,layer_mapping_ind)

# %% [markdown]
# ### Extend inland ghb time

# %%
bhead_mean_180=  []
bhead_mean_400 = []
bhead_180400 = []

for per in range(m_nm.nper):
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==3)
    bhead_mean_180.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==5)
    bhead_mean_400.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==4)
    bhead_180400.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    
    
    
yr = np.arange(2012,2019)
dlvl_180 = np.array([-2,-1,-8,-7,0,11,.5,2])*.3048
dlvl_400 = np.array([-1,-1,-7,-4,1,8,-.5,2])*.3048

bhead_future_180 = [np.array(bhead_mean_180)[-12:]+dlvl for dlvl in dlvl_180]
bhead_future_180 = np.array(bhead_future_180).flatten()
bhead_future_180 = np.r_[bhead_future_180,np.tile(bhead_future_180[-12:],20)]
bhead_future_180 = bhead_future_180[5::6]

bhead_future_400 = [np.array(bhead_mean_400)[-12:]+dlvl for dlvl in dlvl_400]
bhead_future_400 = np.array(bhead_future_400).flatten()
bhead_future_400 = np.r_[bhead_future_400,np.tile(bhead_future_400[-12:],20)]
bhead_future_400 = bhead_future_400[5::6]

# %%
bhead_future[::6]
# Out:
# array([-22.929802, -22.820498, -22.929802, -22.820498, -22.929802,
#        -22.820498, -22.929802, -22.820498, -22.929802, -22.820498,
#        -22.929802, -22.820498, -22.929802, -22.820498, -22.929802,
#        -22.820498, -22.929802, -22.820498, -22.929802, -22.820498,
#        -22.929802, -22.820498, -22.929802, -22.820498, -22.929802,
#        -22.820498, -22.929802, -22.820498, -22.929802, -22.820498,
#        -22.929802, -22.820498, -22.929802, -22.820498, -22.929802,
#        -22.820498, -22.929802, -22.820498], dtype=float32)

# %%
plt.plot(bhead_180400,label='180/400')
plt.plot(bhead_mean_180)
# plt.plot(bhead_mean_400)
plt.legend()

# %%
plt.plot(bhead_future_180)
plt.plot(bhead_future_400)

# %%
inland_inds_180 = np.argwhere(layer_mapping_ind==3)
inland_inds_180 = inland_inds_180[inland_inds_180[:,2]==344,:]

inland_inds_180400 = np.argwhere(layer_mapping_ind==4)
inland_inds_180400 = inland_inds_180400[inland_inds_180400[:,2]==344,:]

inland_inds_400 = np.argwhere(layer_mapping_ind==5)
inland_inds_400 = inland_inds_400[inland_inds_400[:,2]==344,:]

# %%
itype = flopy.mt3d.Mt3dSsm.itype_dict()
cond = 1000.

ghb_data_ocean = {}
ssm_data_ocean = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = []
    ssm_per = []
    #Ocean boundary
    for v in np.argwhere(ocean_grid):
        ghb_per.append([v[0],
                       v[1],
                       v[2],
                       #ocean_hf[3][j],
                        ocean_elev,
                       cond])
        #SSM: {stress_period: [lay,row,col,concentration,itype]}
        ssm_per.append([v[0],
                       v[1],
                       v[2],
                       Csalt,
                       itype['GHB']])
    ghb_data_ocean[kper]=ghb_per
    ssm_data_ocean[kper]=ssm_per

    
    

inds = []
nix_ghb = []
for v in ocean_line.T:
# v = ocean_line.T[-1]
    if 6 in layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]:
        inds.append((v[0],v[1],int(np.argwhere(layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]==6)[0]) + v[2]))
        nix_ghb.append(v)

        
for kper in range(nper):
    for v in nix_ghb:
        try:
            ghb_data_ocean[kper].remove([v[0],v[1],v[2],0,cond])
        except:
            continue
# Out:
# kper 0
# kper 50
# kper 100

# %%
t_m = (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365
t_vec_nm = (start_nm_yr + start_nm_mo/12) + np.cumsum(m_nm.dis.perlen.array)/365    
t_m
# Out:
# 1980.25

# %%
def find_nearest_kper_nm(kper_m):
    t_m = (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365
    t_vec_nm = (start_nm_yr + start_nm_mo/12) + np.cumsum(m_nm.dis.perlen.array)/365    
    if t_m > t_vec_nm.max() + m_nm.dis.perlen.array[0]/365:
        return np.nan
    else:
        return np.argmin(abs(t_vec_nm-t_m))
def date_from_per(kper_m):
    return  (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365

layers_to_map=np.arange(3,6)
z_m_vert = m_empty.modelgrid.zvertices
ghb_data_nm = m_nm.ghb.stress_period_data.data


ghb_data_inland = {}
ssm_data_inland = {}

for kper_m in range(nper):
    kper_nm = find_nearest_kper_nm(kper_m)
    if np.isnan(kper_nm):
        kper_m_max=kper_m
        break
#     if kper>0:
#         continue
    if kper_m%10==0:
        print('date: {}; kper_m {}; nkper_nm {}'.format(
            date_from_per(kper_m),kper_m,kper_nm))

    ghb_per=[]
    ssm_per = []
    for i,row in enumerate(rows):
        for lay in layers_to_map:
            
            
            lay_map = np.argwhere(np.logical_and(layer_mapping_ind[:,i,344]==lay,z_m_vert[1:,i,344]<bhead)).flatten()
            for new_lay in lay_map:
                ghb_per.append((new_lay,i,344,bhead,cond))
                ssm_per.append([new_lay,i,344,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per

    
### Now add what isnt covered by the nmgwm
for iper,kper_m in enumerate(range(kper_m_max,nper)):
    ghb_per=[]
    ssm_per = []
    if kper_m%10==0:
        print('date: {}; kper_m {}; nkper_nm {}'.format(
            date_from_per(kper_m),kper_m,kper_nm))
    bhead180 = bhead_future_180[iper]
    bhead400 = bhead_future_400[iper]
        
    for ind in inland_inds_180:
        k,i,j = ind
        ghb_per.append((k,i,j,bhead180,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
        
    for ind in inland_inds_180400: #Same bhead as 180-FA
        k,i,j = ind
        ghb_per.append((k,i,j,bhead180,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
        
    for ind in inland_inds_400:
        k,i,j = ind
        ghb_per.append((k,i,j,bhead400,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per
# Out:
# date: 1980.25; kper_m 0; nkper_nm 4
# date: 1985.25; kper_m 10; nkper_nm 64
# date: 1990.25; kper_m 20; nkper_nm 124
# date: 1995.25; kper_m 30; nkper_nm 184
# date: 2000.25; kper_m 40; nkper_nm 244
# date: 2005.25; kper_m 50; nkper_nm 304
# date: 2010.25; kper_m 60; nkper_nm 364
# date: 2015.25; kper_m 70; nkper_nm nan
# date: 2020.25; kper_m 80; nkper_nm nan
# date: 2025.25; kper_m 90; nkper_nm nan
# date: 2030.25; kper_m 100; nkper_nm nan

# %% [markdown]
#  ### STRT

# %%
yr_ind = np.argmin([np.min(abs(v - (start_m_yr + start_m_mo/12))) for v in yrs_180])
a_180 = intersect_swi_contour(aquifer=180,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_180]))
a_180 = np.tile(a_180[nonzerolay],(nlay,1,1))


yr_ind = np.argmin([np.min(abs(v - (start_m_yr + start_m_mo/12))) for v in yrs_400])
a_400 = intersect_swi_contour(aquifer=400,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_400]))
a_400 = np.tile(a_400[nonzerolay],(nlay,1,1))
salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)


salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_180[lay,row,:])
        if len(inds_nonzero)>0:
            salt_180[lay,row,:int(inds_nonzero[0])]=True
            
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_400[lay,row,:])
        if len(inds_nonzero)>0:
            salt_400[lay,row,:int(inds_nonzero[0])]=True

# %%
saltgrad_180 = np.zeros_like(a_180)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_180[lay,row,:])
        if len(ind_max)>0:
            ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_180[lay,row,ind_ocean:ind_max.max()]=tds_vec
saltgrad_400 = np.zeros_like(a_400)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_400[lay,row,:])
        if len(ind_max)>0:
            ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_400[lay,row,ind_ocean:ind_max.max()]=tds_vec

# %%
# ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
# for v in np.argwhere(ocean_grid):
#     ibound[v[0],v[1],:v[2]]=0
# head_inland =-10.
head_inland = min([np.min(np.array(v)[:,3]) for k,v in ghb_data_inland.items()])
ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
for lay in range(nlay):
    for row in range(nrow):
        col = int(np.argwhere(ocean_grid[lay,row,:])[0])
        ibound[lay,row,:col]=0
for v in inds:
    ibound[v[0],v[1],:v[2]]=0
ibound[z_m_vert[1:,:,:]>0]=0
ibound[layer_mapping_ind==6]=0

strt = np.ones_like(ibound)*head_inland

# sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
# sconc[ocean_grid] = Csalt
# # interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
# for v in ocean_line.T:
#     sconc[v[0],v[1],:v[2]]=Csalt
# sconc[np.logical_or(salt_180,salt_400)] = Csalt
    
sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
sconc[np.isin(layer_mapping_ind,(3,1))] = saltgrad_180[np.isin(layer_mapping_ind,(3,1))]
sconc[np.isin(layer_mapping_ind,(5,1))] = saltgrad_400[np.isin(layer_mapping_ind,(5,1))]
# sconc[layer_mapping_ind==1] =Csalt
sconc[ocean_grid] = Csalt
# interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
for v in ocean_line.T:
    sconc[v[0],v[1],:v[2]]=Csalt
    
    
    

icbund = np.ones((nlay, nrow, ncol), dtype=np.int)
icbund[np.where(ibound==-1)] = -1

# %%
plt.imshow(sconc[:,10,:])
plt.gca().set_aspect(10)
plt.colorbar()

# %%
ghb_data = {}
ssm_data = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = ghb_data_ocean[kper]
    ssm_per = ssm_data_ocean[kper]
    for vg,vs in zip(ghb_data_inland[kper],ssm_data_inland[kper]):
        ghb_per.append(vg)
        ssm_per.append(vs)
    ghb_data[kper] = ghb_per
    ssm_data[kper] = ssm_per
# Out:
# kper 0
# kper 50
# kper 100

# %%
# In[9]:

#Output control
oc_data = {}
for kper in range(nper):
    oc_data[(kper,0)] = ['save head','save budget']


# In[10]:

#Create instances in flopy
bas = flopy.modflow.ModflowBas(m, ibound=ibound, strt=strt)
ghb = flopy.modflow.ModflowGhb(m, stress_period_data=ghb_data)

# rch = flopy.modflow.ModflowRch(m, rech=rech_data)
# wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)
# riv = flopy.modflow.ModflowRiv(m, stress_period_data=riv_data)
# Add LPF package to the MODFLOW model
ipakcb = 53
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb,laytyp=0,laywet=0,
                              ss=ss,sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data=oc_data,
                             compact=True)

#Create the basic MT3DMS model structure
timprs = np.cumsum(m.DIS.perlen.array)
btn = flopy.mt3d.Mt3dBtn(m,
                         laycon=lpf.laytyp, htop=henry_top,
                         dz=dis.thickness.get_value(), prsity=por, icbund=icbund,
                         sconc=sconc, nprs=1,timprs=timprs)
# adv = flopy.mt3d.Mt3dAdv(m, mixelm=-1 )
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0,nadvfd=0 )

dsp = flopy.mt3d.Mt3dDsp(m, al=al, dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=50, mxiter=1, isolve=3, cclose=1e-4)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data,mxss=len(ssm_data[0])*nper)

#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0,
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# adding Package:  BAS6
# adding Package:  GHB
# Adding NM.cbc (unit=53) to the output list.
# adding Package:  LPF
# adding Package:  PCG
# Adding NM.hds (unit=51) to the output list.
# adding Package:  OC
# adding Package:  BTN
# adding Package:  ADV
# adding Package:  DSP
# adding Package:  GCG
#    explicit cevt in file
# adding Package:  SSM
# adding Package:  VDF

# %%
# %%time
writeyn= False
runyn = True
#Write input
if writeyn:
    m.write_input()

# Try to delete the output files, to prevent accidental use of older files

f_delete = [os.path.join(model_ws,'MT3D.CNF'),
            os.path.join(model_ws,'MT3D001.MAS'),
            os.path.join(model_ws, 'MT3D001.UCN'),
            os.path.join(model_ws, modelname + '.hds'),
            os.path.join(model_ws, modelname + '.cbc')]

for f in f_delete:
    try:
        os.remove(f)
    except:
        pass

#%%
import datetime

if runyn:
    #Run model
    ts = make_timestamp()
    v = m.run_model(silent=False, report=True)
    for idx in range(-3, 0):
        print(v[1][idx])
else:
    print('Not running model!')
# In[14]:
# Out:
# FloPy is using the following  executable to run the model: /usr/local/bin/MODFLOW/swtv4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: NM.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/07/01  6:53:32
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    182.50
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3332E-02  [K,I,J]    3    9  134
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9827E-08  [K,I,J]    1   34  155
#  Transport Step:    2   Step Size:  0.1879     Total Elapsed Time:  0.18888
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6840E-01  [K,I,J]    3    9  134
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1030E-02  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1042E-04  [K,I,J]    1   35  156
#  Transport Step:    3   Step Size:  0.4228     Total Elapsed Time:  0.61173
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6878E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1511E-02  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2525E-04  [K,I,J]    1   39  156
#  Transport Step:    4   Step Size:  0.6863     Total Elapsed Time:   1.2980
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6794E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1225E-02  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2553E-04  [K,I,J]    1   39  156
#  Transport Step:    5   Step Size:  0.9944     Total Elapsed Time:   2.2924
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6341E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8632E-03  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2072E-04  [K,I,J]    1   39  156
#  Transport Step:    6   Step Size:   1.361     Total Elapsed Time:   3.6534
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5842E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6396E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1628E-04  [K,I,J]    1   39  156
#  Transport Step:    7   Step Size:   1.780     Total Elapsed Time:   5.4336
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5418E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4931E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1380E-04  [K,I,J]    1   39  156
#  Transport Step:    8   Step Size:   2.203     Total Elapsed Time:   7.6362
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5063E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3942E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1693E-04  [K,I,J]    1   34  156
#  Transport Step:    9   Step Size:   2.544     Total Elapsed Time:   10.180
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4681E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2826E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2596E-04  [K,I,J]    1    3  154
#  Transport Step:   10   Step Size:   2.759     Total Elapsed Time:   12.939
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4232E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2602E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1400E-04  [K,I,J]    1    3  154
#  Transport Step:   11   Step Size:   2.869     Total Elapsed Time:   15.807
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3756E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2256E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1040E-04  [K,I,J]    1    3  154
#  Transport Step:   12   Step Size:   2.919     Total Elapsed Time:   18.726
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3306E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1921E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7966E-05  [K,I,J]    1    3  154
#  Transport Step:   13   Step Size:   2.940     Total Elapsed Time:   21.666
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2906E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1627E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6618E-05  [K,I,J]    1   21  156
#  Transport Step:   14   Step Size:   2.948     Total Elapsed Time:   24.614
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2656E-01  [K,I,J]    4   40  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1376E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5748E-05  [K,I,J]    1   21  156
#  Transport Step:   15   Step Size:   2.951     Total Elapsed Time:   27.565
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2473E-01  [K,I,J]    4   39  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1163E-03  [K,I,J]    1   36  157
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4920E-05  [K,I,J]    1   19  156
#  Transport Step:   16   Step Size:   2.952     Total Elapsed Time:   30.517
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2304E-01  [K,I,J]    4   39  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9819E-04  [K,I,J]    1   36  157
#  Transport Step:   17   Step Size:   2.952     Total Elapsed Time:   33.469
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2148E-01  [K,I,J]    4   39  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8313E-04  [K,I,J]    1   36  157
#  Transport Step:   18   Step Size:   2.952     Total Elapsed Time:   36.421
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2005E-01  [K,I,J]    3    9  134
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8890E-04  [K,I,J]    1   36  157
#  Transport Step:   19   Step Size:   2.951     Total Elapsed Time:   39.372
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1921E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5511E-04  [K,I,J]    1   36  157
#  Transport Step:   20   Step Size:   2.951     Total Elapsed Time:   42.323
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1845E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4563E-04  [K,I,J]    1   36  157
#  Transport Step:   21   Step Size:   2.950     Total Elapsed Time:   45.273
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1769E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4016E-04  [K,I,J]    1   33  155
#  Transport Step:   22   Step Size:   2.950     Total Elapsed Time:   48.222
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1695E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3904E-04  [K,I,J]    1   33  155
#  Transport Step:   23   Step Size:   2.949     Total Elapsed Time:   51.171
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1622E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3779E-04  [K,I,J]    1   33  155
#  Transport Step:   24   Step Size:   2.948     Total Elapsed Time:   54.119
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1552E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3644E-04  [K,I,J]    1   33  155
#  Transport Step:   25   Step Size:   2.948     Total Elapsed Time:   57.067
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1484E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3504E-04  [K,I,J]    1   33  155
#  Transport Step:   26   Step Size:   2.947     Total Elapsed Time:   60.014
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1419E-01  [K,I,J]    2   29  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3362E-04  [K,I,J]    1   33  155
#  Transport Step:   27   Step Size:   2.946     Total Elapsed Time:   62.960
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1359E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3269E-04  [K,I,J]    1   21  154
#  Transport Step:   28   Step Size:   2.946     Total Elapsed Time:   65.906
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1306E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3259E-04  [K,I,J]    1   21  154
#  Transport Step:   29   Step Size:   2.945     Total Elapsed Time:   68.851
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1256E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3234E-04  [K,I,J]    1   21  154
#  Transport Step:   30   Step Size:   2.944     Total Elapsed Time:   71.795
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1210E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3197E-04  [K,I,J]    1   21  154
#  Transport Step:   31   Step Size:   2.944     Total Elapsed Time:   74.739
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1166E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3151E-04  [K,I,J]    1   21  154
#  Transport Step:   32   Step Size:   2.943     Total Elapsed Time:   77.682
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1124E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3096E-04  [K,I,J]    1   21  154
#  Transport Step:   33   Step Size:   2.942     Total Elapsed Time:   80.624
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1083E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3036E-04  [K,I,J]    1   21  154
#  Transport Step:   34   Step Size:   2.942     Total Elapsed Time:   83.565
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1043E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2970E-04  [K,I,J]    1   21  154
#  Transport Step:   35   Step Size:   2.941     Total Elapsed Time:   86.506
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1005E-01  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2901E-04  [K,I,J]    1   21  154
#  Transport Step:   36   Step Size:   2.940     Total Elapsed Time:   89.446
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9681E-02  [K,I,J]    3    9  135
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2829E-04  [K,I,J]    1   21  154
#  Transport Step:   37   Step Size:   2.939     Total Elapsed Time:   92.386
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9382E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2756E-04  [K,I,J]    1   21  154
#  Transport Step:   38   Step Size:   2.939     Total Elapsed Time:   95.324
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9104E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2681E-04  [K,I,J]    1   21  154
#  Transport Step:   39   Step Size:   2.938     Total Elapsed Time:   98.263
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8833E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2606E-04  [K,I,J]    1   21  154
#  Transport Step:   40   Step Size:   2.937     Total Elapsed Time:   101.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8569E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2530E-04  [K,I,J]    1   21  154
#  Transport Step:   41   Step Size:   2.937     Total Elapsed Time:   104.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8313E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2456E-04  [K,I,J]    1   21  154
#  Transport Step:   42   Step Size:   2.936     Total Elapsed Time:   107.07
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8064E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2382E-04  [K,I,J]    1   21  154
#  Transport Step:   43   Step Size:   2.935     Total Elapsed Time:   110.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7823E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2309E-04  [K,I,J]    1   21  154
#  Transport Step:   44   Step Size:   2.934     Total Elapsed Time:   112.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7589E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2237E-04  [K,I,J]    1   21  154
#  Transport Step:   45   Step Size:   2.934     Total Elapsed Time:   115.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7363E-02  [K,I,J]    2   29  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2167E-04  [K,I,J]    1   21  154
#  Transport Step:   46   Step Size:   2.933     Total Elapsed Time:   118.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7170E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2098E-04  [K,I,J]    1   21  154
#  Transport Step:   47   Step Size:   2.932     Total Elapsed Time:   121.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7001E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2031E-04  [K,I,J]    1   21  154
#  Transport Step:   48   Step Size:   2.932     Total Elapsed Time:   124.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6837E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1966E-04  [K,I,J]    1   21  154
#  Transport Step:   49   Step Size:   2.931     Total Elapsed Time:   127.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6676E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1902E-04  [K,I,J]    1   21  154
#  Transport Step:   50   Step Size:   2.930     Total Elapsed Time:   130.53
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6520E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1841E-04  [K,I,J]    1   21  154
#  Transport Step:   51   Step Size:   2.929     Total Elapsed Time:   133.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6367E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1781E-04  [K,I,J]    1   21  154
#  Transport Step:   52   Step Size:   2.929     Total Elapsed Time:   136.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6219E-02  [K,I,J]    5   40  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1723E-04  [K,I,J]    1   21  154
#  Transport Step:   53   Step Size:   2.928     Total Elapsed Time:   139.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6082E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1667E-04  [K,I,J]    1   21  154
#  Transport Step:   54   Step Size:   2.927     Total Elapsed Time:   142.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5952E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1612E-04  [K,I,J]    1   21  154
#  Transport Step:   55   Step Size:   2.927     Total Elapsed Time:   145.17
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5825E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1560E-04  [K,I,J]    1   21  154
#  Transport Step:   56   Step Size:   2.926     Total Elapsed Time:   148.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5701E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1509E-04  [K,I,J]    1   21  154
#  Transport Step:   57   Step Size:   2.925     Total Elapsed Time:   151.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5580E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1460E-04  [K,I,J]    1   21  154
#  Transport Step:   58   Step Size:   2.924     Total Elapsed Time:   153.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5462E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1412E-04  [K,I,J]    1   21  154
#  Transport Step:   59   Step Size:   2.924     Total Elapsed Time:   156.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5346E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1366E-04  [K,I,J]    1   21  154
#  Transport Step:   60   Step Size:   2.923     Total Elapsed Time:   159.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5233E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1322E-04  [K,I,J]    1   21  154
#  Transport Step:   61   Step Size:   2.922     Total Elapsed Time:   162.72
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5123E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1279E-04  [K,I,J]    1   21  154
#  Transport Step:   62   Step Size:   2.922     Total Elapsed Time:   165.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5016E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1238E-04  [K,I,J]    1   21  154
#  Transport Step:   63   Step Size:   2.921     Total Elapsed Time:   168.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4911E-02  [K,I,J]    5   33  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1198E-04  [K,I,J]    1   21  154
#  Transport Step:   64   Step Size:   2.920     Total Elapsed Time:   171.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4808E-02  [K,I,J]    5   34  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1160E-04  [K,I,J]    1   21  154
#  Transport Step:   65   Step Size:   2.919     Total Elapsed Time:   174.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4710E-02  [K,I,J]    5   34  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1123E-04  [K,I,J]    1   21  154
#  Transport Step:   66   Step Size:   2.919     Total Elapsed Time:   177.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4613E-02  [K,I,J]    5   34  138
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1087E-04  [K,I,J]    1   21  154
#  Transport Step:   67   Step Size:   2.918     Total Elapsed Time:   180.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4523E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1052E-04  [K,I,J]    1   21  154
#  Transport Step:   68   Step Size:   2.264     Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3468E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5829E-05  [K,I,J]    1   21  154
#  Transport Step:   69   Step Size:  2.8422E-14 Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   182.50     TO    365.00
#
#  Transport Step:    1   Step Size:   2.917     Total Elapsed Time:   185.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1063E-01  [K,I,J]    7   23  107
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1935E-04  [K,I,J]    3   30  156
#  Transport Step:    2   Step Size:   2.959     Total Elapsed Time:   188.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4406E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9888E-05  [K,I,J]    1   21  154
#  Transport Step:    3   Step Size:   2.923     Total Elapsed Time:   191.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4291E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9372E-05  [K,I,J]    1   21  154
#  Transport Step:    4   Step Size:   2.917     Total Elapsed Time:   194.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4222E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9052E-05  [K,I,J]    1   21  154
#  Transport Step:    5   Step Size:   2.915     Total Elapsed Time:   197.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4160E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8762E-05  [K,I,J]    1   21  154
#  Transport Step:    6   Step Size:   2.914     Total Elapsed Time:   200.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4100E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8500E-05  [K,I,J]    1   20  155
#  Transport Step:    7   Step Size:   2.913     Total Elapsed Time:   202.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4041E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8263E-05  [K,I,J]    1   20  155
#  Transport Step:    8   Step Size:   2.912     Total Elapsed Time:   205.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3995E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8031E-05  [K,I,J]    1   20  155
#  Transport Step:    9   Step Size:   2.911     Total Elapsed Time:   208.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3961E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7805E-05  [K,I,J]    1   20  155
#  Transport Step:   10   Step Size:   2.910     Total Elapsed Time:   211.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3927E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7584E-05  [K,I,J]    1   20  155
#  Transport Step:   11   Step Size:   2.910     Total Elapsed Time:   214.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3893E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7369E-05  [K,I,J]    1   20  155
#  Transport Step:   12   Step Size:   2.909     Total Elapsed Time:   217.51
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3859E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7159E-05  [K,I,J]    1   20  155
#  Transport Step:   13   Step Size:   2.908     Total Elapsed Time:   220.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3826E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6954E-05  [K,I,J]    1   20  155
#  Transport Step:   14   Step Size:   2.908     Total Elapsed Time:   223.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3793E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6755E-05  [K,I,J]    1   20  155
#  Transport Step:   15   Step Size:   2.907     Total Elapsed Time:   226.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3760E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6561E-05  [K,I,J]    1   20  155
#  Transport Step:   16   Step Size:   2.906     Total Elapsed Time:   229.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3727E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6373E-05  [K,I,J]    1   20  155
#  Transport Step:   17   Step Size:   2.906     Total Elapsed Time:   232.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3695E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6189E-05  [K,I,J]    1   20  155
#  Transport Step:   18   Step Size:   2.905     Total Elapsed Time:   234.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3663E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6011E-05  [K,I,J]    1   20  155
#  Transport Step:   19   Step Size:   2.904     Total Elapsed Time:   237.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3631E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5837E-05  [K,I,J]    1   20  155
#  Transport Step:   20   Step Size:   2.904     Total Elapsed Time:   240.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3599E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5669E-05  [K,I,J]    1   20  155
#  Transport Step:   21   Step Size:   2.903     Total Elapsed Time:   243.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3568E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5505E-05  [K,I,J]    1   20  155
#  Transport Step:   22   Step Size:   2.902     Total Elapsed Time:   246.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3538E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5346E-05  [K,I,J]    1   20  155
#  Transport Step:   23   Step Size:   2.902     Total Elapsed Time:   249.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3507E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5191E-05  [K,I,J]    1   20  155
#  Transport Step:   24   Step Size:   2.901     Total Elapsed Time:   252.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3477E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5041E-05  [K,I,J]    1   20  155
#  Transport Step:   25   Step Size:   2.901     Total Elapsed Time:   255.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3447E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4896E-05  [K,I,J]    1   20  155
#  Transport Step:   26   Step Size:   2.900     Total Elapsed Time:   258.17
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3417E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4754E-05  [K,I,J]    1   20  155
#  Transport Step:   27   Step Size:   2.899     Total Elapsed Time:   261.07
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3387E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4622E-05  [K,I,J]    1   21  155
#  Transport Step:   28   Step Size:   2.899     Total Elapsed Time:   263.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3358E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4502E-05  [K,I,J]    1   21  155
#  Transport Step:   29   Step Size:   2.898     Total Elapsed Time:   266.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3328E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4385E-05  [K,I,J]    1   21  155
#  Transport Step:   30   Step Size:   2.897     Total Elapsed Time:   269.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3299E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4272E-05  [K,I,J]    1   21  155
#  Transport Step:   31   Step Size:   2.897     Total Elapsed Time:   272.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3270E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4162E-05  [K,I,J]    1   21  155
#  Transport Step:   32   Step Size:   2.896     Total Elapsed Time:   275.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3242E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4055E-05  [K,I,J]    1   21  155
#  Transport Step:   33   Step Size:   2.895     Total Elapsed Time:   278.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3213E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3952E-05  [K,I,J]    1   21  155
#  Transport Step:   34   Step Size:   2.895     Total Elapsed Time:   281.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3185E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3851E-05  [K,I,J]    1   21  155
#  Transport Step:   35   Step Size:   2.894     Total Elapsed Time:   284.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3157E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3753E-05  [K,I,J]    1   21  155
#  Transport Step:   36   Step Size:   2.894     Total Elapsed Time:   287.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3129E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3658E-05  [K,I,J]    1   21  155
#  Transport Step:   37   Step Size:   2.893     Total Elapsed Time:   290.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3102E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3565E-05  [K,I,J]    1   21  155
#  Transport Step:   38   Step Size:   2.892     Total Elapsed Time:   292.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3074E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3475E-05  [K,I,J]    1   21  155
#  Transport Step:   39   Step Size:   2.892     Total Elapsed Time:   295.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3047E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3388E-05  [K,I,J]    1   21  155
#  Transport Step:   40   Step Size:   2.891     Total Elapsed Time:   298.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3020E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3303E-05  [K,I,J]    1   21  155
#  Transport Step:   41   Step Size:   2.891     Total Elapsed Time:   301.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2994E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3244E-05  [K,I,J]    1    8  151
#  Transport Step:   42   Step Size:   2.890     Total Elapsed Time:   304.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2967E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3210E-05  [K,I,J]    1    8  151
#  Transport Step:   43   Step Size:   2.889     Total Elapsed Time:   307.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2941E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3177E-05  [K,I,J]    1    8  151
#  Transport Step:   44   Step Size:   2.889     Total Elapsed Time:   310.26
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2914E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3144E-05  [K,I,J]    1    8  151
#  Transport Step:   45   Step Size:   2.888     Total Elapsed Time:   313.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2888E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3112E-05  [K,I,J]    1    8  151
#  Transport Step:   46   Step Size:   2.888     Total Elapsed Time:   316.03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2863E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3079E-05  [K,I,J]    1    8  151
#  Transport Step:   47   Step Size:   2.887     Total Elapsed Time:   318.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2837E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3047E-05  [K,I,J]    1    8  151
#  Transport Step:   48   Step Size:   2.886     Total Elapsed Time:   321.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2812E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3015E-05  [K,I,J]    1    8  151
#  Transport Step:   49   Step Size:   2.886     Total Elapsed Time:   324.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2786E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2983E-05  [K,I,J]    1    8  151
#  Transport Step:   50   Step Size:   2.885     Total Elapsed Time:   327.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2761E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2952E-05  [K,I,J]    1    8  151
#  Transport Step:   51   Step Size:   2.885     Total Elapsed Time:   330.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2737E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2921E-05  [K,I,J]    1    8  151
#  Transport Step:   52   Step Size:   2.884     Total Elapsed Time:   333.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2712E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2889E-05  [K,I,J]    1    8  151
#  Transport Step:   53   Step Size:   2.884     Total Elapsed Time:   336.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2688E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2858E-05  [K,I,J]    1    8  151
#  Transport Step:   54   Step Size:   2.883     Total Elapsed Time:   339.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2663E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2828E-05  [K,I,J]    1    8  151
#  Transport Step:   55   Step Size:   2.883     Total Elapsed Time:   342.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2639E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2797E-05  [K,I,J]    1    8  151
#  Transport Step:   56   Step Size:   2.882     Total Elapsed Time:   344.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2615E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2766E-05  [K,I,J]    1    8  151
#  Transport Step:   57   Step Size:   2.881     Total Elapsed Time:   347.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2592E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2736E-05  [K,I,J]    1    8  151
#  Transport Step:   58   Step Size:   2.881     Total Elapsed Time:   350.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2568E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2706E-05  [K,I,J]    1    8  151
#  Transport Step:   59   Step Size:   2.880     Total Elapsed Time:   353.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2545E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2675E-05  [K,I,J]    1    8  151
#  Transport Step:   60   Step Size:   2.880     Total Elapsed Time:   356.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2522E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2645E-05  [K,I,J]    1    8  151
#  Transport Step:   61   Step Size:   2.879     Total Elapsed Time:   359.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2499E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2615E-05  [K,I,J]    1    8  151
#  Transport Step:   62   Step Size:   2.879     Total Elapsed Time:   362.16
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2476E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2585E-05  [K,I,J]    1    8  151
#  Transport Step:   63   Step Size:   2.842     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2423E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2494E-05  [K,I,J]    1    8  151
#  Transport Step:   64   Step Size:  5.6843E-14 Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   365.00     TO    547.50
#
#  Transport Step:    1   Step Size:   2.878     Total Elapsed Time:   367.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5587E-02  [K,I,J]    1   27  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1112E-04  [K,I,J]    5    2  151
#  Transport Step:    2   Step Size:   2.909     Total Elapsed Time:   370.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2425E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2619E-05  [K,I,J]    1   36  165
#  Transport Step:    3   Step Size:   2.883     Total Elapsed Time:   373.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2391E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2571E-05  [K,I,J]    1   36  165
#  Transport Step:    4   Step Size:   2.878     Total Elapsed Time:   376.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2367E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2554E-05  [K,I,J]    1   36  165
#  Transport Step:    5   Step Size:   2.876     Total Elapsed Time:   379.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2345E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2542E-05  [K,I,J]    1   36  165
#  Transport Step:    6   Step Size:   2.875     Total Elapsed Time:   382.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2323E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2531E-05  [K,I,J]    1   36  165
#  Transport Step:    7   Step Size:   2.875     Total Elapsed Time:   385.17
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2302E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2520E-05  [K,I,J]    1   36  165
#  Transport Step:    8   Step Size:   2.874     Total Elapsed Time:   388.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2281E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2508E-05  [K,I,J]    1   36  165
#  Transport Step:    9   Step Size:   2.873     Total Elapsed Time:   390.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2260E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2495E-05  [K,I,J]    1   36  165
#  Transport Step:   10   Step Size:   2.873     Total Elapsed Time:   393.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2239E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2481E-05  [K,I,J]    1   36  165
#  Transport Step:   11   Step Size:   2.872     Total Elapsed Time:   396.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2218E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2466E-05  [K,I,J]    1   36  165
#  Transport Step:   12   Step Size:   2.872     Total Elapsed Time:   399.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2198E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2450E-05  [K,I,J]    1   36  165
#  Transport Step:   13   Step Size:   2.871     Total Elapsed Time:   402.41
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2177E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2433E-05  [K,I,J]    1   36  165
#  Transport Step:   14   Step Size:   2.871     Total Elapsed Time:   405.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2157E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2414E-05  [K,I,J]    1   36  165
#  Transport Step:   15   Step Size:   2.870     Total Elapsed Time:   408.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2137E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2394E-05  [K,I,J]    1   36  165
#  Transport Step:   16   Step Size:   2.870     Total Elapsed Time:   411.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2118E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2373E-05  [K,I,J]    1   36  165
#  Transport Step:   17   Step Size:   2.869     Total Elapsed Time:   413.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2098E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2350E-05  [K,I,J]    1   36  165
#  Transport Step:   18   Step Size:   2.869     Total Elapsed Time:   416.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2078E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2325E-05  [K,I,J]    1   36  165
#  Transport Step:   19   Step Size:   2.868     Total Elapsed Time:   419.63
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2059E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2299E-05  [K,I,J]    1   36  165
#  Transport Step:   20   Step Size:   2.868     Total Elapsed Time:   422.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2040E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2270E-05  [K,I,J]    1   36  165
#  Transport Step:   21   Step Size:   2.868     Total Elapsed Time:   425.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2021E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2240E-05  [K,I,J]    1   36  165
#  Transport Step:   22   Step Size:   2.867     Total Elapsed Time:   428.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2002E-02  [K,I,J]    6   39  128
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2207E-05  [K,I,J]    1   36  165
#  Transport Step:   23   Step Size:   2.867     Total Elapsed Time:   431.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1989E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2172E-05  [K,I,J]    1   36  165
#  Transport Step:   24   Step Size:   2.866     Total Elapsed Time:   433.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1984E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2133E-05  [K,I,J]    1   36  165
#  Transport Step:   25   Step Size:   2.866     Total Elapsed Time:   436.83
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1979E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2091E-05  [K,I,J]    1   36  165
#  Transport Step:   26   Step Size:   2.865     Total Elapsed Time:   439.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1974E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2045E-05  [K,I,J]    1   36  165
#  Transport Step:   27   Step Size:   2.865     Total Elapsed Time:   442.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1969E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1995E-05  [K,I,J]    1   36  165
#  Transport Step:   28   Step Size:   2.864     Total Elapsed Time:   445.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1964E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1938E-05  [K,I,J]    1   36  165
#  Transport Step:   29   Step Size:   2.864     Total Elapsed Time:   448.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1958E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1874E-05  [K,I,J]    1   36  165
#  Transport Step:   30   Step Size:   2.863     Total Elapsed Time:   451.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1953E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1802E-05  [K,I,J]    1   36  165
#  Transport Step:   31   Step Size:   2.863     Total Elapsed Time:   454.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1948E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1717E-05  [K,I,J]    1   36  165
#  Transport Step:   32   Step Size:   2.862     Total Elapsed Time:   456.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1942E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1616E-05  [K,I,J]    1   36  165
#  Transport Step:   33   Step Size:   2.862     Total Elapsed Time:   459.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1937E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1492E-05  [K,I,J]    1   36  165
#  Transport Step:   34   Step Size:   2.861     Total Elapsed Time:   462.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1932E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1333E-05  [K,I,J]    1   36  165
#  Transport Step:   35   Step Size:   2.861     Total Elapsed Time:   465.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1926E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1120E-05  [K,I,J]    1   29  166
#  Transport Step:   36   Step Size:   2.861     Total Elapsed Time:   468.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1921E-02  [K,I,J]    3    6  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8014E-06  [K,I,J]    1   29  166
#  Transport Step:   37   Step Size:   2.860     Total Elapsed Time:   471.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1917E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2116E-06  [K,I,J]    1   29  166
#  Transport Step:   38   Step Size:   2.860     Total Elapsed Time:   474.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1914E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1488E-05  [K,I,J]    1   29  166
#  Transport Step:   39   Step Size:   2.859     Total Elapsed Time:   476.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1911E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1776E-04  [K,I,J]    1   29  166
#  Transport Step:   40   Step Size:   2.859     Total Elapsed Time:   479.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1908E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1737E-05  [K,I,J]    1   29  166
#  Transport Step:   41   Step Size:   2.858     Total Elapsed Time:   482.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1904E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1025E-05  [K,I,J]    1   29  166
#  Transport Step:   42   Step Size:   2.858     Total Elapsed Time:   485.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1901E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2177E-05  [K,I,J]    1   29  166
#  Transport Step:   43   Step Size:   2.858     Total Elapsed Time:   488.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1897E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5140E-05  [K,I,J]    1   29  166
#  Transport Step:   44   Step Size:   2.857     Total Elapsed Time:   491.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1894E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8489E-04  [K,I,J]    1   29  166
#  Transport Step:   45   Step Size:   2.857     Total Elapsed Time:   494.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1890E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2252E-05  [K,I,J]    1   29  166
#  Transport Step:   46   Step Size:   2.856     Total Elapsed Time:   496.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1886E-02  [K,I,J]    4    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2421E-05  [K,I,J]    1   29  166
#  Transport Step:   47   Step Size:   2.856     Total Elapsed Time:   499.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1883E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2682E-05  [K,I,J]    1   29  166
#  Transport Step:   48   Step Size:   2.855     Total Elapsed Time:   502.61
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1879E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2958E-05  [K,I,J]    1   29  166
#  Transport Step:   49   Step Size:   2.855     Total Elapsed Time:   505.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1876E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3178E-05  [K,I,J]    1   29  166
#  Transport Step:   50   Step Size:   2.855     Total Elapsed Time:   508.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1872E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3318E-05  [K,I,J]    1   29  166
#  Transport Step:   51   Step Size:   2.854     Total Elapsed Time:   511.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1868E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3388E-05  [K,I,J]    1   29  166
#  Transport Step:   52   Step Size:   2.854     Total Elapsed Time:   514.03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1865E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3409E-05  [K,I,J]    1   29  166
#  Transport Step:   53   Step Size:   2.853     Total Elapsed Time:   516.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1861E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3397E-05  [K,I,J]    1   29  166
#  Transport Step:   54   Step Size:   2.853     Total Elapsed Time:   519.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1857E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3367E-05  [K,I,J]    1   29  166
#  Transport Step:   55   Step Size:   2.853     Total Elapsed Time:   522.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1853E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3326E-05  [K,I,J]    1   29  166
#  Transport Step:   56   Step Size:   2.852     Total Elapsed Time:   525.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1849E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3280E-05  [K,I,J]    1   29  166
#  Transport Step:   57   Step Size:   2.852     Total Elapsed Time:   528.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1845E-02  [K,I,J]    3    6  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3232E-05  [K,I,J]    1   29  166
#  Transport Step:   58   Step Size:   2.851     Total Elapsed Time:   531.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1841E-02  [K,I,J]    3    6  172
# ...
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6580E-06  [K,I,J]    1    5  234
#  Transport Step:   58   Step Size:   2.764     Total Elapsed Time:   3080.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8644E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6564E-06  [K,I,J]    1    5  234
#  Transport Step:   59   Step Size:   2.764     Total Elapsed Time:   3083.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8641E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6548E-06  [K,I,J]    1    5  234
#  Transport Step:   60   Step Size:   2.764     Total Elapsed Time:   3085.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8637E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6532E-06  [K,I,J]    1    5  234
#  Transport Step:   61   Step Size:   2.764     Total Elapsed Time:   3088.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8634E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6515E-06  [K,I,J]    1    5  234
#  Transport Step:   62   Step Size:   2.764     Total Elapsed Time:   3091.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8630E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6499E-06  [K,I,J]    1    5  234
#  Transport Step:   63   Step Size:   2.763     Total Elapsed Time:   3094.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8626E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6483E-06  [K,I,J]    1    5  234
#  Transport Step:   64   Step Size:   2.763     Total Elapsed Time:   3096.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8622E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6466E-06  [K,I,J]    1    5  234
#  Transport Step:   65   Step Size:   2.763     Total Elapsed Time:   3099.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8618E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6450E-06  [K,I,J]    1    5  234
#  Transport Step:   66   Step Size:   2.763     Total Elapsed Time:   3102.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8614E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6433E-06  [K,I,J]    1    5  234
#  Transport Step:   67   Step Size:  2.5992E-02 Total Elapsed Time:   3102.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8104E-05  [K,I,J]    8    1  241
#  Transport Step:   68   Step Size:  4.5475E-13 Total Elapsed Time:   3102.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.   18
#
#   STRESS PERIOD   18 TIME STEP    1 FROM TIME =   3102.5     TO    3285.0
#
#  Transport Step:    1   Step Size:   2.763     Total Elapsed Time:   3105.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8537E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6549E-06  [K,I,J]    1    5  234
#  Transport Step:    2   Step Size:   2.787     Total Elapsed Time:   3108.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8679E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6533E-06  [K,I,J]    1    5  234
#  Transport Step:    3   Step Size:   2.773     Total Elapsed Time:   3110.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8629E-03  [K,I,J]    8    1  241
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6389E-06  [K,I,J]    1    5  234
#  Transport Step:    4   Step Size:   2.767     Total Elapsed Time:   3113.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8609E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6341E-06  [K,I,J]    1    5  234
#  Transport Step:    5   Step Size:   2.765     Total Elapsed Time:   3116.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8600E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6319E-06  [K,I,J]    1    5  234
#  Transport Step:    6   Step Size:   2.764     Total Elapsed Time:   3119.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8595E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6305E-06  [K,I,J]    1    5  234
#  Transport Step:    7   Step Size:   2.764     Total Elapsed Time:   3121.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8591E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6293E-06  [K,I,J]    1    5  234
#  Transport Step:    8   Step Size:   2.763     Total Elapsed Time:   3124.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8587E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6281E-06  [K,I,J]    1    5  234
#  Transport Step:    9   Step Size:   2.763     Total Elapsed Time:   3127.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8584E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6268E-06  [K,I,J]    1    5  234
#  Transport Step:   10   Step Size:   2.763     Total Elapsed Time:   3130.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8581E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6254E-06  [K,I,J]    1    5  234
#  Transport Step:   11   Step Size:   2.763     Total Elapsed Time:   3132.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8578E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6239E-06  [K,I,J]    1    5  234
#  Transport Step:   12   Step Size:   2.763     Total Elapsed Time:   3135.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8575E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6224E-06  [K,I,J]    1    5  234
#  Transport Step:   13   Step Size:   2.763     Total Elapsed Time:   3138.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8572E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6208E-06  [K,I,J]    1    5  234
#  Transport Step:   14   Step Size:   2.763     Total Elapsed Time:   3141.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8569E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6192E-06  [K,I,J]    1    5  234
#  Transport Step:   15   Step Size:   2.763     Total Elapsed Time:   3144.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8566E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6176E-06  [K,I,J]    1    5  234
#  Transport Step:   16   Step Size:   2.763     Total Elapsed Time:   3146.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8562E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6159E-06  [K,I,J]    1    5  234
#  Transport Step:   17   Step Size:   2.763     Total Elapsed Time:   3149.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8559E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6142E-06  [K,I,J]    1    5  234
#  Transport Step:   18   Step Size:   2.763     Total Elapsed Time:   3152.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8555E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6125E-06  [K,I,J]    1    5  234
#  Transport Step:   19   Step Size:   2.763     Total Elapsed Time:   3155.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8552E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6108E-06  [K,I,J]    1    5  234
#  Transport Step:   20   Step Size:   2.763     Total Elapsed Time:   3157.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8548E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6091E-06  [K,I,J]    1    5  234
#  Transport Step:   21   Step Size:   2.763     Total Elapsed Time:   3160.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8544E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6073E-06  [K,I,J]    1    5  234
#  Transport Step:   22   Step Size:   2.763     Total Elapsed Time:   3163.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8541E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6056E-06  [K,I,J]    1    5  234
#  Transport Step:   23   Step Size:   2.763     Total Elapsed Time:   3166.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8537E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6038E-06  [K,I,J]    1    5  234
#  Transport Step:   24   Step Size:   2.763     Total Elapsed Time:   3168.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8533E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6020E-06  [K,I,J]    1    5  234
#  Transport Step:   25   Step Size:   2.763     Total Elapsed Time:   3171.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8529E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6003E-06  [K,I,J]    1    5  234
#  Transport Step:   26   Step Size:   2.763     Total Elapsed Time:   3174.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8525E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5985E-06  [K,I,J]    1    5  234
#  Transport Step:   27   Step Size:   2.763     Total Elapsed Time:   3177.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8521E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5967E-06  [K,I,J]    1    5  234
#  Transport Step:   28   Step Size:   2.763     Total Elapsed Time:   3179.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8517E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5949E-06  [K,I,J]    1    5  234
#  Transport Step:   29   Step Size:   2.763     Total Elapsed Time:   3182.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8513E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5932E-06  [K,I,J]    1    5  234
#  Transport Step:   30   Step Size:   2.763     Total Elapsed Time:   3185.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8509E-03  [K,I,J]    8    1  242
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5914E-06  [K,I,J]    1    5  234
#  Transport Step:   31   Step Size:   2.763     Total Elapsed Time:   3188.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8506E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5896E-06  [K,I,J]    1    5  234
#  Transport Step:   32   Step Size:   2.763     Total Elapsed Time:   3191.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8503E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5878E-06  [K,I,J]    1    5  234
#  Transport Step:   33   Step Size:   2.763     Total Elapsed Time:   3193.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8500E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5860E-06  [K,I,J]    1    5  234
#  Transport Step:   34   Step Size:   2.763     Total Elapsed Time:   3196.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8497E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5841E-06  [K,I,J]    1    5  234
#  Transport Step:   35   Step Size:   2.763     Total Elapsed Time:   3199.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8494E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5823E-06  [K,I,J]    1    5  234
#  Transport Step:   36   Step Size:   2.763     Total Elapsed Time:   3202.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8491E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5805E-06  [K,I,J]    1    5  234
#  Transport Step:   37   Step Size:   2.763     Total Elapsed Time:   3204.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8488E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5787E-06  [K,I,J]    1    5  234
#  Transport Step:   38   Step Size:   2.763     Total Elapsed Time:   3207.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8485E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5769E-06  [K,I,J]    1    5  234
#  Transport Step:   39   Step Size:   2.763     Total Elapsed Time:   3210.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8482E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5750E-06  [K,I,J]    1    5  234
#  Transport Step:   40   Step Size:   2.763     Total Elapsed Time:   3213.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8479E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5732E-06  [K,I,J]    1    5  234
#  Transport Step:   41   Step Size:   2.763     Total Elapsed Time:   3215.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8476E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5714E-06  [K,I,J]    1    5  234
#  Transport Step:   42   Step Size:   2.763     Total Elapsed Time:   3218.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8472E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5695E-06  [K,I,J]    1    5  234
#  Transport Step:   43   Step Size:   2.763     Total Elapsed Time:   3221.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8469E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5677E-06  [K,I,J]    1    5  234
#  Transport Step:   44   Step Size:   2.762     Total Elapsed Time:   3224.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8465E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5658E-06  [K,I,J]    1    5  234
#  Transport Step:   45   Step Size:   2.762     Total Elapsed Time:   3226.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8462E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5640E-06  [K,I,J]    1    5  234
#  Transport Step:   46   Step Size:   2.762     Total Elapsed Time:   3229.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8458E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5621E-06  [K,I,J]    1    5  234
#  Transport Step:   47   Step Size:   2.762     Total Elapsed Time:   3232.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8455E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5603E-06  [K,I,J]    1    5  234
#  Transport Step:   48   Step Size:   2.762     Total Elapsed Time:   3235.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8451E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5584E-06  [K,I,J]    1    5  234
#  Transport Step:   49   Step Size:   2.762     Total Elapsed Time:   3237.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8447E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5566E-06  [K,I,J]    1    5  234
#  Transport Step:   50   Step Size:   2.762     Total Elapsed Time:   3240.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8443E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5547E-06  [K,I,J]    1    5  234
#  Transport Step:   51   Step Size:   2.762     Total Elapsed Time:   3243.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8439E-03  [K,I,J]    8    1  243
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5528E-06  [K,I,J]    1    5  234
#  Transport Step:   52   Step Size:   2.762     Total Elapsed Time:   3246.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/mbase.py in run_model(self, silent, pause, report, normal_msg)
#    1222         return run_model(self.exe_name, self.namefile, model_ws=self.model_ws,
#    1223                          silent=silent, pause=pause, report=report,
# -> 1224                          normal_msg=normal_msg)
#    1225
#    1226     def load_results(self):
#
# ~/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy/mbase.py in run_model(exe_name, namefile, model_ws, silent, pause, report, normal_msg, use_async, cargs)
#    1603     if not use_async:
#    1604         while True:
# -> 1605             line = proc.stdout.readline().decode('utf-8')
#    1606             if line == '' and proc.poll() is not None:
#    1607                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Post processing

# %%
fname = model_ws.joinpath('MT3D001.UCN').as_posix()
anyvals= []
ucnobj = flopy.utils.binaryfile.UcnFile(fname,verbose=False)
# if kstpkper==None:
kstpkpers = ucnobj.get_kstpkper()
for kstpkper in kstpkpers:
    conc = ucnobj.get_data(kstpkper=kstpkper)
    anyvals.append(np.logical_and(conc < 100., conc>0.).any())
print(anyvals)

conc = ucnobj.get_data(kstpkper=kstpkpers[-1])
conc[conc > 100]=np.nan
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
from matplotlib import cm

slicetype='Row'
slicenum= -1

# First step is to set up the plot
fig = plt.figure(figsize=(9, 3))
ax = fig.add_subplot(1, 1, 1)

# Next we create an instance of the PlotCrossSection class
xsect = flopy.plot.PlotCrossSection(model=m, line={slicetype: slicenum},geographic_coords=True)
# xsect.plot_ibound()
xsect.plot_grid(linewidth=.1)
# Then we can use the plot_grid() method to draw the grid
# The return value for this function is a matplotlib LineCollection object,
# which could be manipulated (or used) later if necessary.
# linecollection = xsect.plot_grid()
# patches = xsect.plot_ibound()
# csa = xsect.plot_array(layer_mapping_ind)
# cmap = cm.get_cmap('tab10', lay_m.shape[0])
csa = xsect.plot_array(conc,cmap='jet')
c = plt.colorbar(csa)
# wel = xsect.plot_bc("CHD")
wel = xsect.plot_bc("GHB")



t = ax.set_title('{slicetype} {slicenum} Cross-Section'.format(slicetype=slicetype,slicenum=slicenum))
plt.ylabel('Elevation (m)')
plt.ylim((-200,100))
plt.xlabel('X UTM (m)')
# c.set_label('log10(hk)')
# plt.savefig(figdir.joinpath('seawat_fine_xsection_layers_{slicetype}{slicenum}.png'.format(slicetype=slicetype,slicenum=slicenum)),dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Distance (m)')

# %%
m.nrow
# Out:
# 40
