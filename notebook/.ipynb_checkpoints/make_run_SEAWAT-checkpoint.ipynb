# %%
import flopy
import os
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

if sys.platform.lower()=='linux':
    datadir = Path('/scratch/users/ianpg/SWIlarge/data')
    workdir = Path('/scratch/users/ianpg/SWIlarge/work')
    MPSdir = datadir.joinpath('lith/sgems/MPS')
    GISdir = datadir.joinpath('GIS')
    import mplleaflet
elif sys.platform.lower()=='darwin':
    datadir = Path('../data')
    workdir = Path('../work')
    MPSdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/lith/sgems/MPS')
    GISdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/GIS')

nmgwmdir_empty = datadir.joinpath('nmgwmdir_empty') #<-- removed everything but DIS
nmgwmdir_cal = datadir.joinpath('Calibrated_small') #<-- removed RCH, WEL, GLO, LST from the NAM file to load much faster
figdir = workdir.joinpath('figs')
outputdir = workdir.joinpath('output')

import config
from set_rc import *

import pandas as pd
import shapefile as sf #in case you dont have it, form anaconda prompt: pip install pyshp
from flopy.utils.gridgen import Gridgen
from flopy.utils.reference import SpatialReference
from  pyproj import Proj

p = Proj("epsg:26910")
xll=595855
yll = 4059438
rotation = -13.5
# Out:
# flopy is installed in /Users/ianpg/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy
# system: darwin

# %%
#%% Useful functions
def load_obj(dirname,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'rb') as f:
        return pickle.load(f)

def save_obj(dirname,obj,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

#Create new MC_file
def create_MC_file():
    import datetime
    ts = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
    MC_dir = Path(os.path.join(m.model_ws, 'MC_expt_' + ts))
    if not MC_dir.exists():
        MC_dir.mkdir()
    m.MC_file = MC_dir.joinpath('expt.txt')
    with m.MC_file.open('w') as wf:
        wf.close
    print(m.MC_file)
    return

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

#make a line across the grid
def get_line(start, end,allrows=1,nrow=None):
    """Bresenham's Line Algorithm
    Produces a list of tuples from start and end

    >>> points1 = get_line((0, 0), (3, 4))
    >>> points2 = get_line((3, 4), (0, 0))
    >>> assert(set(points1) == set(points2))
    >>> print points1
    [(0, 0), (1, 1), (1, 2), (2, 3), (3, 4)]
    >>> print points2
    [(3, 4), (2, 3), (1, 2), (1, 1), (0, 0)]
    """
    # Setup initial conditions
    x1, y1 = start
    x2, y2 = end
    dx = x2 - x1
    dy = y2 - y1

    # Determine how steep the line is
    is_steep = abs(dy) > abs(dx)

    # Rotate line
    if is_steep:
        x1, y1 = y1, x1
        x2, y2 = y2, x2

    # Swap start and end points if necessary and store swap state
    swapped = False
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
        swapped = True

    # Recalculate differentials
    dx = x2 - x1
    dy = y2 - y1

    # Calculate error
    error = int(dx / 2.0)
    ystep = 1 if y1 < y2 else -1

    # Iterate over bounding box generating points between start and end
    y = y1
    points = []
    for x in range(x1, x2 + 1):
        if allrows==1:
            if nrow is None:
                nrow = m.nrow
            for row in range(nrow):
                coord = (y, row, x) if is_steep else (x, row, y)
                points.append(coord)
        else:
            coord = (y, x) if is_steep else (x, y)
            points.append(coord)
        error -= abs(dy)
        if error < 0:
            y += ystep
            error += dx

    # Reverse the list if the coordinates were swapped
    if swapped:
        points.reverse()
    return points


#make all cells=0 above the line from get_line()
#Calculate freshwater head based on column of saltwater above each node (rho*g*z)
def shade_above(nlay,nrow,ncol,point_list,third_dim=1):
    import numpy as np
    grd = np.ones((nlay,nrow,ncol),dtype='int')
    ocean_hf = []
    if len(point_list)==0:
        return grd,ocean_hf
    for (lay,row,col) in point_list:
        grd[lay,:,col] = -1 #assign ocean ibound to -1
        grd[:lay,:,col] = 0 #assign cells above ocean to 0
        hf = densefresh/densesalt*ocean_elev - (densesalt - densefresh)/densefresh*(henry_botm[lay] +.5*delv)
        for irow in range(nrow):
            ocean_hf.append((int(lay),int(irow),int(col),hf))
    ocean_hf = tuple(np.array(ocean_hf).T)
    ocean_hf = (ocean_hf[0].astype('int'),
                ocean_hf[1].astype('int'),
                ocean_hf[2].astype('int'),
                ocean_hf[3])
    return grd,ocean_hf

def get_ocean_right_edge(m,ocean_line_tuple,startlay=None,col=None):
    import numpy as np
    point_list = []
    if col is None:
        col = m.ncol-1
    #If there is no vertical side boundary, return bottom-right corner node
    if len(ocean_line_tuple)==0:
        if startlay is None:
            startlay = 0
    elif max(ocean_line_tuple[0])==m.nlay:
        startlay = m.nlay
    elif max(ocean_line_tuple[0])<m.nlay:
        startlay = max(ocean_line_tuple[0])
    for lay in range(startlay,m.nlay):
        for row in range(m.nrow):
            point_list.append((lay,row,col))
    point_list = tuple(np.array(point_list).T)
    return point_list

def add_pumping_wells(wel_data,ssm_data,n_wells,flx,rowcol,kper):
    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    new_weldata = wel_data
    new_ssmdata = ssm_data
    wel_cells = []
    for k in range(n_wells):
        row,col = rowcol[k]
        for i in range(nper):
            if i in kper:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,-flx[k]*delv_weight[j]])
                    wel_cells.append((j,row,col))
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
            else:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,0])
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
                    wel_cells.append((j,row,col))
                continue
    wel_cells = tuple(np.array(list(set(wel_cells))).T)
    return new_weldata, new_ssmdata,wel_cells

#Add recharge if desired
def make_rech_array(low=1e-2,high=1e0):
    import scipy.stats as sts
    llow,lhigh = np.log10((low,high))
    rech = np.exp(sts.uniform.rvs(size=1,loc=llow,scale=lhigh-llow)[0])
    return rech/(nrow*ncol)

def add_recharge_cells(recharge_generator,const=1,*args):
    if const==1:
        rech_data = recharge_generator(*args)
    else:
        rech_data = {}
        for i in range(nper):
            rech_array = recharge_generator(*args)
        rech_data[i] = rech_array
    return rech_data

def sample_dist(distclass,size,*args):
    smp = distclass.rvs(*args,size=size)
    if size==1:
        smp=smp[-1]
    return smp

def write_sample(fname,varname,distclass,sample):
    fout= open(fname,"a")
    fout.write(varname + ',' + str(type(distclass)) + ',' + str(sample) + '\n')
    fout.close()
    return

def truncate_grf(grid,lith_props,hk_vals,log10trans=True,plotyn=False,saveyn=False):
    grid_cutoffs = []
    for q in np.cumsum(lith_props):
        grid_cutoffs.append(np.quantile(grid,q))

    if plotyn:
        h = plt.hist(grid.flatten())
        for cutoff in grid_cutoffs:
            plt.vlines(cutoff,0,14000)
        plt.show()

    outgrid = np.ones(grid.shape,dtype=np.float32)
    for i,cutoff in reversed(list(enumerate(grid_cutoffs))):
        outgrid[np.where(grid<cutoff)] = hk_vals[i]

    if plotyn:
        f,axs = plt.subplots(2,1,sharex=True)
        axs[0].imshow(grid[:,0,:])
        axs[1].imshow(outgrid[:,0,:])
        if saveyn:
            plt.savefig(m.MC_file.parent.joinpath('Truncated_GRF.png').as_posix(),resolution=300)
    if log10trans:
        return np.power(10,outgrid)
    else:
        return outgrid

def make_timestamp(YMD=True,HM=True):
    import datetime
    if YMD:
        ymd = '%Y%m%d'
    else:
        ymd = ''
    if HM:
        hm = '%H%M'
    else:
        hm = ''
    if YMD and HM:
        sep = '_'
    else:
        sep = ''
    return datetime.datetime.now().strftime('{}{}{}'.format(ymd,sep,hm))

def pec_num(delv,delc,delr,al):
    delL = (delv,delc,delr) #length in the lay,row,col directions
    pec_num = [round(d/al,2) for d in delL]
    for num,point  in zip(pec_num,('lay','row','col')):
        print('Pe = {} in the {} direction'.format(num,point))
    return pec_num

#%%

# %%
# %%time
m_nm= flopy.modflow.Modflow.load('nm_cali.nam',version='mf2k',verbose=False,check=False,model_ws=nmgwmdir_cal.as_posix())
# m = flopy.modflow.Modflow.load(nmgwmdir_uncal.joinpath('C1-12_copy.nam').as_posix(),version='mf2k',verbose=False,check=False,model_ws=outputdir.joinpath('C1').as_posix())
m_nm.exe_name = config.mf2000exe
if not m_nm.DIS.lenuni==2:
    m_nm.DIS.delr *= .3048
    m_nm.DIS.delc *= .3048
    m_nm.DIS.top *= .3048
    m_nm.DIS.botm *= .3048
m_nm.DIS.lenuni = 2
m_nm.DIS.itmuni=4
m_nm.DIS.rotation=-13.5
# m_nm.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_nm.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_nm.DIS.proj4_str = p.srs
m_nm.modelgrid.set_coord_info(xoff=xll, yoff=yll, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
# Out:
# CPU times: user 1min 24s, sys: 1.13 s, total: 1min 25s
# Wall time: 1min 29s

# %%
start_nm_yr = 1979
start_nm_mo = 10
start_nm_str = 'Oct 1979'
end_nm_yr = 2011
end_nm_mo = 9
end_nm_str = 'Sep 2011'
Lt_nm = ( (end_nm_yr + end_nm_mo/12)  - (start_nm_yr + start_nm_mo/12) )     *365
start_nm_datetime='{}/1/{}'.format(start_nm_mo,start_nm_yr)



start_m_yr = 1979
start_m_mo = 10
start_m_str = 'Oct 1979'
# end_m_yr = 2011
# end_m_mo = 9
# end_m_str = 'Sep 2011'
# Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
# start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)


# start_m_yr = 1980
# start_m_mo = 3
# start_m_str = 'Mar 1980'


start_m_yr = 1990
start_m_mo = 3
start_m_str = 'Mar 1990'

end_m_yr = 2030
end_m_mo = 10
end_m_str = 'Sep 2030'
Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)

# %%
#Name model
modelname = 'NM'
model_ws = workdir.joinpath("NM")
#Name model
sw_exe = config.swexe #set the exe path for seawat

#Model discretization
Lz = 150.

# nrow,ncol,nlay,nper = m_nm.nrow_ncol_nlay_nper

# rows = np.arange(100,102)
# rows = np.arange(100,102)
rows = np.arange(m_nm.nrow-102,   m_nm.nrow-100) #NM super reduced

# rows = np.arange(nrow)
# rows = np.arange(m_nm.nrow-159,   m_nm.nrow-132) #SV
# rows = np.arange(m_nm.nrow-114,   m_nm.nrow-74) #NM
# rows = np.arange(m_nm.nrow-114,   m_nm.nrow-95) #NM reduced, tsw included in domain

cols = np.arange(ncol)
nrow =len(rows) 
ncol = len(cols)
nlay=20


henry_top = 2
ocean_elev = 0
delv_first = 4
botm_first = henry_top-delv_first


delv = (Lz-delv_first) / (nlay-1)
delr = m_nm.dis.delr.array[0]
delc = m_nm.dis.delc.array[0]

henry_botm = np.hstack(([botm_first],np.linspace(botm_first-delv,henry_top-Lz,nlay-1)))
delv_vec = np.hstack((delv_first,np.repeat(delv,nlay-1)))
delv_weight = [x/np.sum(delv_vec) for x in delv_vec]


topo_grid = np.load(GISdir.joinpath('topo_grid.npy'))
henry_top = topo_grid[(slice(rows[0],rows[-1]+1),slice(cols[0],cols[-1]+1))]


# beachslope = .05
# ocean_col = [np.floor(ncol-1).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn
# ocean_col = [np.floor(ncol/2).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn

# inland_elev = beachslope*ocean_col[0]*delr
# offshore_elev = -beachslope*(ocean_col[1]-ocean_col[0])*delr


#Period data
# nyrs= 2
# Lt = 365*nyrs #Length of time in days

perlen = list(np.repeat(365/2,int(Lt_m/(365/2))))
nper = len(perlen)
nstp = np.ones_like(perlen,dtype=np.int)

# nstp = m_nm.dis.nstp.array
# perlen = m_nm.dis.perlen.array
# nper = m_nm.nper





steady = [False for x in range(len(perlen))] #Never steady
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1.1
ssm_data = None
verbose = True

print('Model setup: \n'
      'nlay: {}\n'
      'nrow: {}\n'
      'ncol: {}\n'
      'Total cells: {}\n'
      'Total time: {} days\n'
      'nper: {}\n'.format(nlay,nrow,ncol,nlay*nrow*ncol,Lt_m,nper))
# In[4]:

#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws.as_posix(),verbose=verbose)
# SGD.ModelSGD.Seawat2SGD(m)  #convert to subclass ModelSGD
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,
                               start_datetime=start_m_datetime)

xll=595855
yll = 4059438
rotation=-13.5
# p = Proj(proj='utm',zone='10n',ellps='WGS84',units='meters', preserve_units=False)

m.DIS.lenuni = 2
m.DIS.itmuni=4
m.DIS.rotation=-13.5
# m.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m.DIS.proj4_str = p.srs
xll_m,yll_m = m_nm.modelgrid.xvertices[rows[-1]+1,0],m_nm.modelgrid.yvertices[rows[-1]+1,0]


m.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
print(m.modelgrid)
# Out:
# Model setup:
# nlay: 20
# nrow: 2
# ncol: 345
# Total cells: 13800
# Total time: 14812.916666666639 days
# nper: 81
#
# NM.nam
# adding Package:  DIS
# xll:597278.0829380656; yll:4065365.567034744; rotation:-13.5; proj4_str:+proj=utm +zone=10 +datum=NAD83 +units=m +no_defs; units:undefined; lenuni:0

# %%
m_empty = flopy.modflow.Modflow('m_empty', model_ws=model_ws.joinpath('m_empty').as_posix())


flopy.modflow.ModflowDis(m_empty, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,start_datetime=start_m_datetime)

m_empty.DIS.lenuni = 2
m_empty.DIS.itmuni=4
m_empty.DIS.rotation=-13.5
# m_empty.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_empty.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_empty.DIS.proj4_str = p.srs
m_empty.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')

# %%
# %%time
gridgen_ws = model_ws.joinpath('gridgen')
if not gridgen_ws.exists():
    gridgen_ws.mkdir()
g = Gridgen(m_empty.dis, model_ws=gridgen_ws.as_posix(),exe_name=config.gridgenexe,surface_interpolation='replicate')
g.build(verbose=False)
# Out:
# CPU times: user 891 ms, sys: 131 ms, total: 1.02 s
# Wall time: 3.28 s

# %%
f_swi_180 = GISdir.joinpath("chloride_contours",'SWI_180_lines_noz.shp').as_posix()
swi_180 = sf.Reader(f_swi_180)
yrs_180 = [ int(r[-1]) for r in swi_180.records()]


for yr in yrs_180:
    f_exp = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_180.fields[1:] # skip first deletion field
        for feature in swi_180.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

f_swi_400 = GISdir.joinpath("chloride_contours",'SWI_400_lines_noz.shp').as_posix()
swi_400 = sf.Reader(f_swi_400)
yrs_400 = [ int(r[-1]) for r in swi_400.records()]


for yr in yrs_400:
    f_exp = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_400.fields[1:] # skip first deletion field
        for feature in swi_400.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

# %%
layer =3
yr = yrs_180[-1]
f_shp_180 = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
int_180 = g.intersect(f_shp_180,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_180.nodenumber] = 1
a180 = a.reshape((nlay,nrow,ncol),order='C')


yr = yrs_400[-1]
f_shp_400 = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
int_400 = g.intersect(f_shp_400,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_400.nodenumber] = 1
a400 = a.reshape((nlay,nrow,ncol),order='C')

# %% [raw]
# df_TDS = pd.read_excel(datadir.joinpath('WQ','export_TDS_data.xlsx'))
# TDSij =[]
# for x,y in zip(df_TDS.X_NAD83_UTM10N.values,df_TDS.Y_NAD83_UTM10N.values):
#     try:
#         TDSij.append(m_empty.modelgrid.intersect(x,y))
#     except:
#         TDSij.append((np.nan,np.nan))
# df_TDS = df_TDS.assign(rowi=np.array(TDSij)[:,0])
# df_TDS = df_TDS.assign(colj=np.array(TDSij)[:,1])

# %%
def intersect_swi_contour(aquifer=180,yr_ind=None):
    if aquifer==180:
        yr = yrs_180[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    elif aquifer==400:
        yr = yrs_400[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    else:
        raise('enter either 180 or 400')
    int_obj = g.intersect(f,'polygon',layer=layer)
    a = np.zeros((g.nodes), dtype=np.int)
    a[int_obj.nodenumber] = 1
    return a.reshape((nlay,nrow,ncol),order='C')


from scipy.interpolate import interp2d,RectBivariateSpline,NearestNDInterpolator,griddata
def make_surf(grid_old,m_old,m_new,method='nearest'):
    points = np.stack((m_old.modelgrid.xcellcenters.flatten(),m_old.modelgrid.ycellcenters.flatten())).T
    values = grid_old.flatten()
    grid_x=  m_new.modelgrid.xcellcenters
    grid_y=  m_new.modelgrid.ycellcenters
    return griddata(points, values, (grid_x, grid_y), method=method)

# %%
botm_orig= m_nm.DIS.botm.array[:6]
layer_mapping = np.zeros((7,nlay,nrow,ncol),dtype=bool)
for lay in range(7):
    if lay==0:
        ind_inlay = np.zeros((nlay,nrow,ncol),dtype=np.bool)
        ind_inlay[0,:,:] = True
    elif lay==6:
#         botm_orig_lay = interp_surf2newgrid(botm_orig[lay-1])
        botm_orig_lay = make_surf(botm_orig[-1],m_nm,m_empty)
        ind_inlay = m_empty.dis.botm.array<botm_orig_lay
    else:
        botm_orig_lay = make_surf(botm_orig[lay],m_nm,m_empty)
        top_orig_lay = make_surf(botm_orig[lay-1],m_nm,m_empty)
        ind_inlay =np.logical_and(m_empty.dis.botm.array>=botm_orig_lay,m_empty.dis.botm.array<top_orig_lay)
    layer_mapping[lay,:,:,:] = ind_inlay
    
    
    
layer_mapping_ind = np.zeros((nlay,nrow,ncol),dtype=int)
for lay in range(7):
    if lay==0:
        val=-50
    if lay==6:
        val=50
    else:
        val=lay
    layer_mapping_ind+=layer_mapping[lay].astype(int)*val
    
layer_mapping_ind[layer_mapping_ind<=0]= 0
layer_mapping_ind[layer_mapping_ind>=6]=6

# %%
hk_nm = m_nm.lpf.hk.array
x_nm = m_nm.modelgrid.xcellcenters
y_nm = m_nm.modelgrid.ycellcenters
z_nm = m_nm.modelgrid.zcellcenters
x_m = m_empty.modelgrid.xcellcenters
y_m = m_empty.modelgrid.ycellcenters
z_m = m_empty.modelgrid.zcellcenters

hk_new = griddata(points=(np.tile(x_nm,(m_nm.dis.nlay,1,1)).flatten(),np.tile(y_nm,(m_nm.dis.nlay,1,1)).flatten(),z_nm.flatten()),
               values=hk_nm.flatten(),
               xi=(x_m,y_m,z_m),method='nearest')
hk_new[np.isnan(hk_new)] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])
hk_new[hk_new>10000] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])



#Hydraulic conductivity field
hkSand = 1e2 #horizontal hydraulic conductivity m/day
hkClay = hkSand*.001

# heterogenous = 0 #0:homogenous,1:variogram,2:MPS

# hk = np.ones((nlay,nrow,ncol), dtype=np.float)
# hk[np.isin(layer_mapping_ind,(0,1,3,5))] = hkSand
# hk[np.isin(layer_mapping_ind,(2,4,6))] = hkClay


hk = hk_new 
#plt.figure(),plt.imshow((hk[:,0,:])),plt.colorbar(),plt.title('Sill:{}'.format(sill)),plt.show()

#Set Hydraulic properties
sy = 0.15
ss = 1e-5
por = 0.3
vka = .5 # = vk/hk
al = 20 #longitudinal dispersivity (m) from Walther et al. 2017
dmcoef = 2e-9 #m2/day

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)
#denseslp = 0 #trick for testing constant density

# %%
plt.figure()


mps180 = np.load(MPSdir.joinpath('reals','mps180_16node.npy'))
mps180[mps180==1]=hkSand
mps180[mps180==0]=hkClay
hk2 = hk.copy()
hk2[np.where(layer_mapping_ind==3)] = mps180[np.where(layer_mapping_ind==3)] 
plt.imshow(np.ma.masked_where(hk2>600,hk2)[:,0,:])
plt.gca().set_aspect(10)

# %% [markdown]
# ### BCs

# %%
def find_ocean(m,layer_mapping_ind):
    ocean_line = []

    for lay in range(m.dis.nlay):
        for row in range(m.dis.nrow):
            thislay = (lay,row,np.where(layer_mapping_ind[lay,row,:]!=0)[0][0])
            ocean_line.append(thislay)
            if lay==m.dis.nlay-1:
                pass
            else:
                nextlay = (lay+1,row,np.where(layer_mapping_ind[lay+1,row,:]!=0)[0][0])
                for col in np.arange(thislay[2],nextlay[2],-1):
                    ocean_line.append((lay,row,col))
    ocean_line = np.array(ocean_line).T


    ocean_grid = np.zeros((nlay,nrow,ncol),dtype=np.bool)
    ocean_grid[tuple(ocean_line)]=True
    ocean_grid[m.modelgrid.zvertices[1:,:,:]>ocean_elev]=False
    return ocean_line,ocean_grid

ocean_line,ocean_grid = find_ocean(m,layer_mapping_ind)

# %% [markdown]
# ### Extend inland ghb time

# %%
bhead_mean_180=  []
bhead_mean_400 = []
bhead_180400 = []

for per in range(m_nm.nper):
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==3)
    bhead_mean_180.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==5)
    bhead_mean_400.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==4)
    bhead_180400.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    
    
    
yr = np.arange(2012,2019)
dlvl_180 = np.array([-2,-1,-8,-7,0,11,.5,2])*.3048
dlvl_400 = np.array([-1,-1,-7,-4,1,8,-.5,2])*.3048

bhead_future_180 = [np.array(bhead_mean_180)[-12:]+dlvl for dlvl in dlvl_180]
bhead_future_180 = np.array(bhead_future_180).flatten()
bhead_future_180 = np.r_[bhead_future_180,np.tile(bhead_future_180[-12:],20)]
bhead_future_180 = bhead_future_180[5::6]

bhead_future_400 = [np.array(bhead_mean_400)[-12:]+dlvl for dlvl in dlvl_400]
bhead_future_400 = np.array(bhead_future_400).flatten()
bhead_future_400 = np.r_[bhead_future_400,np.tile(bhead_future_400[-12:],20)]
bhead_future_400 = bhead_future_400[5::6]


inland_inds_180 = np.argwhere(layer_mapping_ind==3)
inland_inds_180 = inland_inds_180[inland_inds_180[:,2]==344,:]

inland_inds_180400 = np.argwhere(layer_mapping_ind==4)
inland_inds_180400 = inland_inds_180400[inland_inds_180400[:,2]==344,:]

inland_inds_400 = np.argwhere(layer_mapping_ind==5)
inland_inds_400 = inland_inds_400[inland_inds_400[:,2]==344,:]

# %%
itype = flopy.mt3d.Mt3dSsm.itype_dict()
cond = 1000.

ghb_data_ocean = {}
ssm_data_ocean = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = []
    ssm_per = []
    #Ocean boundary
    for v in np.argwhere(ocean_grid):
        ghb_per.append([v[0],
                       v[1],
                       v[2],
                       #ocean_hf[3][j],
                        ocean_elev,
                       cond])
        #SSM: {stress_period: [lay,row,col,concentration,itype]}
        ssm_per.append([v[0],
                       v[1],
                       v[2],
                       Csalt,
                       itype['GHB']])
    ghb_data_ocean[kper]=ghb_per
    ssm_data_ocean[kper]=ssm_per

    
    

inds = []
nix_ghb = []
for v in ocean_line.T:
# v = ocean_line.T[-1]
    if 6 in layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]:
        inds.append((v[0],v[1],int(np.argwhere(layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]==6)[0]) + v[2]))
        nix_ghb.append(v)

        
for kper in range(nper):
    for v in nix_ghb:
        try:
            ghb_data_ocean[kper].remove([v[0],v[1],v[2],0,cond])
        except:
            continue
# Out:
# kper 0
# kper 50

# %%
def find_nearest_kper_nm(kper_m):
    t_m = (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365
    t_vec_nm = (start_nm_yr + start_nm_mo/12) + np.cumsum(m_nm.dis.perlen.array)/365    
    if t_m > t_vec_nm.max() + m_nm.dis.perlen.array[0]/365:
        return np.nan
    else:
        return np.argmin(abs(t_vec_nm-t_m))
def date_from_per(kper_m):
    return  (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365

layers_to_map=np.arange(3,6)
z_m_vert = m_empty.modelgrid.zvertices
ghb_data_nm = m_nm.ghb.stress_period_data.data


ghb_data_inland = {}
ssm_data_inland = {}

for kper_m in range(nper):
    kper_nm = find_nearest_kper_nm(kper_m)
    if np.isnan(kper_nm):
        kper_m_max=kper_m
        break
#     if kper>0:
#         continue
    if kper_m%10==0:
        print('date: {}; kper_m {}; nkper_nm {}'.format(
            date_from_per(kper_m),kper_m,kper_nm))

    ghb_per=[]
    ssm_per = []
    for i,row in enumerate(rows):
        for lay in layers_to_map:
            
            
            lay_map = np.argwhere(np.logical_and(layer_mapping_ind[:,i,344]==lay,z_m_vert[1:,i,344]<bhead)).flatten()
            for new_lay in lay_map:
                ghb_per.append((new_lay,i,344,bhead,cond))
                ssm_per.append([new_lay,i,344,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per

    
### Now add what isnt covered by the nmgwm
for iper,kper_m in enumerate(range(kper_m_max,nper)):
    ghb_per=[]
    ssm_per = []
    if kper_m%10==0:
        print('date: {}; kper_m {}; nkper_nm {}'.format(
            date_from_per(kper_m),kper_m,kper_nm))
    bhead180 = bhead_future_180[iper]
    bhead400 = bhead_future_400[iper]
        
    for ind in inland_inds_180:
        k,i,j = ind
        ghb_per.append((k,i,j,bhead180,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
        
    for ind in inland_inds_180400: #Same bhead as 180-FA
        k,i,j = ind
        ghb_per.append((k,i,j,bhead180,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
        
    for ind in inland_inds_400:
        k,i,j = ind
        ghb_per.append((k,i,j,bhead400,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per
# Out:
# date: 1990.25; kper_m 0; nkper_nm 124
# date: 1995.25; kper_m 10; nkper_nm 184
# date: 2000.25; kper_m 20; nkper_nm 244
# date: 2005.25; kper_m 30; nkper_nm 304
# date: 2010.25; kper_m 40; nkper_nm 364
# date: 2015.25; kper_m 50; nkper_nm nan
# date: 2020.25; kper_m 60; nkper_nm nan
# date: 2025.25; kper_m 70; nkper_nm nan
# date: 2030.25; kper_m 80; nkper_nm nan

# %% [markdown]
# ### Add in the recharge

# %%
layer =1
f_exp = GISdir.joinpath("sva_edge_2","SVA_edge").as_posix()
int_sva = g.intersect(f_exp,'line',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_sva.nodenumber] = 1
asva = a.reshape((nlay,nrow,ncol),order='C')

# %%
flopy.modflow.mfchd.ModflowChd()

# %%
chd_data =  {}
ssm_rech = {}
for kper_m in range(nper):
    chd_per=[]
    ssm_per = []
    if kper_m%10==0:
        print('date: {}; kper_m {}'.format(
            date_from_per(kper_m),kper_m))
    bhead  = 2
    
    for ind in np.argwhere(asva):
        k,i,j = ind
        chd_per.append([k,i,j-1,bhead,bhead]) #[lay, row, col, shead, ehead]
        ssm_per.append([k,i,j-1,Cfresh,itype['CHD']])
        chd_per.append([k,i,j-2,bhead,bhead]) #[lay, row, col, shead, ehead]
        ssm_per.append([k,i,j-2,Cfresh,itype['CHD']])

    
    chd_data[kper_m] = chd_per
    ssm_rech[kper_m] = ssm_per
#     ghb_data_inland[kper_m]=ghb_per
#     ssm_data_inland[kper_m]=ssm_per
# Out:
# date: 1990.25; kper_m 0
# date: 1995.25; kper_m 10
# date: 2000.25; kper_m 20
# date: 2005.25; kper_m 30
# date: 2010.25; kper_m 40
# date: 2015.25; kper_m 50
# date: 2020.25; kper_m 60
# date: 2025.25; kper_m 70
# date: 2030.25; kper_m 80

# %% [markdown]
# ### Merge GHB data, SSM data

# %%
ghb_data = {}
ssm_data = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = ghb_data_ocean[kper]
    ssm_per = ssm_data_ocean[kper]
    for vg,vs in zip(ghb_data_inland[kper],ssm_data_inland[kper]):
        ghb_per.append(vg)
        ssm_per.append(vs)
    
    #Add recharge data
    for vc in chd_data[kper]:
        ssm_per.append(vc)
    ghb_data[kper] = ghb_per
    ssm_data[kper] = ssm_per
# Out:
# kper 0
# kper 50

# %% [markdown]
#  ### STRT

# %%
yr_ind = np.argmin(np.abs([v - (start_m_yr + start_m_mo/12) for v in yrs_180]))
a_180 = intersect_swi_contour(aquifer=180,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_180]))
a_180 = np.tile(a_180[nonzerolay],(nlay,1,1))


yr_ind = np.argmin(np.abs([v - (start_m_yr + start_m_mo/12) for v in yrs_400]))
a_400 = intersect_swi_contour(aquifer=400,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_400]))
a_400 = np.tile(a_400[nonzerolay],(nlay,1,1))
salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)


salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_180[lay,row,:])
        if len(inds_nonzero)>0:
            salt_180[lay,row,:int(inds_nonzero[0])]=True
            
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_400[lay,row,:])
        if len(inds_nonzero)>0:
            salt_400[lay,row,:int(inds_nonzero[0])]=True

# %%
ind_ocean = np.where(ocean_grid[0,0,:])[0].max()
# ocean_lay = np.where((layer_mapping_ind[:,row,:]==3).any(axis=1))[0].min() # highest layer within the 180-FA containing the ocean
# ind_ocean = np.where(ocean_grid[ocean_lay,0,:])[0].max() #farthest inland point for the given row corresponding to the ocean



saltgrad_180 = np.zeros_like(a_180)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_180[lay,row,:])
        if len(ind_max)>0:
#             ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_180[lay,row,:ind_ocean]=Csalt
            saltgrad_180[lay,row,ind_ocean:ind_max.max()]=tds_vec
saltgrad_400 = np.zeros_like(a_400)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_400[lay,row,:])
        if len(ind_max)>0:
#             ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_400[lay,row,:ind_ocean]=Csalt
            saltgrad_400[lay,row,ind_ocean:ind_max.max()]=tds_vec

# %%
# ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
# for v in np.argwhere(ocean_grid):
#     ibound[v[0],v[1],:v[2]]=0
# head_inland =-10.
head_inland = min([np.min(np.array(v)[:,3]) for k,v in ghb_data_inland.items()])
ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
for lay in range(nlay):
    for row in range(nrow):
        col = int(np.argwhere(ocean_grid[lay,row,:])[0])
        ibound[lay,row,:col]=0
for v in inds:
    ibound[v[0],v[1],:v[2]]=0
# ibound[z_m_vert[1:,:,:]>0]=0
ibound[m_empty.modelgrid.zcellcenters > -1] = 0 
ibound[layer_mapping_ind==6]=0


strt = np.ones_like(ibound)*head_inland

# sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
# sconc[ocean_grid] = Csalt
# # interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
# for v in ocean_line.T:
#     sconc[v[0],v[1],:v[2]]=Csalt
# sconc[np.logical_or(salt_180,salt_400)] = Csalt
    
sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
sconc[np.isin(layer_mapping_ind,(3,1))] = saltgrad_180[np.isin(layer_mapping_ind,(3,1))]
sconc[np.isin(layer_mapping_ind,(5,1))] = saltgrad_400[np.isin(layer_mapping_ind,(5,1))]
# sconc[layer_mapping_ind==1] =Csalt
sconc[ocean_grid] = Csalt
# interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
for v in ocean_line.T:
    sconc[v[0],v[1],:v[2]]=Csalt
    
    
    

icbund = np.ones((nlay, nrow, ncol), dtype=np.int)
icbund[np.where(ibound==-1)] = -1

# %%
plt.imshow(sconc[:,0,:])
plt.gca().set_aspect(10)
plt.colorbar()

# %%
# In[9]:

#Output control
oc_data = {}
for kper in range(nper):
    oc_data[(kper,0)] = ['save head','save budget']


# In[10]:

#Create instances in flopy
bas = flopy.modflow.ModflowBas(m, ibound=ibound, strt=strt)
ghb = flopy.modflow.ModflowGhb(m, stress_period_data=ghb_data)
chd = flopy.modflow.ModflowChd(m, stress_period_data=chd_data)
# rch = flopy.modflow.ModflowRch(m, rech=rech_data)
# wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)
# riv = flopy.modflow.ModflowRiv(m, stress_period_data=riv_data)
# Add LPF package to the MODFLOW model
ipakcb = 53
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb,laytyp=0,laywet=0,
                              ss=ss,sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data=oc_data,
                             compact=True)

#Create the basic MT3DMS model structure
timprs = np.cumsum(m.DIS.perlen.array)
btn = flopy.mt3d.Mt3dBtn(m,
                         laycon=lpf.laytyp, htop=henry_top,
                         dz=dis.thickness.get_value(), prsity=por, icbund=icbund,
                         sconc=sconc, nprs=1,timprs=timprs)
# adv = flopy.mt3d.Mt3dAdv(m, mixelm=-1 )
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0,nadvfd=0 )

dsp = flopy.mt3d.Mt3dDsp(m, al=al, dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=50, mxiter=1, isolve=3, cclose=1e-4)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data,mxss=len(ssm_data[0])*nper)

#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0,
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# WARNING: unit 13 of package BAS6 already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfbas.ModflowBas'> <class 'flopy.modflow.mfbas.ModflowBas'>
# replacing existing Package...
# WARNING: unit 23 of package GHB already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfghb.ModflowGhb'> <class 'flopy.modflow.mfghb.ModflowGhb'>
# replacing existing Package...
# adding Package:  CHD
# WARNING: unit 15 of package LPF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mflpf.ModflowLpf'> <class 'flopy.modflow.mflpf.ModflowLpf'>
# replacing existing Package...
# WARNING: unit 27 of package PCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfpcg.ModflowPcg'> <class 'flopy.modflow.mfpcg.ModflowPcg'>
# replacing existing Package...
# WARNING: unit 14 of package OC already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfoc.ModflowOc'> <class 'flopy.modflow.mfoc.ModflowOc'>
# replacing existing Package...
# WARNING: unit 31 of package BTN already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtbtn.Mt3dBtn'> <class 'flopy.mt3d.mtbtn.Mt3dBtn'>
# replacing existing Package...
# WARNING: unit 32 of package ADV already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtadv.Mt3dAdv'> <class 'flopy.mt3d.mtadv.Mt3dAdv'>
# replacing existing Package...
# WARNING: unit 33 of package DSP already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtdsp.Mt3dDsp'> <class 'flopy.mt3d.mtdsp.Mt3dDsp'>
# replacing existing Package...
# WARNING: unit 35 of package GCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtgcg.Mt3dGcg'> <class 'flopy.mt3d.mtgcg.Mt3dGcg'>
# replacing existing Package...
#    explicit cevt in file
# WARNING: unit 34 of package SSM already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtssm.Mt3dSsm'> <class 'flopy.mt3d.mtssm.Mt3dSsm'>
# replacing existing Package...
# WARNING: unit 37 of package VDF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.seawat.swtvdf.SeawatVdf'> <class 'flopy.seawat.swtvdf.SeawatVdf'>
# replacing existing Package...

# %%
from matplotlib import cm

slicetype='Row'
slicenum= -1

# First step is to set up the plot
fig = plt.figure(figsize=(9, 3))
ax = fig.add_subplot(1, 1, 1)

# Next we create an instance of the PlotCrossSection class
xsect = flopy.plot.PlotCrossSection(model=m, line={slicetype: slicenum},geographic_coords=True)
# xsect.plot_ibound()
xsect.plot_grid(linewidth=.1)
# Then we can use the plot_grid() method to draw the grid
# The return value for this function is a matplotlib LineCollection object,
# which could be manipulated (or used) later if necessary.
# linecollection = xsect.plot_grid()
# patches = xsect.plot_ibound()
# csa = xsect.plot_array(layer_mapping_ind)
# cmap = cm.get_cmap('tab10', lay_m.shape[0])
# csa = xsect.plot_array(conc,cmap='jet')
# c = plt.colorbar(csa)
# wel = xsect.plot_bc("CHD")
# wel = xsect.plot_ibound()
wel = xsect.plot_bc("GHB")
wel = xsect.plot_bc("CHD")

# csa = xsect.plot_array(m.bas6.ibound,cmap='jet')




t = ax.set_title('{slicetype} {slicenum} Cross-Section'.format(slicetype=slicetype,slicenum=slicenum))
plt.ylabel('Elevation (m)')
plt.ylim((-200,100))
plt.xlabel('X UTM (m)')
# c.set_label('log10(hk)')
# plt.savefig(figdir.joinpath('seawat_fine_xsection_layers_{slicetype}{slicenum}.png'.format(slicetype=slicetype,slicenum=slicenum)),dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'X UTM (m)')

# %%
# %%time
writeyn= True
runyn = True
#Write input
if writeyn:
    m.write_input()

# Try to delete the output files, to prevent accidental use of older files

f_delete = [os.path.join(model_ws,'MT3D.CNF'),
            os.path.join(model_ws,'MT3D001.MAS'),
            os.path.join(model_ws, 'MT3D001.UCN'),
            os.path.join(model_ws, modelname + '.hds'),
            os.path.join(model_ws, modelname + '.cbc')]

for f in f_delete:
    try:
        os.remove(f)
    except:
        pass

#%%
import datetime

if runyn:
    #Run model
    ts = make_timestamp()
    v = m.run_model(silent=False, report=True)
    for idx in range(-3, 0):
        print(v[1][idx])
else:
    print('Not running model!')
# In[14]:
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  GHB
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  VDF
#    Package:  CHD
#
# FloPy is using the following  executable to run the model: /usr/local/bin/MODFLOW/swtv4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: NM.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/07/01 10:07:34
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    182.50
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2932E-02  [K,I,J]    2    1  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4370E-08  [K,I,J]    3    1  160
#  Transport Step:    2   Step Size:  0.3796     Total Elapsed Time:  0.38058
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1972      [K,I,J]    2    1  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1368E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3363E-05  [K,I,J]    3    2  160
#  Transport Step:    3   Step Size:   2.233     Total Elapsed Time:   2.6136
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3038      [K,I,J]    2    1  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1561E-01  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1941E-03  [K,I,J]    3    2  160
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4351E-04  [K,I,J]    3    2  160
#  Transport Step:    4   Step Size:   3.461     Total Elapsed Time:   6.0750
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2010      [K,I,J]    2    2  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3906E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1382E-03  [K,I,J]    3    1  160
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8060E-05  [K,I,J]    3    1  160
#  Transport Step:    5   Step Size:   4.166     Total Elapsed Time:   10.241
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1258      [K,I,J]    2    2  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2544E-02  [K,I,J]    2    2  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1046E-03  [K,I,J]    3    1  160
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1300E-04  [K,I,J]    3    1  160
#  Transport Step:    6   Step Size:   4.427     Total Elapsed Time:   14.668
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8526E-01  [K,I,J]    2    2  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4132E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4090E-04  [K,I,J]    3    1  159
#  Transport Step:    7   Step Size:   4.502     Total Elapsed Time:   19.170
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7157E-01  [K,I,J]    2    2  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4222E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3375E-04  [K,I,J]    2    2  161
#  Transport Step:    8   Step Size:   4.520     Total Elapsed Time:   23.690
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5960E-01  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3821E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2873E-04  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.524     Total Elapsed Time:   28.214
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4949E-01  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3308E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2614E-04  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.524     Total Elapsed Time:   32.737
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4361E-01  [K,I,J]    2    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2812E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2472E-04  [K,I,J]    3    1  160
#  Transport Step:   11   Step Size:   4.523     Total Elapsed Time:   37.260
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3977E-01  [K,I,J]    2    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2375E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2454E-04  [K,I,J]    3    1  160
#  Transport Step:   12   Step Size:   4.522     Total Elapsed Time:   41.782
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3592E-01  [K,I,J]    2    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2006E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2328E-04  [K,I,J]    3    1  160
#  Transport Step:   13   Step Size:   4.521     Total Elapsed Time:   46.303
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3225E-01  [K,I,J]    2    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1701E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2154E-04  [K,I,J]    3    1  160
#  Transport Step:   14   Step Size:   4.521     Total Elapsed Time:   50.824
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3001E-01  [K,I,J]    2    2  159
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1450E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1962E-04  [K,I,J]    3    1  160
#  Transport Step:   15   Step Size:   4.521     Total Elapsed Time:   55.346
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2874E-01  [K,I,J]    2    2  159
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1246E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1809E-04  [K,I,J]    3    2  160
#  Transport Step:   16   Step Size:   4.521     Total Elapsed Time:   59.867
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2732E-01  [K,I,J]    2    2  159
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1078E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1715E-04  [K,I,J]    3    2  160
#  Transport Step:   17   Step Size:   4.521     Total Elapsed Time:   64.388
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2583E-01  [K,I,J]    2    2  159
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9393E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1615E-04  [K,I,J]    3    2  160
#  Transport Step:   18   Step Size:   4.522     Total Elapsed Time:   68.910
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2431E-01  [K,I,J]    2    2  159
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8248E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1514E-04  [K,I,J]    3    2  160
#  Transport Step:   19   Step Size:   4.522     Total Elapsed Time:   73.432
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2295E-01  [K,I,J]    2    1  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7294E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1414E-04  [K,I,J]    3    2  160
#  Transport Step:   20   Step Size:   4.523     Total Elapsed Time:   77.955
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2175E-01  [K,I,J]    2    1  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6494E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1317E-04  [K,I,J]    3    2  160
#  Transport Step:   21   Step Size:   4.523     Total Elapsed Time:   82.478
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2114E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5817E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1225E-04  [K,I,J]    3    2  160
#  Transport Step:   22   Step Size:   4.524     Total Elapsed Time:   87.002
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2053E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5240E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1138E-04  [K,I,J]    3    2  160
#  Transport Step:   23   Step Size:   4.525     Total Elapsed Time:   91.527
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1987E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4745E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1057E-04  [K,I,J]    3    2  160
#  Transport Step:   24   Step Size:   4.525     Total Elapsed Time:   96.052
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1917E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4318E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9821E-05  [K,I,J]    3    2  160
#  Transport Step:   25   Step Size:   4.526     Total Elapsed Time:   100.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1845E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3945E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9124E-05  [K,I,J]    3    2  160
#  Transport Step:   26   Step Size:   4.527     Total Elapsed Time:   105.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1771E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3619E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8480E-05  [K,I,J]    3    2  160
#  Transport Step:   27   Step Size:   4.527     Total Elapsed Time:   109.63
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1698E-01  [K,I,J]    2    2  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3332E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7886E-05  [K,I,J]    3    2  160
#  Transport Step:   28   Step Size:   4.528     Total Elapsed Time:   114.16
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1628E-01  [K,I,J]    2    1  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3077E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7339E-05  [K,I,J]    3    2  160
#  Transport Step:   29   Step Size:   4.529     Total Elapsed Time:   118.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1584E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2850E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6836E-05  [K,I,J]    3    2  160
#  Transport Step:   30   Step Size:   4.529     Total Elapsed Time:   123.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1555E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2646E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6373E-05  [K,I,J]    3    2  160
#  Transport Step:   31   Step Size:   4.530     Total Elapsed Time:   127.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1523E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2463E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5947E-05  [K,I,J]    3    2  160
#  Transport Step:   32   Step Size:   4.531     Total Elapsed Time:   132.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1489E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2298E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5647E-05  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.532     Total Elapsed Time:   136.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1453E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2149E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5377E-05  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.532     Total Elapsed Time:   141.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1416E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2013E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5125E-05  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.533     Total Elapsed Time:   145.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1378E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1889E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4889E-05  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.534     Total Elapsed Time:   150.41
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1339E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1775E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4668E-05  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.534     Total Elapsed Time:   154.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1300E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1672E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4460E-05  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.535     Total Elapsed Time:   159.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1261E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1576E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4265E-05  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.536     Total Elapsed Time:   164.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1222E-01  [K,I,J]    2    2  157
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1488E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4082E-05  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.536     Total Elapsed Time:   168.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1200E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1407E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3909E-05  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:   4.537     Total Elapsed Time:   173.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1185E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1332E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3746E-05  [K,I,J]    3    1  161
#  Transport Step:   42   Step Size:   4.538     Total Elapsed Time:   177.63
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1168E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1263E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3592E-05  [K,I,J]    3    1  161
#  Transport Step:   43   Step Size:   4.538     Total Elapsed Time:   182.16
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1150E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1199E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3446E-05  [K,I,J]    3    1  161
#  Transport Step:   44   Step Size:  0.3365     Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8515E-03  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1326E-06  [K,I,J]    3    1  161
#  Transport Step:   45   Step Size:  2.8422E-14 Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   182.50     TO    365.00
#
#  Transport Step:    1   Step Size:   4.540     Total Elapsed Time:   187.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1952E-01  [K,I,J]    9    1  158
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1184E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3322E-05  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.540     Total Elapsed Time:   191.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1111E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1065E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3168E-05  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.542     Total Elapsed Time:   196.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1090E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1013E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3053E-05  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.541     Total Elapsed Time:   200.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1068E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9684E-04  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.542     Total Elapsed Time:   205.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1047E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9280E-04  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.542     Total Elapsed Time:   209.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1024E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8894E-04  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.543     Total Elapsed Time:   214.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1002E-01  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8526E-04  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.543     Total Elapsed Time:   218.83
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9877E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8174E-04  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.544     Total Elapsed Time:   223.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9793E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7840E-04  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.544     Total Elapsed Time:   227.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9701E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7523E-04  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.545     Total Elapsed Time:   232.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9600E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7222E-04  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.545     Total Elapsed Time:   237.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9491E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6938E-04  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.546     Total Elapsed Time:   241.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9377E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6668E-04  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.546     Total Elapsed Time:   246.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9256E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6412E-04  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.547     Total Elapsed Time:   250.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9131E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6171E-04  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.547     Total Elapsed Time:   255.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9001E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5941E-04  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.548     Total Elapsed Time:   259.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8867E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5724E-04  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.548     Total Elapsed Time:   264.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8730E-02  [K,I,J]    2    2  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5518E-04  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.549     Total Elapsed Time:   268.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8617E-02  [K,I,J]    2    1  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5322E-04  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.549     Total Elapsed Time:   273.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8531E-02  [K,I,J]    2    1  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5136E-04  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.549     Total Elapsed Time:   277.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8448E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4959E-04  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.550     Total Elapsed Time:   282.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8392E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4791E-04  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.550     Total Elapsed Time:   287.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8330E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4631E-04  [K,I,J]    3    1  161
#  Transport Step:   24   Step Size:   4.551     Total Elapsed Time:   291.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8263E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4478E-04  [K,I,J]    3    1  161
#  Transport Step:   25   Step Size:   4.551     Total Elapsed Time:   296.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8191E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4332E-04  [K,I,J]    3    1  161
#  Transport Step:   26   Step Size:   4.551     Total Elapsed Time:   300.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8116E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4192E-04  [K,I,J]    3    1  161
#  Transport Step:   27   Step Size:   4.552     Total Elapsed Time:   305.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8036E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4059E-04  [K,I,J]    3    1  161
#  Transport Step:   28   Step Size:   4.552     Total Elapsed Time:   309.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7953E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3931E-04  [K,I,J]    3    1  161
#  Transport Step:   29   Step Size:   4.552     Total Elapsed Time:   314.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7867E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3808E-04  [K,I,J]    3    1  161
#  Transport Step:   30   Step Size:   4.553     Total Elapsed Time:   318.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7778E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3691E-04  [K,I,J]    3    1  161
#  Transport Step:   31   Step Size:   4.553     Total Elapsed Time:   323.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7687E-02  [K,I,J]    2    2  154
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3577E-04  [K,I,J]    3    1  161
#  Transport Step:   32   Step Size:   4.553     Total Elapsed Time:   328.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7612E-02  [K,I,J]    2    1  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3468E-04  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.554     Total Elapsed Time:   332.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7557E-02  [K,I,J]    2    1  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3363E-04  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.554     Total Elapsed Time:   337.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7499E-02  [K,I,J]    2    1  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3261E-04  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.554     Total Elapsed Time:   341.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7449E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3163E-04  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.555     Total Elapsed Time:   346.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7407E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3066E-04  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.555     Total Elapsed Time:   350.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7362E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2972E-04  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.555     Total Elapsed Time:   355.33
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7314E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2880E-04  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.555     Total Elapsed Time:   359.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7262E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2789E-04  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.556     Total Elapsed Time:   364.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7208E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2698E-04  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:  0.5563     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8803E-03  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1341E-06  [K,I,J]    3    1  161
#  Transport Step:   42   Step Size:  5.6843E-14 Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   365.00     TO    547.50
#
#  Transport Step:    1   Step Size:   4.556     Total Elapsed Time:   369.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7055E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2755E-04  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.559     Total Elapsed Time:   374.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7095E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2481E-04  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.558     Total Elapsed Time:   378.67
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7028E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2357E-04  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.557     Total Elapsed Time:   383.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6961E-02  [K,I,J]    2    2  153
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2247E-04  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.557     Total Elapsed Time:   387.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6941E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2119E-04  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.557     Total Elapsed Time:   392.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6930E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1935E-04  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.557     Total Elapsed Time:   396.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6916E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1587E-04  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.557     Total Elapsed Time:   401.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6898E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1018E-05  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.558     Total Elapsed Time:   406.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6877E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3762E-04  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.558     Total Elapsed Time:   410.57
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6853E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3147E-04  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.558     Total Elapsed Time:   415.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6826E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2770E-04  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.558     Total Elapsed Time:   419.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6796E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2552E-04  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.558     Total Elapsed Time:   424.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6764E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2407E-04  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.559     Total Elapsed Time:   428.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6729E-02  [K,I,J]    1    1  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2297E-04  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.559     Total Elapsed Time:   433.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6703E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2208E-04  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.559     Total Elapsed Time:   437.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6676E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2131E-04  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.559     Total Elapsed Time:   442.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6646E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2064E-04  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.559     Total Elapsed Time:   447.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6613E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2002E-04  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.559     Total Elapsed Time:   451.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6578E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1946E-04  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.560     Total Elapsed Time:   456.16
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6541E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1893E-04  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.560     Total Elapsed Time:   460.72
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6502E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1844E-04  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.560     Total Elapsed Time:   465.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6460E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1798E-04  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.560     Total Elapsed Time:   469.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6416E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1754E-04  [K,I,J]    3    1  161
#  Transport Step:   24   Step Size:   4.560     Total Elapsed Time:   474.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6371E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1711E-04  [K,I,J]    3    1  161
#  Transport Step:   25   Step Size:   4.560     Total Elapsed Time:   478.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6324E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1671E-04  [K,I,J]    3    1  161
#  Transport Step:   26   Step Size:   4.560     Total Elapsed Time:   483.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6275E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1633E-04  [K,I,J]    3    1  161
#  Transport Step:   27   Step Size:   4.560     Total Elapsed Time:   488.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6224E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1596E-04  [K,I,J]    3    1  161
#  Transport Step:   28   Step Size:   4.561     Total Elapsed Time:   492.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6172E-02  [K,I,J]    1    2  152
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1560E-04  [K,I,J]    3    1  161
#  Transport Step:   29   Step Size:   4.561     Total Elapsed Time:   497.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6133E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1526E-04  [K,I,J]    3    1  161
#  Transport Step:   30   Step Size:   4.561     Total Elapsed Time:   501.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6097E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1493E-04  [K,I,J]    3    1  161
#  Transport Step:   31   Step Size:   4.561     Total Elapsed Time:   506.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6059E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1461E-04  [K,I,J]    3    1  161
#  Transport Step:   32   Step Size:   4.561     Total Elapsed Time:   510.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6020E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1430E-04  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.561     Total Elapsed Time:   515.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5980E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1400E-04  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.561     Total Elapsed Time:   520.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5938E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1371E-04  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.561     Total Elapsed Time:   524.57
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5894E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1343E-04  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.561     Total Elapsed Time:   529.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5850E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1315E-04  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.561     Total Elapsed Time:   533.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5804E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1289E-04  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.561     Total Elapsed Time:   538.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5757E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1263E-04  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.562     Total Elapsed Time:   542.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5709E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1238E-04  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.562     Total Elapsed Time:   547.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5660E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1213E-04  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:  0.1232     Total Elapsed Time:   547.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1531E-03  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7333E-09  [K,I,J]    3    1  161
#  Transport Step:   42   Step Size:  1.1369E-13 Total Elapsed Time:   547.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   547.50     TO    730.00
#
#  Transport Step:    1   Step Size:   4.562     Total Elapsed Time:   552.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5512E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1232E-04  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.564     Total Elapsed Time:   556.63
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5570E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1157E-04  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.563     Total Elapsed Time:   561.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5515E-02  [K,I,J]    1    2  151
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1126E-04  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.562     Total Elapsed Time:   565.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5478E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1107E-04  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.562     Total Elapsed Time:   570.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5450E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1090E-04  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.562     Total Elapsed Time:   574.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5421E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1072E-04  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.562     Total Elapsed Time:   579.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5390E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1055E-04  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.562     Total Elapsed Time:   584.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5359E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1037E-04  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.562     Total Elapsed Time:   588.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5327E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1019E-04  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.562     Total Elapsed Time:   593.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5294E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1001E-04  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.562     Total Elapsed Time:   597.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5260E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9830E-05  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.562     Total Elapsed Time:   602.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5225E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9654E-05  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.562     Total Elapsed Time:   606.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5189E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9480E-05  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.562     Total Elapsed Time:   611.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5153E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9310E-05  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.563     Total Elapsed Time:   615.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5116E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9143E-05  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.563     Total Elapsed Time:   620.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5078E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8980E-05  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.563     Total Elapsed Time:   625.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5040E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8820E-05  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.563     Total Elapsed Time:   629.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5001E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8663E-05  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.563     Total Elapsed Time:   634.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4962E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8510E-05  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.563     Total Elapsed Time:   638.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4923E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8360E-05  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.563     Total Elapsed Time:   643.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4883E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8214E-05  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.563     Total Elapsed Time:   647.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4843E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8070E-05  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.563     Total Elapsed Time:   652.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4802E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7931E-05  [K,I,J]    3    1  161
#  Transport Step:   24   Step Size:   4.563     Total Elapsed Time:   657.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4761E-02  [K,I,J]    1    2  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7794E-05  [K,I,J]    3    1  161
#  Transport Step:   25   Step Size:   4.563     Total Elapsed Time:   661.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4740E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7660E-05  [K,I,J]    3    1  161
#  Transport Step:   26   Step Size:   4.563     Total Elapsed Time:   666.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4721E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7529E-05  [K,I,J]    3    1  161
#  Transport Step:   27   Step Size:   4.563     Total Elapsed Time:   670.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4701E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7401E-05  [K,I,J]    3    1  161
#  Transport Step:   28   Step Size:   4.563     Total Elapsed Time:   675.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4680E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-05  [K,I,J]    3    1  161
#  Transport Step:   29   Step Size:   4.563     Total Elapsed Time:   679.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4658E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7153E-05  [K,I,J]    3    1  161
#  Transport Step:   30   Step Size:   4.563     Total Elapsed Time:   684.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4636E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7033E-05  [K,I,J]    3    1  161
#  Transport Step:   31   Step Size:   4.563     Total Elapsed Time:   688.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4613E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6916E-05  [K,I,J]    3    1  161
#  Transport Step:   32   Step Size:   4.563     Total Elapsed Time:   693.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4590E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6801E-05  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.563     Total Elapsed Time:   698.07
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4566E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6689E-05  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.563     Total Elapsed Time:   702.63
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4541E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6579E-05  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.563     Total Elapsed Time:   707.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4516E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6471E-05  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.563     Total Elapsed Time:   711.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4490E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6365E-05  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.563     Total Elapsed Time:   716.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4464E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6262E-05  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.563     Total Elapsed Time:   720.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4438E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6161E-05  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.563     Total Elapsed Time:   725.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4411E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6062E-05  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.555     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4376E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5941E-05  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:  1.1369E-13 Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   730.00     TO    912.50
#
#  Transport Step:    1   Step Size:   4.563     Total Elapsed Time:   734.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4293E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5966E-05  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.564     Total Elapsed Time:   739.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4330E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5813E-05  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.564     Total Elapsed Time:   743.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4302E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5664E-05  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.563     Total Elapsed Time:   748.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4272E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5566E-05  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.563     Total Elapsed Time:   752.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4243E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5483E-05  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.563     Total Elapsed Time:   757.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4214E-02  [K,I,J]    1    2  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5403E-05  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.563     Total Elapsed Time:   761.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4185E-02  [K,I,J]    3    1  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5324E-05  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.563     Total Elapsed Time:   766.51
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4176E-02  [K,I,J]    3    1  150
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5246E-05  [K,I,J]    3    1  161
# ...
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5896E-06  [K,I,J]   12    2  341
#  Transport Step:   15   Step Size:   4.751     Total Elapsed Time:   14485.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2151E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5624E-06  [K,I,J]   12    2  341
#  Transport Step:   16   Step Size:   4.751     Total Elapsed Time:   14490.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2128E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5365E-06  [K,I,J]   12    2  341
#  Transport Step:   17   Step Size:   4.751     Total Elapsed Time:   14494.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2105E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5120E-06  [K,I,J]   12    2  341
#  Transport Step:   18   Step Size:   4.751     Total Elapsed Time:   14499.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2083E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4890E-06  [K,I,J]   12    2  341
#  Transport Step:   19   Step Size:   4.751     Total Elapsed Time:   14504.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2061E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4673E-06  [K,I,J]   12    2  341
#  Transport Step:   20   Step Size:   4.751     Total Elapsed Time:   14509.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2039E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4470E-06  [K,I,J]   12    2  341
#  Transport Step:   21   Step Size:   4.751     Total Elapsed Time:   14513.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2018E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4279E-06  [K,I,J]   12    2  341
#  Transport Step:   22   Step Size:   4.751     Total Elapsed Time:   14518.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1997E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4100E-06  [K,I,J]   12    2  341
#  Transport Step:   23   Step Size:   4.751     Total Elapsed Time:   14523.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1976E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3932E-06  [K,I,J]   12    2  341
#  Transport Step:   24   Step Size:   4.751     Total Elapsed Time:   14528.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1956E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3774E-06  [K,I,J]   12    2  341
#  Transport Step:   25   Step Size:   4.751     Total Elapsed Time:   14532.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1936E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3626E-06  [K,I,J]   12    2  341
#  Transport Step:   26   Step Size:   4.751     Total Elapsed Time:   14537.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1916E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3487E-06  [K,I,J]   12    2  341
#  Transport Step:   27   Step Size:   4.751     Total Elapsed Time:   14542.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1897E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3356E-06  [K,I,J]   12    2  341
#  Transport Step:   28   Step Size:   4.751     Total Elapsed Time:   14547.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1877E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3232E-06  [K,I,J]   12    2  341
#  Transport Step:   29   Step Size:   4.751     Total Elapsed Time:   14551.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1858E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3116E-06  [K,I,J]   12    2  341
#  Transport Step:   30   Step Size:   4.751     Total Elapsed Time:   14556.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1840E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3006E-06  [K,I,J]   12    2  341
#  Transport Step:   31   Step Size:   4.751     Total Elapsed Time:   14561.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1821E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2902E-06  [K,I,J]   12    2  341
#  Transport Step:   32   Step Size:   4.751     Total Elapsed Time:   14566.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1803E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2804E-06  [K,I,J]   12    2  341
#  Transport Step:   33   Step Size:   4.751     Total Elapsed Time:   14570.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1785E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2710E-06  [K,I,J]   12    2  341
#  Transport Step:   34   Step Size:   4.751     Total Elapsed Time:   14575.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1767E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2622E-06  [K,I,J]   12    2  341
#  Transport Step:   35   Step Size:   4.751     Total Elapsed Time:   14580.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1749E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2538E-06  [K,I,J]   12    2  341
#  Transport Step:   36   Step Size:   4.751     Total Elapsed Time:   14585.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1732E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2459E-06  [K,I,J]   12    2  341
#  Transport Step:   37   Step Size:   4.751     Total Elapsed Time:   14589.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1715E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2383E-06  [K,I,J]   12    2  341
#  Transport Step:   38   Step Size:   4.751     Total Elapsed Time:   14594.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1698E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2311E-06  [K,I,J]   12    2  341
#  Transport Step:   39   Step Size:   4.751     Total Elapsed Time:   14599.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1681E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2243E-06  [K,I,J]   12    2  341
#  Transport Step:   40   Step Size:   1.161     Total Elapsed Time:   14600.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4111E-03  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4771E-08  [K,I,J]   19    2  342
#  Transport Step:   41   Step Size:  1.8190E-12 Total Elapsed Time:   14600.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.   81
#
#   STRESS PERIOD   81 TIME STEP    1 FROM TIME =   14600.     TO    14783.
#
#  Transport Step:    1   Step Size:   4.751     Total Elapsed Time:   14605.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1524E-02  [K,I,J]   11    2  340
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1635E-05  [K,I,J]   12    2  339
#  Transport Step:    2   Step Size:   4.853     Total Elapsed Time:   14610.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1787E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1962E-06  [K,I,J]   19    1  345
#  Transport Step:    3   Step Size:   4.910     Total Elapsed Time:   14615.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2635E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2699E-06  [K,I,J]   19    2  344
#  Transport Step:    4   Step Size:   4.932     Total Elapsed Time:   14619.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2710E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2800E-06  [K,I,J]   19    2  344
#  Transport Step:    5   Step Size:   4.938     Total Elapsed Time:   14624.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2693E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2524E-06  [K,I,J]   19    2  344
#  Transport Step:    6   Step Size:   4.940     Total Elapsed Time:   14629.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2660E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2198E-06  [K,I,J]   19    2  344
#  Transport Step:    7   Step Size:   4.941     Total Elapsed Time:   14634.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2623E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1902E-06  [K,I,J]   19    2  344
#  Transport Step:    8   Step Size:   4.941     Total Elapsed Time:   14639.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2586E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1647E-06  [K,I,J]   19    2  344
#  Transport Step:    9   Step Size:   4.941     Total Elapsed Time:   14644.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2549E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1431E-06  [K,I,J]   19    2  344
#  Transport Step:   10   Step Size:   4.941     Total Elapsed Time:   14649.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2512E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1326E-06  [K,I,J]    4    1  147
#  Transport Step:   11   Step Size:   4.941     Total Elapsed Time:   14654.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2475E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1319E-06  [K,I,J]    4    1  147
#  Transport Step:   12   Step Size:   4.941     Total Elapsed Time:   14659.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2439E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1312E-06  [K,I,J]    4    1  147
#  Transport Step:   13   Step Size:   4.941     Total Elapsed Time:   14664.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2403E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1303E-06  [K,I,J]    4    1  147
#  Transport Step:   14   Step Size:   4.941     Total Elapsed Time:   14669.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2367E-02  [K,I,J]    5    1  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1294E-06  [K,I,J]    4    1  147
#  Transport Step:   15   Step Size:   4.941     Total Elapsed Time:   14674.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2332E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1285E-06  [K,I,J]    4    1  147
#  Transport Step:   16   Step Size:   4.941     Total Elapsed Time:   14679.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2297E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1274E-06  [K,I,J]    4    1  147
#  Transport Step:   17   Step Size:   4.941     Total Elapsed Time:   14684.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2263E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1264E-06  [K,I,J]    4    1  147
#  Transport Step:   18   Step Size:   4.941     Total Elapsed Time:   14689.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2229E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1252E-06  [K,I,J]    4    1  147
#  Transport Step:   19   Step Size:   4.941     Total Elapsed Time:   14694.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2196E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1241E-06  [K,I,J]    4    1  147
#  Transport Step:   20   Step Size:   4.941     Total Elapsed Time:   14698.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2162E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1228E-06  [K,I,J]    4    1  147
#  Transport Step:   21   Step Size:   4.941     Total Elapsed Time:   14703.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2130E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1216E-06  [K,I,J]    4    1  147
#  Transport Step:   22   Step Size:   4.941     Total Elapsed Time:   14708.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2097E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1203E-06  [K,I,J]    4    1  147
#  Transport Step:   23   Step Size:   4.941     Total Elapsed Time:   14713.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2065E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1190E-06  [K,I,J]    4    1  147
#  Transport Step:   24   Step Size:   4.941     Total Elapsed Time:   14718.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2033E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1176E-06  [K,I,J]    4    1  147
#  Transport Step:   25   Step Size:   4.941     Total Elapsed Time:   14723.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2002E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1163E-06  [K,I,J]    4    1  147
#  Transport Step:   26   Step Size:   4.941     Total Elapsed Time:   14728.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1971E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1149E-06  [K,I,J]    4    1  147
#  Transport Step:   27   Step Size:   4.941     Total Elapsed Time:   14733.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1941E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1135E-06  [K,I,J]    4    1  147
#  Transport Step:   28   Step Size:   4.941     Total Elapsed Time:   14738.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1911E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1120E-06  [K,I,J]    4    1  147
#  Transport Step:   29   Step Size:   4.941     Total Elapsed Time:   14743.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1881E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1106E-06  [K,I,J]    4    1  147
#  Transport Step:   30   Step Size:   4.941     Total Elapsed Time:   14748.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1851E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1091E-06  [K,I,J]    4    1  147
#  Transport Step:   31   Step Size:   4.941     Total Elapsed Time:   14753.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1822E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1077E-06  [K,I,J]    4    1  147
#  Transport Step:   32   Step Size:   4.941     Total Elapsed Time:   14758.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1794E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1062E-06  [K,I,J]    4    1  147
#  Transport Step:   33   Step Size:   4.941     Total Elapsed Time:   14763.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1765E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1047E-06  [K,I,J]    4    1  147
#  Transport Step:   34   Step Size:   4.941     Total Elapsed Time:   14768.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1738E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1033E-06  [K,I,J]    4    1  147
#  Transport Step:   35   Step Size:   4.941     Total Elapsed Time:   14773.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1710E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1018E-06  [K,I,J]    4    1  147
#  Transport Step:   36   Step Size:   4.940     Total Elapsed Time:   14778.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1683E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1003E-06  [K,I,J]    4    1  147
#  Transport Step:   37   Step Size:   4.458     Total Elapsed Time:   14782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1496E-02  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7337E-07  [K,I,J]    4    1  147
#  Transport Step:   38   Step Size:  0.5000     Total Elapsed Time:   14783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1674E-03  [K,I,J]    5    2  146
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1119E-09  [K,I,J]    4    1  147
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2020/07/01 10:10:37
#  Elapsed run time:  3 Minutes,  3.566 Seconds
#
#  Normal termination of SEAWAT
#  Elapsed run time:  3 Minutes,  3.566 Seconds
#
#  Normal termination of SEAWAT
# CPU times: user 6.69 s, sys: 1.56 s, total: 8.25 s
# Wall time: 3min 5s

# %% [markdown]
# ### Post processing

# %%
fname = model_ws.joinpath('MT3D001.UCN').as_posix()
anyvals= []
ucnobj = flopy.utils.binaryfile.UcnFile(fname,verbose=False)
# if kstpkper==None:
kstpkpers = ucnobj.get_kstpkper()
for kstpkper in kstpkpers:
    conc = ucnobj.get_data(kstpkper=kstpkper)
    anyvals.append(np.logical_and(conc < 100., conc>0.).any())
print(anyvals)

conc = ucnobj.get_data(kstpkper=kstpkpers[-1])
conc[conc > 100]=np.nan
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
from matplotlib import cm

slicetype='Row'
slicenum= -1

# First step is to set up the plot
fig = plt.figure(figsize=(9, 3))
ax = fig.add_subplot(1, 1, 1)

# Next we create an instance of the PlotCrossSection class
xsect = flopy.plot.PlotCrossSection(model=m, line={slicetype: slicenum},geographic_coords=True)
# xsect.plot_ibound()
xsect.plot_grid(linewidth=.1)
# Then we can use the plot_grid() method to draw the grid
# The return value for this function is a matplotlib LineCollection object,
# which could be manipulated (or used) later if necessary.
# linecollection = xsect.plot_grid()
# patches = xsect.plot_ibound()
# csa = xsect.plot_array(layer_mapping_ind)
# cmap = cm.get_cmap('tab10', lay_m.shape[0])
csa = xsect.plot_array(conc,cmap='jet')
c = plt.colorbar(csa)
# wel = xsect.plot_bc("CHD")
# wel = xsect.plot_bc("GHB")



t = ax.set_title('{slicetype} {slicenum} Cross-Section'.format(slicetype=slicetype,slicenum=slicenum))
plt.ylabel('Elevation (m)')
plt.ylim((-200,100))
plt.xlabel('X UTM (m)')
# c.set_label('log10(hk)')
# plt.savefig(figdir.joinpath('seawat_fine_xsection_layers_{slicetype}{slicenum}.png'.format(slicetype=slicetype,slicenum=slicenum)),dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'X UTM (m)')
