# %%
import flopy
import os
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

if sys.platform.lower()=='linux':
    datadir = Path('/scratch/users/ianpg/SWIlarge/data')
    workdir = Path('/scratch/users/ianpg/SWIlarge/work')
    MPSdir = datadir.joinpath('lith/sgems/MPS')
    GISdir = datadir.joinpath('GIS')
    import mplleaflet
elif sys.platform.lower()=='darwin':
    datadir = Path('../data')
    workdir = Path('../work')
    MPSdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/lith/sgems/MPS')
    GISdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/GIS')

nmgwmdir_empty = datadir.joinpath('nmgwmdir_empty') #<-- removed everything but DIS
nmgwmdir_cal = datadir.joinpath('Calibrated_small') #<-- removed RCH, WEL, GLO, LST from the NAM file to load much faster
figdir = workdir.joinpath('figs')
outputdir = workdir.joinpath('output')

import config
from set_rc import *

import pandas as pd
import shapefile as sf #in case you dont have it, form anaconda prompt: pip install pyshp
from flopy.utils.gridgen import Gridgen
from flopy.utils.reference import SpatialReference
from  pyproj import Proj

p = Proj("epsg:26910")
xll=595855
yll = 4059438
rotation = -13.5
# Out:
# flopy is installed in /Users/ianpg/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy
# system: darwin

# %%
#%% Useful functions
def load_obj(dirname,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'rb') as f:
        return pickle.load(f)

def save_obj(dirname,obj,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

#Create new MC_file
def create_MC_file():
    import datetime
    ts = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
    MC_dir = Path(os.path.join(m.model_ws, 'MC_expt_' + ts))
    if not MC_dir.exists():
        MC_dir.mkdir()
    m.MC_file = MC_dir.joinpath('expt.txt')
    with m.MC_file.open('w') as wf:
        wf.close
    print(m.MC_file)
    return

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

#make a line across the grid
def get_line(start, end,allrows=1,nrow=None):
    """Bresenham's Line Algorithm
    Produces a list of tuples from start and end

    >>> points1 = get_line((0, 0), (3, 4))
    >>> points2 = get_line((3, 4), (0, 0))
    >>> assert(set(points1) == set(points2))
    >>> print points1
    [(0, 0), (1, 1), (1, 2), (2, 3), (3, 4)]
    >>> print points2
    [(3, 4), (2, 3), (1, 2), (1, 1), (0, 0)]
    """
    # Setup initial conditions
    x1, y1 = start
    x2, y2 = end
    dx = x2 - x1
    dy = y2 - y1

    # Determine how steep the line is
    is_steep = abs(dy) > abs(dx)

    # Rotate line
    if is_steep:
        x1, y1 = y1, x1
        x2, y2 = y2, x2

    # Swap start and end points if necessary and store swap state
    swapped = False
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
        swapped = True

    # Recalculate differentials
    dx = x2 - x1
    dy = y2 - y1

    # Calculate error
    error = int(dx / 2.0)
    ystep = 1 if y1 < y2 else -1

    # Iterate over bounding box generating points between start and end
    y = y1
    points = []
    for x in range(x1, x2 + 1):
        if allrows==1:
            if nrow is None:
                nrow = m.nrow
            for row in range(nrow):
                coord = (y, row, x) if is_steep else (x, row, y)
                points.append(coord)
        else:
            coord = (y, x) if is_steep else (x, y)
            points.append(coord)
        error -= abs(dy)
        if error < 0:
            y += ystep
            error += dx

    # Reverse the list if the coordinates were swapped
    if swapped:
        points.reverse()
    return points


#make all cells=0 above the line from get_line()
#Calculate freshwater head based on column of saltwater above each node (rho*g*z)
def shade_above(nlay,nrow,ncol,point_list,third_dim=1):
    import numpy as np
    grd = np.ones((nlay,nrow,ncol),dtype='int')
    ocean_hf = []
    if len(point_list)==0:
        return grd,ocean_hf
    for (lay,row,col) in point_list:
        grd[lay,:,col] = -1 #assign ocean ibound to -1
        grd[:lay,:,col] = 0 #assign cells above ocean to 0
        hf = densefresh/densesalt*ocean_elev - (densesalt - densefresh)/densefresh*(henry_botm[lay] +.5*delv)
        for irow in range(nrow):
            ocean_hf.append((int(lay),int(irow),int(col),hf))
    ocean_hf = tuple(np.array(ocean_hf).T)
    ocean_hf = (ocean_hf[0].astype('int'),
                ocean_hf[1].astype('int'),
                ocean_hf[2].astype('int'),
                ocean_hf[3])
    return grd,ocean_hf

def get_ocean_right_edge(m,ocean_line_tuple,startlay=None,col=None):
    import numpy as np
    point_list = []
    if col is None:
        col = m.ncol-1
    #If there is no vertical side boundary, return bottom-right corner node
    if len(ocean_line_tuple)==0:
        if startlay is None:
            startlay = 0
    elif max(ocean_line_tuple[0])==m.nlay:
        startlay = m.nlay
    elif max(ocean_line_tuple[0])<m.nlay:
        startlay = max(ocean_line_tuple[0])
    for lay in range(startlay,m.nlay):
        for row in range(m.nrow):
            point_list.append((lay,row,col))
    point_list = tuple(np.array(point_list).T)
    return point_list

def add_pumping_wells(wel_data,ssm_data,n_wells,flx,rowcol,kper):
    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    new_weldata = wel_data
    new_ssmdata = ssm_data
    wel_cells = []
    for k in range(n_wells):
        row,col = rowcol[k]
        for i in range(nper):
            if i in kper:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,-flx[k]*delv_weight[j]])
                    wel_cells.append((j,row,col))
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
            else:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,0])
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
                    wel_cells.append((j,row,col))
                continue
    wel_cells = tuple(np.array(list(set(wel_cells))).T)
    return new_weldata, new_ssmdata,wel_cells

#Add recharge if desired
def make_rech_array(low=1e-2,high=1e0):
    import scipy.stats as sts
    llow,lhigh = np.log10((low,high))
    rech = np.exp(sts.uniform.rvs(size=1,loc=llow,scale=lhigh-llow)[0])
    return rech/(nrow*ncol)

def add_recharge_cells(recharge_generator,const=1,*args):
    if const==1:
        rech_data = recharge_generator(*args)
    else:
        rech_data = {}
        for i in range(nper):
            rech_array = recharge_generator(*args)
        rech_data[i] = rech_array
    return rech_data

def sample_dist(distclass,size,*args):
    smp = distclass.rvs(*args,size=size)
    if size==1:
        smp=smp[-1]
    return smp

def write_sample(fname,varname,distclass,sample):
    fout= open(fname,"a")
    fout.write(varname + ',' + str(type(distclass)) + ',' + str(sample) + '\n')
    fout.close()
    return

def truncate_grf(grid,lith_props,hk_vals,log10trans=True,plotyn=False,saveyn=False):
    grid_cutoffs = []
    for q in np.cumsum(lith_props):
        grid_cutoffs.append(np.quantile(grid,q))

    if plotyn:
        h = plt.hist(grid.flatten())
        for cutoff in grid_cutoffs:
            plt.vlines(cutoff,0,14000)
        plt.show()

    outgrid = np.ones(grid.shape,dtype=np.float32)
    for i,cutoff in reversed(list(enumerate(grid_cutoffs))):
        outgrid[np.where(grid<cutoff)] = hk_vals[i]

    if plotyn:
        f,axs = plt.subplots(2,1,sharex=True)
        axs[0].imshow(grid[:,0,:])
        axs[1].imshow(outgrid[:,0,:])
        if saveyn:
            plt.savefig(m.MC_file.parent.joinpath('Truncated_GRF.png').as_posix(),resolution=300)
    if log10trans:
        return np.power(10,outgrid)
    else:
        return outgrid

def make_timestamp(YMD=True,HM=True):
    import datetime
    if YMD:
        ymd = '%Y%m%d'
    else:
        ymd = ''
    if HM:
        hm = '%H%M'
    else:
        hm = ''
    if YMD and HM:
        sep = '_'
    else:
        sep = ''
    return datetime.datetime.now().strftime('{}{}{}'.format(ymd,sep,hm))

def pec_num(delv,delc,delr,al):
    delL = (delv,delc,delr) #length in the lay,row,col directions
    pec_num = [round(d/al,2) for d in delL]
    for num,point  in zip(pec_num,('lay','row','col')):
        print('Pe = {} in the {} direction'.format(num,point))
    return pec_num

#%%

# %%
# %%time
m_nm= flopy.modflow.Modflow.load('nm_cali.nam',version='mf2k',verbose=False,check=False,model_ws=nmgwmdir_cal.as_posix())
# m = flopy.modflow.Modflow.load(nmgwmdir_uncal.joinpath('C1-12_copy.nam').as_posix(),version='mf2k',verbose=False,check=False,model_ws=outputdir.joinpath('C1').as_posix())
m_nm.exe_name = config.mf2000exe
if not m_nm.DIS.lenuni==2:
    m_nm.DIS.delr *= .3048
    m_nm.DIS.delc *= .3048
    m_nm.DIS.top *= .3048
    m_nm.DIS.botm *= .3048
m_nm.DIS.lenuni = 2
m_nm.DIS.itmuni=4
m_nm.DIS.rotation=-13.5
# m_nm.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_nm.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_nm.DIS.proj4_str = p.srs
m_nm.modelgrid.set_coord_info(xoff=xll, yoff=yll, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
# Out:
# CPU times: user 1min 24s, sys: 1.13 s, total: 1min 25s
# Wall time: 1min 29s

# %%
start_nm_yr = 1979
start_nm_mo = 10
start_nm_str = 'Oct 1979'
end_nm_yr = 2011
end_nm_mo = 9
end_nm_str = 'Sep 2011'
Lt_nm = ( (end_nm_yr + end_nm_mo/12)  - (start_nm_yr + start_nm_mo/12) )     *365
start_nm_datetime='{}/1/{}'.format(start_nm_mo,start_nm_yr)



start_m_yr = 1979
start_m_mo = 10
start_m_str = 'Oct 1979'
# end_m_yr = 2011
# end_m_mo = 9
# end_m_str = 'Sep 2011'
# Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
# start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)


# start_m_yr = 1980
# start_m_mo = 3
# start_m_str = 'Mar 1980'


start_m_yr = 1990
start_m_mo = 3
start_m_str = 'Mar 1990'

end_m_yr = 2030
end_m_mo = 10
end_m_str = 'Sep 2030'
Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)

# %%
rows
# Out:
# array([198, 199])

# %%
#Name model
modelname = 'NM'
model_ws = workdir.joinpath("NM")
#Name model
sw_exe = config.swexe #set the exe path for seawat

#Model discretization
Lz = 150.

# nrow,ncol,nlay,nper = m_nm.nrow_ncol_nlay_nper

# rows = np.arange(100,102)
# rows = np.arange(100,102)
rows = np.arange(m_nm.nrow-102,   m_nm.nrow-100) #NM super reduced

# rows = np.arange(nrow)
# rows = np.arange(m_nm.nrow-159,   m_nm.nrow-132) #SV
# rows = np.arange(m_nm.nrow-114,   m_nm.nrow-74) #NM
# rows = np.arange(m_nm.nrow-114,   m_nm.nrow-95) #NM reduced, tsw included in domain

cols = np.arange(ncol)
nrow =len(rows) 
ncol = len(cols)
nlay=20


henry_top = 2
ocean_elev = 0
delv_first = 4
botm_first = henry_top-delv_first


delv = (Lz-delv_first) / (nlay-1)
delr = m_nm.dis.delr.array[0]
delc = m_nm.dis.delc.array[0]

henry_botm = np.hstack(([botm_first],np.linspace(botm_first-delv,henry_top-Lz,nlay-1)))
delv_vec = np.hstack((delv_first,np.repeat(delv,nlay-1)))
delv_weight = [x/np.sum(delv_vec) for x in delv_vec]


topo_grid = np.load(GISdir.joinpath('topo_grid.npy'))
henry_top = topo_grid[(slice(rows[0],rows[-1]+1),slice(cols[0],cols[-1]+1))]


# beachslope = .05
# ocean_col = [np.floor(ncol-1).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn
# ocean_col = [np.floor(ncol/2).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn

# inland_elev = beachslope*ocean_col[0]*delr
# offshore_elev = -beachslope*(ocean_col[1]-ocean_col[0])*delr


#Period data
# nyrs= 2
# Lt = 365*nyrs #Length of time in days

perlen = list(np.repeat(365/2,int(Lt_m/(365/2))))
nper = len(perlen)
nstp = np.ones_like(perlen,dtype=np.int)

# nstp = m_nm.dis.nstp.array
# perlen = m_nm.dis.perlen.array
# nper = m_nm.nper





steady = [False for x in range(len(perlen))] #Never steady
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1.1
ssm_data = None
verbose = True

print('Model setup: \n'
      'nlay: {}\n'
      'nrow: {}\n'
      'ncol: {}\n'
      'Total cells: {}\n'
      'Total time: {} days\n'
      'nper: {}\n'.format(nlay,nrow,ncol,nlay*nrow*ncol,Lt_m,nper))
# In[4]:

#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws.as_posix(),verbose=verbose)
# SGD.ModelSGD.Seawat2SGD(m)  #convert to subclass ModelSGD
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,
                               start_datetime=start_m_datetime)

xll=595855
yll = 4059438
rotation=-13.5
# p = Proj(proj='utm',zone='10n',ellps='WGS84',units='meters', preserve_units=False)

m.DIS.lenuni = 2
m.DIS.itmuni=4
m.DIS.rotation=-13.5
# m.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m.DIS.proj4_str = p.srs
xll_m,yll_m = m_nm.modelgrid.xvertices[rows[-1]+1,0],m_nm.modelgrid.yvertices[rows[-1]+1,0]


m.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
print(m.modelgrid)


np.save(model_ws.joinpath('rows.npy'),rows)
# Out:
# Model setup:
# nlay: 20
# nrow: 2
# ncol: 345
# Total cells: 13800
# Total time: 14812.916666666639 days
# nper: 81
#
# NM.nam
# adding Package:  DIS
# xll:597278.0829380656; yll:4065365.567034744; rotation:-13.5; proj4_str:+proj=utm +zone=10 +datum=NAD83 +units=m +no_defs; units:undefined; lenuni:0

# %%
m_empty = flopy.modflow.Modflow('m_empty', model_ws=model_ws.joinpath('m_empty').as_posix())

flopy.modflow.ModflowDis(m_empty, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,start_datetime=start_m_datetime)

m_empty.DIS.lenuni = 2
m_empty.DIS.itmuni=4
m_empty.DIS.rotation=-13.5
# m_empty.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_empty.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_empty.DIS.proj4_str = p.srs
m_empty.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')

# %%
# %%time
gridgen_ws = model_ws.joinpath('gridgen')
if not gridgen_ws.exists():
    gridgen_ws.mkdir()
g = Gridgen(m_empty.dis, model_ws=gridgen_ws.as_posix(),exe_name=config.gridgenexe,surface_interpolation='replicate')
g.build(verbose=False)
# Out:
# CPU times: user 891 ms, sys: 131 ms, total: 1.02 s
# Wall time: 3.28 s

# %%
f_swi_180 = GISdir.joinpath("chloride_contours",'SWI_180_lines_noz.shp').as_posix()
swi_180 = sf.Reader(f_swi_180)
yrs_180 = [ int(r[-1]) for r in swi_180.records()]


for yr in yrs_180:
    f_exp = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_180.fields[1:] # skip first deletion field
        for feature in swi_180.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

f_swi_400 = GISdir.joinpath("chloride_contours",'SWI_400_lines_noz.shp').as_posix()
swi_400 = sf.Reader(f_swi_400)
yrs_400 = [ int(r[-1]) for r in swi_400.records()]


for yr in yrs_400:
    f_exp = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_400.fields[1:] # skip first deletion field
        for feature in swi_400.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

# %%
layer =3
yr = yrs_180[-1]
f_shp_180 = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
int_180 = g.intersect(f_shp_180,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_180.nodenumber] = 1
a180 = a.reshape((nlay,nrow,ncol),order='C')


yr = yrs_400[-1]
f_shp_400 = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
int_400 = g.intersect(f_shp_400,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_400.nodenumber] = 1
a400 = a.reshape((nlay,nrow,ncol),order='C')

# %% [raw]
# df_TDS = pd.read_excel(datadir.joinpath('WQ','export_TDS_data.xlsx'))
# TDSij =[]
# for x,y in zip(df_TDS.X_NAD83_UTM10N.values,df_TDS.Y_NAD83_UTM10N.values):
#     try:
#         TDSij.append(m_empty.modelgrid.intersect(x,y))
#     except:
#         TDSij.append((np.nan,np.nan))
# df_TDS = df_TDS.assign(rowi=np.array(TDSij)[:,0])
# df_TDS = df_TDS.assign(colj=np.array(TDSij)[:,1])

# %%
def intersect_swi_contour(aquifer=180,yr_ind=None):
    if aquifer==180:
        yr = yrs_180[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    elif aquifer==400:
        yr = yrs_400[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    else:
        raise('enter either 180 or 400')
    int_obj = g.intersect(f,'polygon',layer=layer)
    a = np.zeros((g.nodes), dtype=np.int)
    a[int_obj.nodenumber] = 1
    return a.reshape((nlay,nrow,ncol),order='C')


from scipy.interpolate import interp2d,RectBivariateSpline,NearestNDInterpolator,griddata
def make_surf(grid_old,m_old,m_new,method='nearest'):
    points = np.stack((m_old.modelgrid.xcellcenters.flatten(),m_old.modelgrid.ycellcenters.flatten())).T
    values = grid_old.flatten()
    grid_x=  m_new.modelgrid.xcellcenters
    grid_y=  m_new.modelgrid.ycellcenters
    return griddata(points, values, (grid_x, grid_y), method=method)

# %%
botm_orig= m_nm.DIS.botm.array[:6]
layer_mapping = np.zeros((7,nlay,nrow,ncol),dtype=bool)
for lay in range(7):
    if lay==0:
        ind_inlay = np.zeros((nlay,nrow,ncol),dtype=np.bool)
        ind_inlay[0,:,:] = True
    elif lay==6:
#         botm_orig_lay = interp_surf2newgrid(botm_orig[lay-1])
        botm_orig_lay = make_surf(botm_orig[-1],m_nm,m_empty)
        ind_inlay = m_empty.dis.botm.array<botm_orig_lay
    else:
        botm_orig_lay = make_surf(botm_orig[lay],m_nm,m_empty)
        top_orig_lay = make_surf(botm_orig[lay-1],m_nm,m_empty)
        ind_inlay =np.logical_and(m_empty.dis.botm.array>=botm_orig_lay,m_empty.dis.botm.array<top_orig_lay)
    layer_mapping[lay,:,:,:] = ind_inlay
    
    
    
layer_mapping_ind = np.zeros((nlay,nrow,ncol),dtype=int)
for lay in range(7):
    if lay==0:
        val=-50
    if lay==6:
        val=50
    else:
        val=lay
    layer_mapping_ind+=layer_mapping[lay].astype(int)*val
    
layer_mapping_ind[layer_mapping_ind<=0]= 0
layer_mapping_ind[layer_mapping_ind>=6]=6

# %%
hk_nm = m_nm.lpf.hk.array
x_nm = m_nm.modelgrid.xcellcenters
y_nm = m_nm.modelgrid.ycellcenters
z_nm = m_nm.modelgrid.zcellcenters
x_m = m_empty.modelgrid.xcellcenters
y_m = m_empty.modelgrid.ycellcenters
z_m = m_empty.modelgrid.zcellcenters

hk_new = griddata(points=(np.tile(x_nm,(m_nm.dis.nlay,1,1)).flatten(),np.tile(y_nm,(m_nm.dis.nlay,1,1)).flatten(),z_nm.flatten()),
               values=hk_nm.flatten(),
               xi=(x_m,y_m,z_m),method='nearest')


hk_new[np.isnan(hk_new)] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])
hk_new[hk_new>10000] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])



hk_new[layer_mapping_ind==4]=hkClay*.01

#Hydraulic conductivity field
hkSand = 1e2 #horizontal hydraulic conductivity m/day
hkClay = hkSand*.001

# heterogenous = 0 #0:homogenous,1:variogram,2:MPS

# hk = np.ones((nlay,nrow,ncol), dtype=np.float)
# hk[np.isin(layer_mapping_ind,(0,1,3,5))] = hkSand
# hk[np.isin(layer_mapping_ind,(2,4,6))] = hkClay


hk = hk_new 
#plt.figure(),plt.imshow((hk[:,0,:])),plt.colorbar(),plt.title('Sill:{}'.format(sill)),plt.show()

#Set Hydraulic properties
sy = 0.15
ss = 1e-5
por = 0.3
vka = .5 # = vk/hk
al = 20 #longitudinal dispersivity (m) from Walther et al. 2017
dmcoef = 2e-9 #m2/day

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)
#denseslp = 0 #trick for testing constant density

# %%
mps180 = np.load(MPSdir.joinpath('reals','mps180_16node.npy')).astype(np.float)
mps180[mps180==1]=hkSand
mps180[mps180==0]=hkClay

# %%
layer_mapping_ind.shape
# Out:
# (20, 2, 345)

# %%
mps180.shape
# Out:
# (20, 300, 345)

# %%
hk = np.ones_like(ibound,dtype=np.float64)
mps180 = np.load(MPSdir.joinpath('reals','mps180_16node.npy')).astype(np.float)
mps180[mps180==1]=hkSand
mps180[mps180==0]=hkClay
hk[np.where(layer_mapping_ind==0)] = 10000
hk[np.where(layer_mapping_ind==1)] = 100
hk[np.where(layer_mapping_ind==2)] = hkClay*.01
hk[np.where(layer_mapping_ind==3)] = mps180[np.where(layer_mapping_ind==3)]
hk[np.where(layer_mapping_ind==4)] = hkClay*.01
hk[np.where(layer_mapping_ind==5)] = mps180[np.where(layer_mapping_ind==5)]


plt.figure()
plt.imshow(np.log10(hk)[:,0,:],vmin=-2,vmax=3)
plt.gca().set_aspect(10)
plt.colorbar()

# %% [markdown]
# ### BCs

# %%
def find_ocean(m,layer_mapping_ind):
    ocean_line = []

    for lay in range(m.dis.nlay):
        for row in range(m.dis.nrow):
            thislay = (lay,row,np.where(layer_mapping_ind[lay,row,:]!=0)[0][0])
            ocean_line.append(thislay)
            if lay==m.dis.nlay-1:
                pass
            else:
                nextlay = (lay+1,row,np.where(layer_mapping_ind[lay+1,row,:]!=0)[0][0])
                for col in np.arange(thislay[2],nextlay[2],-1):
                    ocean_line.append((lay,row,col))
    ocean_line = np.array(ocean_line).T


    ocean_grid = np.zeros((nlay,nrow,ncol),dtype=np.bool)
    ocean_grid[tuple(ocean_line)]=True
    ocean_grid[m.modelgrid.zvertices[1:,:,:]>ocean_elev]=False
    return ocean_line,ocean_grid

ocean_line,ocean_grid = find_ocean(m,layer_mapping_ind)

# %%
itype = flopy.mt3d.Mt3dSsm.itype_dict()
cond = 1000.

ghb_data_ocean = {}
ssm_data_ocean = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = []
    ssm_per = []
    #Ocean boundary
    for v in np.argwhere(ocean_grid):
        ghb_per.append([v[0],
                       v[1],
                       v[2],
                       #ocean_hf[3][j],
                        ocean_elev,
                       cond])
        #SSM: {stress_period: [lay,row,col,concentration,itype]}
        ssm_per.append([v[0],
                       v[1],
                       v[2],
                       Csalt,
                       itype['GHB']])
    ghb_data_ocean[kper]=ghb_per
    ssm_data_ocean[kper]=ssm_per

    
    
# print(np.where(ibound[tuple(np.array(ghb_data_ocean[0])[:,:3].astype(int).T)]==0))

inds = []
nix_ghb = []
for v in ocean_line.T:
# v = ocean_line.T[-1]
    if 6 in layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]:
        inds.append((v[0],v[1],int(np.argwhere(layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]==6)[0]) + v[2]))
        nix_ghb.append(v)

        
for kper in range(nper):
    for v in nix_ghb:
        try:
            ghb_data_ocean[kper].remove([v[0],v[1],v[2],0,cond])
            ssm_data_ocean[kper].remove([v[0],v[1],v[2],Csalt,itype['GHB']])
        except:
            continue
# Out:
# kper 0
# kper 50

# %% [markdown]
# ### Extend inland ghb time

# %%
bhead_mean_180=  []
bhead_mean_400 = []
bhead_180400 = []

for per in range(m_nm.nper):
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==3)
    bhead_mean_180.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==5)
    bhead_mean_400.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    msk = np.logical_and(m_nm.ghb.stress_period_data[per]['j']==344,
                     m_nm.ghb.stress_period_data[per]['k']==4)
    bhead_180400.append(m_nm.ghb.stress_period_data[per][msk]['bhead'].mean())
    
    
    
    
yr = np.arange(2012,2019)
dlvl_180 = np.array([-2,-1,-8,-7,0,11,.5,2])*.3048
dlvl_400 = np.array([-1,-1,-7,-4,1,8,-.5,2])*.3048

bhead_future_180 = [np.array(bhead_mean_180)[-12:]+dlvl for dlvl in dlvl_180]
bhead_future_180 = np.array(bhead_future_180).flatten()
bhead_future_180 = np.r_[bhead_future_180,np.tile(bhead_future_180[-12:],20)]
bhead_future_180 = bhead_future_180[5::6]

bhead_future_400 = [np.array(bhead_mean_400)[-12:]+dlvl for dlvl in dlvl_400]
bhead_future_400 = np.array(bhead_future_400).flatten()
bhead_future_400 = np.r_[bhead_future_400,np.tile(bhead_future_400[-12:],20)]
bhead_future_400 = bhead_future_400[5::6]


inland_inds_180 = np.argwhere(layer_mapping_ind==3)
inland_inds_180 = inland_inds_180[inland_inds_180[:,2]==344,:]

inland_inds_180400 = np.argwhere(layer_mapping_ind==4)
inland_inds_180400 = inland_inds_180400[inland_inds_180400[:,2]==344,:]

inland_inds_400 = np.argwhere(layer_mapping_ind==5)
inland_inds_400 = inland_inds_400[inland_inds_400[:,2]==344,:]

# %%
def find_nearest_kper_nm(kper_m):
    t_m = (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365
    t_vec_nm = (start_nm_yr + start_nm_mo/12) + np.cumsum(m_nm.dis.perlen.array)/365    
    if t_m > t_vec_nm.max() + m_nm.dis.perlen.array[0]/365:
        return np.nan
    else:
        return np.argmin(abs(t_vec_nm-t_m))
def date_from_per(kper_m):
    return  (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])/365

layers_to_map=np.arange(3,6)
z_m_vert = m_empty.modelgrid.zvertices
ghb_data_nm = m_nm.ghb.stress_period_data.data


ghb_data_inland = {}
ssm_data_inland = {}

for kper_m in range(nper):
    kper_nm = find_nearest_kper_nm(kper_m)
    if np.isnan(kper_nm):
        kper_m_max=kper_m
        break
#     if kper>0:
#         continue
    if kper_m%10==0:
        print('date: {}; kper_m {}; nkper_nm {}'.format(
            date_from_per(kper_m),kper_m,kper_nm))

    ghb_per=[]
    ssm_per = []
    for i,row in enumerate(rows):
        for lay in layers_to_map:
            msk = np.logical_and(np.logical_and(ghb_data_nm[kper_nm]['i']==i,ghb_data_nm[kper_nm]['j']==344),ghb_data_nm[kper_nm]['k']==lay)
            bhead = ghb_data_nm[kper_nm][msk]['bhead'][0]
            lay_map = np.argwhere(np.logical_and(layer_mapping_ind[:,i,344]==lay,z_m_vert[1:,i,344]<bhead)).flatten()
            for new_lay in lay_map:
                ghb_per.append((new_lay,i,344,bhead,cond))
                ssm_per.append([new_lay,i,344,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per

    
### Now add what isnt covered by the nmgwm
for iper,kper_m in enumerate(range(kper_m_max,nper)):
    ghb_per=[]
    ssm_per = []
    if kper_m%10==0:
        print('date: {}; kper_m {}; nkper_nm {}'.format(
            date_from_per(kper_m),kper_m,kper_nm))
    bhead180 = bhead_future_180[iper]
    bhead400 = bhead_future_400[iper]
        
    for ind in inland_inds_180:
        k,i,j = ind
        ghb_per.append((k,i,j,bhead180,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
        
    for ind in inland_inds_180400: #Same bhead as 180-FA
        k,i,j = ind
        ghb_per.append((k,i,j,bhead180,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
        
    for ind in inland_inds_400:
        k,i,j = ind
        ghb_per.append((k,i,j,bhead400,cond))
        ssm_per.append([k,i,j,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per
# Out:
# date: 1990.25; kper_m 0; nkper_nm 124
# date: 1995.25; kper_m 10; nkper_nm 184
# date: 2000.25; kper_m 20; nkper_nm 244
# date: 2005.25; kper_m 30; nkper_nm 304
# date: 2010.25; kper_m 40; nkper_nm 364
# date: 2015.25; kper_m 50; nkper_nm nan
# date: 2020.25; kper_m 60; nkper_nm nan
# date: 2025.25; kper_m 70; nkper_nm nan
# date: 2030.25; kper_m 80; nkper_nm nan

# %% [markdown]
# ### Adding the recharge

# %%
layer =1
f_exp = GISdir.joinpath("sva_edge_2","SVA_edge").as_posix()
int_sva = g.intersect(f_exp,'line',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_sva.nodenumber] = 1
asva = a.reshape((nlay,nrow,ncol),order='C')

asva_inds = np.argwhere(asva)
# asva_inds_adj = asva_inds.copy()
# asva_inds_adj[:,2]=asva_inds_adj[:,2]-1
# asva_inds = np.r_[asva_inds,asva_inds_adj]
ibound[tuple(asva_inds.T)] = 1

rch_how = 'CHD'

# %% [markdown]
# ### Add in the recharge as CHD

# %%
bhead  = .1
chd_data =  {}
ssm_rech = {}
for kper_m in range(nper):
    chd_per=[]
    ssm_per = []
    if kper_m%10==0:
        print('date: {}; kper_m {}'.format(
            date_from_per(kper_m),kper_m))
    
    for ind in asva_inds:
        k,i,j = ind
        chd_per.append([k,i,j-1,bhead,bhead]) #[lay, row, col, shead, ehead]
        ssm_per.append([k,i,j-1,Cfresh,itype['CHD']])
    
    chd_data[kper_m] = chd_per
    ssm_rech[kper_m] = ssm_per
#     ghb_data_inland[kper_m]=ghb_per
#     ssm_data_inland[kper_m]=ssm_per
# Out:
# date: 1990.25; kper_m 0
# date: 1995.25; kper_m 10
# date: 2000.25; kper_m 20
# date: 2005.25; kper_m 30
# date: 2010.25; kper_m 40
# date: 2015.25; kper_m 50
# date: 2020.25; kper_m 60
# date: 2025.25; kper_m 70
# date: 2030.25; kper_m 80

# %% [markdown]
# ### Add recharge as GHB

# %% [raw]
# bhead  = 1.2
# cond = hkClay * m_empty.dis.delr[0]*m_empty.dis.delc[0]/(m_empty.dis.botm[0].array - m_empty.dis.botm[1].array).mean()
# ghb_data_rech =  {}
# ssm_rech = {}
# for kper_m in range(nper):
#     ghb_per=[]
#     ssm_per = []
#     if kper_m%10==0:
#         print('date: {}; kper_m {}'.format(
#             date_from_per(kper_m),kper_m))
#
#     for ind in asva_inds:
#         k,i,j = ind
#         ghb_per.append([k,i,j-1,bhead,cond]) #[lay, row, col, shead, ehead]
#         ssm_per.append([k,i,j-1,Cfresh,itype['GHB']])
#
#         ghb_data_rech[kper_m] = ghb_per
#         ssm_rech[kper_m] = ssm_per
#     ghb_data_rech[kper_m]=ghb_per
#     ssm_rech[kper_m]=ssm_per

# %% [markdown]
# ### Add recharge as RCH

# %% [raw]
# rech_rate  = .1
# rech_data = np.zeros((m.nrow,m.ncol))
# rech_data[tuple(asva_inds.T)[1:]] = rech_rate

# %% [markdown]
# ### Merge GHB data, SSM data

# %%
ghb_data = {}
ssm_data = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = ghb_data_ocean[kper]
    ssm_per = ssm_data_ocean[kper]
    for vg,vs in zip(ghb_data_inland[kper],ssm_data_inland[kper]):
        ghb_per.append(vg)
        ssm_per.append(vs)
    
    #Add recharge data if coded as CHD/GHB/etc.. data
    try:
        for vc in ssm_rech[kper]:
            ssm_per.append(vc)
    except:
        pass
    
#     for vg in ghb_data_rech[kper]:
#         ghb_per.append(vg)
    
    ghb_data[kper] = ghb_per
    ssm_data[kper] = ssm_per
# Out:
# kper 0
# kper 50

# %% [markdown]
#  ### STRT

# %%
yr_ind = np.argmin(np.abs([v - (start_m_yr + start_m_mo/12) for v in yrs_180]))
a_180 = intersect_swi_contour(aquifer=180,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_180]))
a_180 = np.tile(a_180[nonzerolay],(nlay,1,1))


yr_ind = np.argmin(np.abs([v - (start_m_yr + start_m_mo/12) for v in yrs_400]))
a_400 = intersect_swi_contour(aquifer=400,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_400]))
a_400 = np.tile(a_400[nonzerolay],(nlay,1,1))
salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)


salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_180[lay,row,:])
        if len(inds_nonzero)>0:
            salt_180[lay,row,:int(inds_nonzero[0])]=True
            
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_400[lay,row,:])
        if len(inds_nonzero)>0:
            salt_400[lay,row,:int(inds_nonzero[0])]=True

# %%
ind_ocean = np.where(ocean_grid[0,0,:])[0].max()
# ocean_lay = np.where((layer_mapping_ind[:,row,:]==3).any(axis=1))[0].min() # highest layer within the 180-FA containing the ocean
# ind_ocean = np.where(ocean_grid[ocean_lay,0,:])[0].max() #farthest inland point for the given row corresponding to the ocean



saltgrad_180 = np.zeros_like(a_180)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_180[lay,row,:])
        if len(ind_max)>0:
#             ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_180[lay,row,:ind_ocean]=Csalt
            saltgrad_180[lay,row,ind_ocean:ind_max.max()]=tds_vec
saltgrad_400 = np.zeros_like(a_400)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_400[lay,row,:])
        if len(ind_max)>0:
#             ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_400[lay,row,:ind_ocean]=Csalt
            saltgrad_400[lay,row,ind_ocean:ind_max.max()]=tds_vec

# %%
# ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
# for v in np.argwhere(ocean_grid):
#     ibound[v[0],v[1],:v[2]]=0
# head_inland =-10.
head_inland = min([np.min(np.array(v)[:,3]) for k,v in ghb_data_inland.items()])
ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
for lay in range(nlay):
    for row in range(nrow):
        col = int(np.argwhere(ocean_grid[lay,row,:])[0])
        ibound[lay,row,:col]=0
for v in inds:
    ibound[v[0],v[1],:v[2]]=0
# ibound[z_m_vert[1:,:,:]>0]=0
ibound[m_empty.modelgrid.zcellcenters > -1] = 0 
ibound[layer_mapping_ind==6]=0


strt = np.ones_like(ibound)*head_inland

# sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
# sconc[ocean_grid] = Csalt
# # interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
# for v in ocean_line.T:
#     sconc[v[0],v[1],:v[2]]=Csalt
# sconc[np.logical_or(salt_180,salt_400)] = Csalt
    
sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
sconc[np.isin(layer_mapping_ind,(3,1))] = saltgrad_180[np.isin(layer_mapping_ind,(3,1))]
sconc[np.isin(layer_mapping_ind,(5,1))] = saltgrad_400[np.isin(layer_mapping_ind,(5,1))]
# sconc[layer_mapping_ind==1] =Csalt
sconc[ocean_grid] = Csalt
# interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
for v in ocean_line.T:
    sconc[v[0],v[1],:v[2]]=Csalt
    
    
    

icbund = np.ones((nlay, nrow, ncol), dtype=np.int)
icbund[np.where(ibound==-1)] = -1

# %%
plt.imshow(sconc[:,0,:])
plt.gca().set_aspect(10)
plt.colorbar()

# %%
rch_how is 'RCH'
# Out:
# False

# %%
# In[9]:

#Output control
oc_data = {}
for kper in range(nper):
    oc_data[(kper,0)] = ['save head','save budget']


# In[10]:

#Create instances in flopy
bas = flopy.modflow.ModflowBas(m, ibound=ibound, strt=strt)
ghb = flopy.modflow.ModflowGhb(m, stress_period_data=ghb_data)

if rch_how is 'CHD':
    chd = flopy.modflow.ModflowChd(m, stress_period_data=chd_data)
elif rch_how is 'RCH':
    rch = flopy.modflow.ModflowRch(m,rech=rech_data)

# rch = flopy.modflow.ModflowRch(m, rech=rech_data)
# wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)
# riv = flopy.modflow.ModflowRiv(m, stress_period_data=riv_data)
# Add LPF package to the MODFLOW model
ipakcb = 53
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb,laytyp=0,laywet=0,
                              ss=ss,sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data=oc_data,
                             compact=True)

#Create the basic MT3DMS model structure
timprs = np.cumsum(m.DIS.perlen.array)
btn = flopy.mt3d.Mt3dBtn(m,
                         laycon=lpf.laytyp, htop=henry_top,
                         dz=dis.thickness.get_value(), prsity=por, icbund=icbund,
                         sconc=sconc, nprs=1,timprs=timprs)
# adv = flopy.mt3d.Mt3dAdv(m, mixelm=-1 )
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0,nadvfd=0 )

dsp = flopy.mt3d.Mt3dDsp(m, al=al, dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=50, mxiter=1, isolve=3, cclose=1e-4)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data,mxss=len(ssm_data[0])*nper)

#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0,
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)


for pak in ['RCH','CHD',]:
    if pak is not rch_how:
        try:
            m.remove_package(pak)
        except:
            pass
# Out:
# WARNING: unit 13 of package BAS6 already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfbas.ModflowBas'> <class 'flopy.modflow.mfbas.ModflowBas'>
# replacing existing Package...
# WARNING: unit 23 of package GHB already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfghb.ModflowGhb'> <class 'flopy.modflow.mfghb.ModflowGhb'>
# replacing existing Package...
# WARNING: unit 24 of package CHD already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfchd.ModflowChd'> <class 'flopy.modflow.mfchd.ModflowChd'>
# replacing existing Package...
# WARNING: unit 15 of package LPF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mflpf.ModflowLpf'> <class 'flopy.modflow.mflpf.ModflowLpf'>
# replacing existing Package...
# WARNING: unit 27 of package PCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfpcg.ModflowPcg'> <class 'flopy.modflow.mfpcg.ModflowPcg'>
# replacing existing Package...
# WARNING: unit 14 of package OC already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfoc.ModflowOc'> <class 'flopy.modflow.mfoc.ModflowOc'>
# replacing existing Package...
# WARNING: unit 31 of package BTN already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtbtn.Mt3dBtn'> <class 'flopy.mt3d.mtbtn.Mt3dBtn'>
# replacing existing Package...
# WARNING: unit 32 of package ADV already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtadv.Mt3dAdv'> <class 'flopy.mt3d.mtadv.Mt3dAdv'>
# replacing existing Package...
# WARNING: unit 33 of package DSP already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtdsp.Mt3dDsp'> <class 'flopy.mt3d.mtdsp.Mt3dDsp'>
# replacing existing Package...
# WARNING: unit 35 of package GCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtgcg.Mt3dGcg'> <class 'flopy.mt3d.mtgcg.Mt3dGcg'>
# replacing existing Package...
#    explicit cevt in file
# WARNING: unit 34 of package SSM already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtssm.Mt3dSsm'> <class 'flopy.mt3d.mtssm.Mt3dSsm'>
# replacing existing Package...
# WARNING: unit 37 of package VDF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.seawat.swtvdf.SeawatVdf'> <class 'flopy.seawat.swtvdf.SeawatVdf'>
# replacing existing Package...

# %%
from matplotlib import cm

slicetype='Row'
slicenum= -1

# First step is to set up the plot
fig = plt.figure(figsize=(9, 3))
ax = fig.add_subplot(1, 1, 1)

# Next we create an instance of the PlotCrossSection class
xsect = flopy.plot.PlotCrossSection(model=m, line={slicetype: slicenum},geographic_coords=True)
# xsect.plot_ibound()
xsect.plot_grid(linewidth=.1)
# Then we can use the plot_grid() method to draw the grid
# The return value for this function is a matplotlib LineCollection object,
# which could be manipulated (or used) later if necessary.
# linecollection = xsect.plot_grid()
# patches = xsect.plot_ibound()
# csa = xsect.plot_array(layer_mapping_ind)
# cmap = cm.get_cmap('tab10', lay_m.shape[0])
# csa = xsect.plot_array(conc,cmap='jet')
# c = plt.colorbar(csa)
# wel = xsect.plot_bc("CHD")
wel = xsect.plot_ibound()
wel = xsect.plot_bc("GHB")
# wel = xsect.plot_bc("RCH")

# wel = xsect.plot_bc("CHD")

# csa = xsect.plot_array(m.bas6.ibound,cmap='jet')




t = ax.set_title('{slicetype} {slicenum} Cross-Section'.format(slicetype=slicetype,slicenum=slicenum))
plt.ylabel('Elevation (m)')
plt.ylim((-200,100))
plt.xlabel('X UTM (m)')
# c.set_label('log10(hk)')
# plt.savefig(figdir.joinpath('seawat_fine_xsection_layers_{slicetype}{slicenum}.png'.format(slicetype=slicetype,slicenum=slicenum)),dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'X UTM (m)')

# %%
# %%time
writeyn= True
runyn = True
#Write input
if writeyn:
    m.write_input()

# Try to delete the output files, to prevent accidental use of older files

f_delete = [os.path.join(model_ws,'MT3D.CNF'),
            os.path.join(model_ws,'MT3D001.MAS'),
            os.path.join(model_ws, 'MT3D001.UCN'),
            os.path.join(model_ws, modelname + '.hds'),
            os.path.join(model_ws, modelname + '.cbc')]

for f in f_delete:
    try:
        os.remove(f)
    except:
        pass

#%%
import datetime

if runyn:
    #Run model
    ts = make_timestamp()
    v = m.run_model(silent=False, report=True)
    for idx in range(-3, 0):
        print(v[1][idx])
else:
    print('Not running model!')
# In[14]:
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  GHB
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  VDF
#    Package:  CHD
#
# FloPy is using the following  executable to run the model: /usr/local/bin/MODFLOW/swtv4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: NM.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/07/01 15:11:03
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    182.50
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2904E-02  [K,I,J]    2    1  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3780E-08  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:  0.5434     Total Elapsed Time:  0.54436
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1606      [K,I,J]    2    2  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1200E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1623E-05  [K,I,J]    2    2  161
#  Transport Step:    3   Step Size:   2.713     Total Elapsed Time:   3.2576
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1509      [K,I,J]    2    2  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1812E-02  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9827E-05  [K,I,J]    3    2  162
#  Transport Step:    4   Step Size:   4.551     Total Elapsed Time:   7.8087
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8181E-01  [K,I,J]    2    2  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6476E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9515E-05  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.550     Total Elapsed Time:   12.359
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4287E-01  [K,I,J]    2    1  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1586E-03  [K,I,J]    3    1  161
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1382E-05  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.550     Total Elapsed Time:   16.909
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3195E-01  [K,I,J]   11    2   60
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6573E-04  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.550     Total Elapsed Time:   21.459
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2974E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3758E-04  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.550     Total Elapsed Time:   26.009
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2775E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2571E-04  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.550     Total Elapsed Time:   30.559
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2594E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1921E-04  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.550     Total Elapsed Time:   35.109
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2427E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1655E-04  [K,I,J]    3    2  161
#  Transport Step:   11   Step Size:   4.550     Total Elapsed Time:   39.659
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2274E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1537E-04  [K,I,J]    3    2  161
#  Transport Step:   12   Step Size:   4.550     Total Elapsed Time:   44.209
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2133E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1435E-04  [K,I,J]    3    2  161
#  Transport Step:   13   Step Size:   4.550     Total Elapsed Time:   48.758
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2003E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1340E-04  [K,I,J]    3    2  161
#  Transport Step:   14   Step Size:   4.550     Total Elapsed Time:   53.308
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1884E-01  [K,I,J]   10    2   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1250E-04  [K,I,J]    3    2  161
#  Transport Step:   15   Step Size:   4.550     Total Elapsed Time:   57.858
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1779E-01  [K,I,J]   10    1   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1162E-04  [K,I,J]    3    2  161
#  Transport Step:   16   Step Size:   4.550     Total Elapsed Time:   62.408
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1687E-01  [K,I,J]   10    1   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1077E-04  [K,I,J]    3    2  161
#  Transport Step:   17   Step Size:   4.550     Total Elapsed Time:   66.958
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1602E-01  [K,I,J]   10    1   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9953E-05  [K,I,J]    3    2  161
#  Transport Step:   18   Step Size:   4.550     Total Elapsed Time:   71.508
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1522E-01  [K,I,J]   10    1   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9166E-05  [K,I,J]    3    2  161
#  Transport Step:   19   Step Size:   4.550     Total Elapsed Time:   76.058
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1446E-01  [K,I,J]   10    1   81
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8412E-05  [K,I,J]    3    2  161
#  Transport Step:   20   Step Size:   4.550     Total Elapsed Time:   80.607
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1379E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7693E-05  [K,I,J]    3    2  161
#  Transport Step:   21   Step Size:   4.550     Total Elapsed Time:   85.157
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1321E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7010E-05  [K,I,J]    3    2  161
#  Transport Step:   22   Step Size:   4.550     Total Elapsed Time:   89.707
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1265E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6706E-05  [K,I,J]    3    2  162
#  Transport Step:   23   Step Size:   4.550     Total Elapsed Time:   94.257
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1212E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6909E-05  [K,I,J]    3    2  162
#  Transport Step:   24   Step Size:   4.550     Total Elapsed Time:   98.807
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1162E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7061E-05  [K,I,J]    3    2  162
#  Transport Step:   25   Step Size:   4.550     Total Elapsed Time:   103.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1114E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7170E-05  [K,I,J]    3    2  162
#  Transport Step:   26   Step Size:   4.550     Total Elapsed Time:   107.91
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1068E-01  [K,I,J]   10    1   82
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7243E-05  [K,I,J]    3    2  162
#  Transport Step:   27   Step Size:   4.550     Total Elapsed Time:   112.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1025E-01  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7284E-05  [K,I,J]    3    2  162
#  Transport Step:   28   Step Size:   4.550     Total Elapsed Time:   117.01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9880E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7299E-05  [K,I,J]    3    2  162
#  Transport Step:   29   Step Size:   4.550     Total Elapsed Time:   121.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9524E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7292E-05  [K,I,J]    3    2  162
#  Transport Step:   30   Step Size:   4.550     Total Elapsed Time:   126.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9183E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7265E-05  [K,I,J]    3    2  162
#  Transport Step:   31   Step Size:   4.550     Total Elapsed Time:   130.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8855E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7222E-05  [K,I,J]    3    2  162
#  Transport Step:   32   Step Size:   4.550     Total Elapsed Time:   135.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8541E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7165E-05  [K,I,J]    3    2  162
#  Transport Step:   33   Step Size:   4.550     Total Elapsed Time:   139.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8240E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7097E-05  [K,I,J]    3    2  162
#  Transport Step:   34   Step Size:   4.550     Total Elapsed Time:   144.31
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7950E-02  [K,I,J]   11    1   58
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7019E-05  [K,I,J]    3    2  162
#  Transport Step:   35   Step Size:   4.550     Total Elapsed Time:   148.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7748E-02  [K,I,J]    3    1  164
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6933E-05  [K,I,J]    3    2  162
#  Transport Step:   36   Step Size:   4.550     Total Elapsed Time:   153.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7630E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6841E-05  [K,I,J]    3    2  162
#  Transport Step:   37   Step Size:   4.550     Total Elapsed Time:   157.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7553E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6743E-05  [K,I,J]    3    2  162
#  Transport Step:   38   Step Size:   4.550     Total Elapsed Time:   162.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7471E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6641E-05  [K,I,J]    3    2  162
#  Transport Step:   39   Step Size:   4.550     Total Elapsed Time:   167.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7384E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6535E-05  [K,I,J]    3    2  162
#  Transport Step:   40   Step Size:   4.550     Total Elapsed Time:   171.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7293E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6427E-05  [K,I,J]    3    2  162
#  Transport Step:   41   Step Size:   4.550     Total Elapsed Time:   176.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7197E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6316E-05  [K,I,J]    3    2  162
#  Transport Step:   42   Step Size:   4.550     Total Elapsed Time:   180.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7098E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6205E-05  [K,I,J]    3    2  162
#  Transport Step:   43   Step Size:   1.796     Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2787E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4122E-06  [K,I,J]    3    2  162
#  Transport Step:   44   Step Size:  2.8422E-14 Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   182.50     TO    365.00
#
#  Transport Step:    1   Step Size:   4.550     Total Elapsed Time:   187.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1261E-01  [K,I,J]   19    2  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8133E-05  [K,I,J]    3    2  162
#  Transport Step:    2   Step Size:   4.550     Total Elapsed Time:   191.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7498E-02  [K,I,J]    2    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8014E-05  [K,I,J]    3    2  162
#  Transport Step:    3   Step Size:   4.550     Total Elapsed Time:   196.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7560E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8417E-05  [K,I,J]    3    2  162
#  Transport Step:    4   Step Size:   4.550     Total Elapsed Time:   200.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7538E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8564E-05  [K,I,J]    3    2  162
#  Transport Step:    5   Step Size:   4.550     Total Elapsed Time:   205.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7456E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8529E-05  [K,I,J]    3    2  162
#  Transport Step:    6   Step Size:   4.550     Total Elapsed Time:   209.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7345E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8478E-05  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.550     Total Elapsed Time:   214.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7219E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8392E-05  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.550     Total Elapsed Time:   218.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7087E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8288E-05  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.550     Total Elapsed Time:   223.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6951E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8172E-05  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.550     Total Elapsed Time:   228.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6814E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8053E-05  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.550     Total Elapsed Time:   232.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6678E-02  [K,I,J]    3    1  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7932E-05  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.550     Total Elapsed Time:   237.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6584E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7810E-05  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.550     Total Elapsed Time:   241.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6525E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7688E-05  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.550     Total Elapsed Time:   246.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6464E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7567E-05  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.550     Total Elapsed Time:   250.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6399E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7446E-05  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.550     Total Elapsed Time:   255.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6331E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7325E-05  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.550     Total Elapsed Time:   259.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6262E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7205E-05  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.550     Total Elapsed Time:   264.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6189E-02  [K,I,J]    3    1  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7087E-05  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.550     Total Elapsed Time:   268.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6123E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6969E-05  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.550     Total Elapsed Time:   273.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6055E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6852E-05  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.550     Total Elapsed Time:   278.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5985E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6737E-05  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.550     Total Elapsed Time:   282.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5914E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6623E-05  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.550     Total Elapsed Time:   287.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5841E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6510E-05  [K,I,J]    3    1  161
#  Transport Step:   24   Step Size:   4.550     Total Elapsed Time:   291.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5766E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6399E-05  [K,I,J]    3    1  161
#  Transport Step:   25   Step Size:   4.550     Total Elapsed Time:   296.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5691E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6290E-05  [K,I,J]    3    1  161
#  Transport Step:   26   Step Size:   4.550     Total Elapsed Time:   300.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5615E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6182E-05  [K,I,J]    3    1  161
#  Transport Step:   27   Step Size:   4.550     Total Elapsed Time:   305.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5538E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6075E-05  [K,I,J]    3    1  161
#  Transport Step:   28   Step Size:   4.550     Total Elapsed Time:   309.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5461E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5970E-05  [K,I,J]    3    1  161
#  Transport Step:   29   Step Size:   4.550     Total Elapsed Time:   314.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5383E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5867E-05  [K,I,J]    3    1  161
#  Transport Step:   30   Step Size:   4.550     Total Elapsed Time:   318.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5306E-02  [K,I,J]    2    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5766E-05  [K,I,J]    3    1  161
#  Transport Step:   31   Step Size:   4.550     Total Elapsed Time:   323.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5233E-02  [K,I,J]    3    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5666E-05  [K,I,J]    3    1  161
#  Transport Step:   32   Step Size:   4.550     Total Elapsed Time:   328.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5197E-02  [K,I,J]    3    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5568E-05  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.550     Total Elapsed Time:   332.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5158E-02  [K,I,J]    3    1  167
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5472E-05  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.550     Total Elapsed Time:   337.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5119E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5377E-05  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.550     Total Elapsed Time:   341.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5089E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5284E-05  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.550     Total Elapsed Time:   346.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5058E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5193E-05  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.550     Total Elapsed Time:   350.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5024E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5104E-05  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.550     Total Elapsed Time:   355.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4989E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5016E-05  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.550     Total Elapsed Time:   359.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4952E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4930E-05  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.550     Total Elapsed Time:   364.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4914E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4846E-05  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:  0.5095     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5499E-03  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7561E-08  [K,I,J]    3    1  161
#  Transport Step:   42   Step Size:  5.6843E-14 Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   365.00     TO    547.50
#
#  Transport Step:    1   Step Size:   4.550     Total Elapsed Time:   369.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5226E-02  [K,I,J]    9    2  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5074E-05  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.550     Total Elapsed Time:   374.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4855E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4753E-05  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.550     Total Elapsed Time:   378.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4821E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4701E-05  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.550     Total Elapsed Time:   383.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4782E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4637E-05  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.550     Total Elapsed Time:   387.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4739E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4566E-05  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.550     Total Elapsed Time:   392.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4694E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4493E-05  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.550     Total Elapsed Time:   396.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4648E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4419E-05  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.550     Total Elapsed Time:   401.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4600E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4345E-05  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.550     Total Elapsed Time:   405.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4553E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4273E-05  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.550     Total Elapsed Time:   410.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4504E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4203E-05  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.550     Total Elapsed Time:   415.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4455E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4138E-05  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.550     Total Elapsed Time:   419.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4406E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4074E-05  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.550     Total Elapsed Time:   424.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4356E-02  [K,I,J]    2    1  168
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4011E-05  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.550     Total Elapsed Time:   428.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4326E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3949E-05  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.550     Total Elapsed Time:   433.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4310E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3889E-05  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.550     Total Elapsed Time:   437.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4293E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3829E-05  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.550     Total Elapsed Time:   442.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4274E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3771E-05  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.550     Total Elapsed Time:   446.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4255E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3714E-05  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.550     Total Elapsed Time:   451.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4233E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3657E-05  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.550     Total Elapsed Time:   456.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4211E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3602E-05  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.550     Total Elapsed Time:   460.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4187E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3548E-05  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.550     Total Elapsed Time:   465.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4162E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3495E-05  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.550     Total Elapsed Time:   469.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4137E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3443E-05  [K,I,J]    3    1  161
#  Transport Step:   24   Step Size:   4.550     Total Elapsed Time:   474.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4110E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3392E-05  [K,I,J]    3    1  161
#  Transport Step:   25   Step Size:   4.550     Total Elapsed Time:   478.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4082E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3342E-05  [K,I,J]    3    1  161
#  Transport Step:   26   Step Size:   4.550     Total Elapsed Time:   483.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4054E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3292E-05  [K,I,J]    3    1  161
#  Transport Step:   27   Step Size:   4.550     Total Elapsed Time:   487.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4025E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3244E-05  [K,I,J]    3    1  161
#  Transport Step:   28   Step Size:   4.550     Total Elapsed Time:   492.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3995E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3197E-05  [K,I,J]    3    1  161
#  Transport Step:   29   Step Size:   4.550     Total Elapsed Time:   496.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3964E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3150E-05  [K,I,J]    3    1  161
#  Transport Step:   30   Step Size:   4.550     Total Elapsed Time:   501.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3933E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3105E-05  [K,I,J]    3    1  161
#  Transport Step:   31   Step Size:   4.550     Total Elapsed Time:   506.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3901E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3060E-05  [K,I,J]    3    1  161
#  Transport Step:   32   Step Size:   4.550     Total Elapsed Time:   510.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3869E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3016E-05  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.550     Total Elapsed Time:   515.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3836E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2973E-05  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.550     Total Elapsed Time:   519.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3803E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2931E-05  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.550     Total Elapsed Time:   524.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3769E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2889E-05  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.550     Total Elapsed Time:   528.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3735E-02  [K,I,J]    2    1  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2848E-05  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.550     Total Elapsed Time:   533.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3705E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2808E-05  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.550     Total Elapsed Time:   537.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3694E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2769E-05  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.550     Total Elapsed Time:   542.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3682E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2731E-05  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.550     Total Elapsed Time:   546.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3669E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2693E-05  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:  0.5096     Total Elapsed Time:   547.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4110E-03  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4211E-08  [K,I,J]    3    1  161
#  Transport Step:   42   Step Size:  1.1369E-13 Total Elapsed Time:   547.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   547.50     TO    730.00
#
#  Transport Step:    1   Step Size:   4.550     Total Elapsed Time:   552.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3800E-02  [K,I,J]   17    2  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2943E-05  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.550     Total Elapsed Time:   556.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3855E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3130E-05  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.550     Total Elapsed Time:   561.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3911E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3271E-05  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.550     Total Elapsed Time:   565.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3929E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3321E-05  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.550     Total Elapsed Time:   570.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3927E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3322E-05  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.550     Total Elapsed Time:   574.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3914E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3298E-05  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.550     Total Elapsed Time:   579.35
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3895E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3264E-05  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.550     Total Elapsed Time:   583.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3874E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3225E-05  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.550     Total Elapsed Time:   588.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3851E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3184E-05  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.550     Total Elapsed Time:   593.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3826E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3143E-05  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.550     Total Elapsed Time:   597.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3801E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3102E-05  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.550     Total Elapsed Time:   602.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3775E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3062E-05  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.550     Total Elapsed Time:   606.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3748E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3022E-05  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.550     Total Elapsed Time:   611.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3721E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2983E-05  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.550     Total Elapsed Time:   615.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3693E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2945E-05  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.550     Total Elapsed Time:   620.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3665E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2907E-05  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.550     Total Elapsed Time:   624.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3636E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2870E-05  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.550     Total Elapsed Time:   629.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3607E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2834E-05  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.550     Total Elapsed Time:   633.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3577E-02  [K,I,J]    2    1  170
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2798E-05  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.550     Total Elapsed Time:   638.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3554E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2763E-05  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.550     Total Elapsed Time:   643.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3545E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2728E-05  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.550     Total Elapsed Time:   647.59
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3534E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2694E-05  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.550     Total Elapsed Time:   652.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3522E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2661E-05  [K,I,J]    3    1  161
#  Transport Step:   24   Step Size:   4.550     Total Elapsed Time:   656.69
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3510E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2628E-05  [K,I,J]    3    1  161
#  Transport Step:   25   Step Size:   4.550     Total Elapsed Time:   661.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3497E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2595E-05  [K,I,J]    3    1  161
#  Transport Step:   26   Step Size:   4.550     Total Elapsed Time:   665.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3483E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2563E-05  [K,I,J]    3    1  161
#  Transport Step:   27   Step Size:   4.550     Total Elapsed Time:   670.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3468E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2532E-05  [K,I,J]    3    1  161
#  Transport Step:   28   Step Size:   4.550     Total Elapsed Time:   674.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3452E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2501E-05  [K,I,J]    3    1  161
#  Transport Step:   29   Step Size:   4.550     Total Elapsed Time:   679.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3436E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2471E-05  [K,I,J]    3    1  161
#  Transport Step:   30   Step Size:   4.550     Total Elapsed Time:   683.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3420E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2441E-05  [K,I,J]    3    1  161
#  Transport Step:   31   Step Size:   4.550     Total Elapsed Time:   688.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3402E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2412E-05  [K,I,J]    3    1  161
#  Transport Step:   32   Step Size:   4.550     Total Elapsed Time:   693.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3384E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2383E-05  [K,I,J]    3    1  161
#  Transport Step:   33   Step Size:   4.550     Total Elapsed Time:   697.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3366E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2355E-05  [K,I,J]    3    1  161
#  Transport Step:   34   Step Size:   4.550     Total Elapsed Time:   702.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3347E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2327E-05  [K,I,J]    3    1  161
#  Transport Step:   35   Step Size:   4.550     Total Elapsed Time:   706.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3327E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2300E-05  [K,I,J]    3    1  161
#  Transport Step:   36   Step Size:   4.550     Total Elapsed Time:   711.29
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3307E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2273E-05  [K,I,J]    3    1  161
#  Transport Step:   37   Step Size:   4.550     Total Elapsed Time:   715.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3287E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2246E-05  [K,I,J]    3    1  161
#  Transport Step:   38   Step Size:   4.550     Total Elapsed Time:   720.39
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3266E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2220E-05  [K,I,J]    3    1  161
#  Transport Step:   39   Step Size:   4.550     Total Elapsed Time:   724.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3245E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2195E-05  [K,I,J]    3    1  161
#  Transport Step:   40   Step Size:   4.550     Total Elapsed Time:   729.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3223E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2169E-05  [K,I,J]    3    1  161
#  Transport Step:   41   Step Size:  0.5142     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3640E-03  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3527E-08  [K,I,J]    3    1  161
#  Transport Step:   42   Step Size:  1.1369E-13 Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    5
#
#   STRESS PERIOD    5 TIME STEP    1 FROM TIME =   730.00     TO    912.50
#
#  Transport Step:    1   Step Size:   4.550     Total Elapsed Time:   734.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3297E-02  [K,I,J]   17    2  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2140E-05  [K,I,J]    3    1  161
#  Transport Step:    2   Step Size:   4.550     Total Elapsed Time:   739.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3130E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2033E-05  [K,I,J]    3    1  161
#  Transport Step:    3   Step Size:   4.550     Total Elapsed Time:   743.65
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3097E-02  [K,I,J]    2    1  171
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1986E-05  [K,I,J]    3    1  161
#  Transport Step:    4   Step Size:   4.550     Total Elapsed Time:   748.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3082E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1951E-05  [K,I,J]    3    1  161
#  Transport Step:    5   Step Size:   4.550     Total Elapsed Time:   752.75
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3071E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1922E-05  [K,I,J]    3    1  161
#  Transport Step:    6   Step Size:   4.550     Total Elapsed Time:   757.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3062E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1897E-05  [K,I,J]    3    1  161
#  Transport Step:    7   Step Size:   4.550     Total Elapsed Time:   761.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3052E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1874E-05  [K,I,J]    3    1  161
#  Transport Step:    8   Step Size:   4.550     Total Elapsed Time:   766.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3042E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1851E-05  [K,I,J]    3    1  161
#  Transport Step:    9   Step Size:   4.550     Total Elapsed Time:   770.95
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3032E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1830E-05  [K,I,J]    3    1  161
#  Transport Step:   10   Step Size:   4.550     Total Elapsed Time:   775.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3022E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1809E-05  [K,I,J]    3    1  161
#  Transport Step:   11   Step Size:   4.550     Total Elapsed Time:   780.05
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3011E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1788E-05  [K,I,J]    3    1  161
#  Transport Step:   12   Step Size:   4.550     Total Elapsed Time:   784.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2999E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1768E-05  [K,I,J]    3    1  161
#  Transport Step:   13   Step Size:   4.550     Total Elapsed Time:   789.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2987E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1748E-05  [K,I,J]    3    1  161
#  Transport Step:   14   Step Size:   4.550     Total Elapsed Time:   793.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2975E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1729E-05  [K,I,J]    3    1  161
#  Transport Step:   15   Step Size:   4.550     Total Elapsed Time:   798.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2962E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1710E-05  [K,I,J]    3    1  161
#  Transport Step:   16   Step Size:   4.550     Total Elapsed Time:   802.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2948E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1691E-05  [K,I,J]    3    1  161
#  Transport Step:   17   Step Size:   4.550     Total Elapsed Time:   807.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2935E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1673E-05  [K,I,J]    3    1  161
#  Transport Step:   18   Step Size:   4.550     Total Elapsed Time:   811.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2921E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1655E-05  [K,I,J]    3    1  161
#  Transport Step:   19   Step Size:   4.550     Total Elapsed Time:   816.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2906E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1637E-05  [K,I,J]    3    1  161
#  Transport Step:   20   Step Size:   4.550     Total Elapsed Time:   820.99
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2891E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1619E-05  [K,I,J]    3    1  161
#  Transport Step:   21   Step Size:   4.550     Total Elapsed Time:   825.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2876E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1602E-05  [K,I,J]    3    1  161
#  Transport Step:   22   Step Size:   4.550     Total Elapsed Time:   830.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2861E-02  [K,I,J]    2    1  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1585E-05  [K,I,J]    3    1  161
#  Transport Step:   23   Step Size:   4.550     Total Elapsed Time:   834.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2845E-02  [K,I,J]    2    1  172
# ...
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1528E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2485E-06  [K,I,J]    5    1  179
#  Transport Step:   19   Step Size:   6.427     Total Elapsed Time:   14187.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1521E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2433E-06  [K,I,J]    5    1  179
#  Transport Step:   20   Step Size:   6.427     Total Elapsed Time:   14193.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1514E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-06  [K,I,J]    5    1  179
#  Transport Step:   21   Step Size:   6.427     Total Elapsed Time:   14200.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1507E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2339E-06  [K,I,J]    5    1  179
#  Transport Step:   22   Step Size:   6.427     Total Elapsed Time:   14206.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1499E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2298E-06  [K,I,J]    5    1  179
#  Transport Step:   23   Step Size:   6.427     Total Elapsed Time:   14213.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1492E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2259E-06  [K,I,J]    5    1  179
#  Transport Step:   24   Step Size:   6.427     Total Elapsed Time:   14219.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1485E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2223E-06  [K,I,J]    5    1  179
#  Transport Step:   25   Step Size:   6.427     Total Elapsed Time:   14225.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1478E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2190E-06  [K,I,J]    5    1  179
#  Transport Step:   26   Step Size:   6.427     Total Elapsed Time:   14232.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1471E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2158E-06  [K,I,J]    5    1  179
#  Transport Step:   27   Step Size:   3.113     Total Elapsed Time:   14235.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7113E-03  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2724E-07  [K,I,J]    5    1  179
#  Transport Step:   28   Step Size:  1.8190E-12 Total Elapsed Time:   14235.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.   79
#
#   STRESS PERIOD   79 TIME STEP    1 FROM TIME =   14235.     TO    14418.
#
#  Transport Step:    1   Step Size:   6.427     Total Elapsed Time:   14241.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6152E-03  [K,I,J]    2    1  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1077E-06  [K,I,J]    6    1  159
#  Transport Step:    2   Step Size:   18.69     Total Elapsed Time:   14260.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5147E-02  [K,I,J]    7    2  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1529E-05  [K,I,J]    6    1  158
#  Transport Step:    3   Step Size:   18.70     Total Elapsed Time:   14279.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5294E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1565E-05  [K,I,J]    6    1  158
#  Transport Step:    4   Step Size:   18.70     Total Elapsed Time:   14298.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5418E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1579E-05  [K,I,J]    6    1  158
#  Transport Step:    5   Step Size:   18.70     Total Elapsed Time:   14316.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5285E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1571E-05  [K,I,J]    6    1  158
#  Transport Step:    6   Step Size:   18.70     Total Elapsed Time:   14335.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5111E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1548E-05  [K,I,J]    6    1  158
#  Transport Step:    7   Step Size:   18.70     Total Elapsed Time:   14354.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4937E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1516E-05  [K,I,J]    6    1  158
#  Transport Step:    8   Step Size:   18.70     Total Elapsed Time:   14372.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4769E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1477E-05  [K,I,J]    6    1  158
#  Transport Step:    9   Step Size:   18.70     Total Elapsed Time:   14391.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4608E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1433E-05  [K,I,J]    6    1  158
#  Transport Step:   10   Step Size:   18.70     Total Elapsed Time:   14410.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4453E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1387E-05  [K,I,J]    6    1  158
#  Transport Step:   11   Step Size:   7.757     Total Elapsed Time:   14418.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1806E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1071E-06  [K,I,J]    6    1  158
#
#  STRESS PERIOD NO.   80
#
#   STRESS PERIOD   80 TIME STEP    1 FROM TIME =   14418.     TO    14600.
#
#  Transport Step:    1   Step Size:  0.5000     Total Elapsed Time:   14418.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1147E-03  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3067E-10  [K,I,J]    6    1  158
#  Transport Step:    2   Step Size:   4.972     Total Elapsed Time:   14423.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4928E-03  [K,I,J]    6    1  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6822E-07  [K,I,J]    3    1  241
#  Transport Step:    3   Step Size:   6.428     Total Elapsed Time:   14429.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1365E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2788E-06  [K,I,J]    3    1  241
#  Transport Step:    4   Step Size:   6.428     Total Elapsed Time:   14436.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1855E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3186E-06  [K,I,J]    3    1  241
#  Transport Step:    5   Step Size:   6.427     Total Elapsed Time:   14442.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2017E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3611E-06  [K,I,J]    5    1  179
#  Transport Step:    6   Step Size:   6.427     Total Elapsed Time:   14449.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2032E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3754E-06  [K,I,J]    5    1  179
#  Transport Step:    7   Step Size:   6.427     Total Elapsed Time:   14455.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2005E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3726E-06  [K,I,J]    5    1  179
#  Transport Step:    8   Step Size:   6.427     Total Elapsed Time:   14462.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1966E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3635E-06  [K,I,J]    5    1  179
#  Transport Step:    9   Step Size:   6.427     Total Elapsed Time:   14468.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1924E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3523E-06  [K,I,J]    5    1  179
#  Transport Step:   10   Step Size:   6.427     Total Elapsed Time:   14474.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1883E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3409E-06  [K,I,J]    5    1  179
#  Transport Step:   11   Step Size:   6.427     Total Elapsed Time:   14481.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1842E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3300E-06  [K,I,J]    5    1  179
#  Transport Step:   12   Step Size:   6.427     Total Elapsed Time:   14487.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1802E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3218E-06  [K,I,J]    5    1  179
#  Transport Step:   13   Step Size:   6.427     Total Elapsed Time:   14494.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1764E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2996E-06  [K,I,J]    5    1  179
#  Transport Step:   14   Step Size:   6.427     Total Elapsed Time:   14500.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1728E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2953E-06  [K,I,J]    5    1  179
#  Transport Step:   15   Step Size:   6.427     Total Elapsed Time:   14507.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1693E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2872E-06  [K,I,J]    5    1  179
#  Transport Step:   16   Step Size:   6.427     Total Elapsed Time:   14513.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1659E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2791E-06  [K,I,J]    5    1  179
#  Transport Step:   17   Step Size:   6.427     Total Elapsed Time:   14519.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1627E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2716E-06  [K,I,J]    5    1  179
#  Transport Step:   18   Step Size:   6.427     Total Elapsed Time:   14526.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1595E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2645E-06  [K,I,J]    5    1  179
#  Transport Step:   19   Step Size:   6.427     Total Elapsed Time:   14532.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1565E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2580E-06  [K,I,J]    5    1  179
#  Transport Step:   20   Step Size:   6.427     Total Elapsed Time:   14539.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1541E-02  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2520E-06  [K,I,J]    5    1  179
#  Transport Step:   21   Step Size:   6.427     Total Elapsed Time:   14545.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1525E-02  [K,I,J]    2    2  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2464E-06  [K,I,J]    5    1  179
#  Transport Step:   22   Step Size:   6.427     Total Elapsed Time:   14552.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1514E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2412E-06  [K,I,J]    5    1  179
#  Transport Step:   23   Step Size:   6.427     Total Elapsed Time:   14558.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1507E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2365E-06  [K,I,J]    5    1  179
#  Transport Step:   24   Step Size:   6.427     Total Elapsed Time:   14564.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1500E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2321E-06  [K,I,J]    5    1  179
#  Transport Step:   25   Step Size:   6.427     Total Elapsed Time:   14571.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1492E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2280E-06  [K,I,J]    5    1  179
#  Transport Step:   26   Step Size:   6.427     Total Elapsed Time:   14577.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1485E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2242E-06  [K,I,J]    5    1  179
#  Transport Step:   27   Step Size:   6.427     Total Elapsed Time:   14584.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1478E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2207E-06  [K,I,J]    5    1  179
#  Transport Step:   28   Step Size:   6.427     Total Elapsed Time:   14590.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1470E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2174E-06  [K,I,J]    5    1  179
#  Transport Step:   29   Step Size:   6.427     Total Elapsed Time:   14597.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1463E-02  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2143E-06  [K,I,J]    5    1  179
#  Transport Step:   30   Step Size:   3.489     Total Elapsed Time:   14600.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7926E-03  [K,I,J]    2    1  155
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3753E-07  [K,I,J]    5    1  179
#  Transport Step:   31   Step Size:  1.8190E-12 Total Elapsed Time:   14600.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.   81
#
#   STRESS PERIOD   81 TIME STEP    1 FROM TIME =   14600.     TO    14783.
#
#  Transport Step:    1   Step Size:   6.427     Total Elapsed Time:   14606.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6155E-03  [K,I,J]    2    1  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1090E-06  [K,I,J]    6    1  159
#  Transport Step:    2   Step Size:   18.69     Total Elapsed Time:   14625.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5168E-02  [K,I,J]    7    2  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1514E-05  [K,I,J]    6    1  158
#  Transport Step:    3   Step Size:   18.70     Total Elapsed Time:   14644.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5312E-02  [K,I,J]    7    2  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1561E-05  [K,I,J]    6    1  158
#  Transport Step:    4   Step Size:   18.70     Total Elapsed Time:   14663.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5398E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1578E-05  [K,I,J]    6    1  158
#  Transport Step:    5   Step Size:   18.70     Total Elapsed Time:   14681.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5267E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1571E-05  [K,I,J]    6    1  158
#  Transport Step:    6   Step Size:   18.70     Total Elapsed Time:   14700.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5096E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1549E-05  [K,I,J]    6    1  158
#  Transport Step:    7   Step Size:   18.70     Total Elapsed Time:   14719.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4923E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1518E-05  [K,I,J]    6    1  158
#  Transport Step:    8   Step Size:   18.70     Total Elapsed Time:   14737.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4756E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1479E-05  [K,I,J]    6    1  158
#  Transport Step:    9   Step Size:   18.70     Total Elapsed Time:   14756.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4597E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1436E-05  [K,I,J]    6    1  158
#  Transport Step:   10   Step Size:   18.70     Total Elapsed Time:   14775.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4443E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1391E-05  [K,I,J]    6    1  158
#  Transport Step:   11   Step Size:   7.257     Total Elapsed Time:   14782.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1687E-02  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8846E-07  [K,I,J]    6    1  158
#  Transport Step:   12   Step Size:  0.5000     Total Elapsed Time:   14783.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1155E-03  [K,I,J]    5    2  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3073E-10  [K,I,J]    6    1  158
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2020/07/01 15:17:47
#  Elapsed run time:  6 Minutes, 43.213 Seconds
#
#  Normal termination of SEAWAT
#  Elapsed run time:  6 Minutes, 43.213 Seconds
#
#  Normal termination of SEAWAT
# CPU times: user 5.95 s, sys: 1.5 s, total: 7.44 s
# Wall time: 6min 44s

# %% [markdown]
# ### Post processing

# %%
fname = model_ws.joinpath('MT3D001.UCN').as_posix()
anyvals= []
ucnobj = flopy.utils.binaryfile.UcnFile(fname,verbose=False)
# if kstpkper==None:
kstpkpers = ucnobj.get_kstpkper()
for kstpkper in kstpkpers:
    conc = ucnobj.get_data(kstpkper=kstpkper)
    anyvals.append(np.logical_and(conc < 100., conc>0.).any())
print(anyvals)


conc = ucnobj.get_data(kstpkper=kstpkpers[-1])
conc[conc > 100]=np.nan


fname = model_ws.joinpath(m.name +'.hds').as_posix()
hdobj = flopy.utils.binaryfile.HeadFile(fname,verbose=False)
kstpkpers = hdobj.get_kstpkper()
hd = hdobj.get_data(kstpkper=kstpkpers[-1])
hd[hd<-100]=np.nan
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
from matplotlib import cm

slicetype='Row'
slicenum= -1

# First step is to set up the plot
fig = plt.figure(figsize=(9, 3))
ax = fig.add_subplot(1, 1, 1)

# Next we create an instance of the PlotCrossSection class
xsect = flopy.plot.PlotCrossSection(model=m, line={slicetype: slicenum},geographic_coords=True)
# xsect.plot_ibound()
xsect.plot_grid(linewidth=.1)
# Then we can use the plot_grid() method to draw the grid
# The return value for this function is a matplotlib LineCollection object,
# which could be manipulated (or used) later if necessary.
# linecollection = xsect.plot_grid()
# patches = xsect.plot_ibound()
# csa = xsect.plot_array(layer_mapping_ind)
# cmap = cm.get_cmap('tab10', lay_m.shape[0])
# xsect.contour_array(conc,cmap='jet',levels=np.array([.05,.5,.95])*Csalt)
xsect.plot_array(conc,cmap='jet',vmin=Cfresh,vmax=Csalt)
# csa = xsect.plot_array(hd)

c = plt.colorbar(csa)
# wel = xsect.plot_bc("CHD")
wel = xsect.plot_bc("GHB")



t = ax.set_title('{slicetype} {slicenum} Cross-Section'.format(slicetype=slicetype,slicenum=slicenum))
plt.ylabel('Elevation (m)')
plt.ylim((-200,100))
plt.xlabel('X UTM (m)')
# c.set_label('log10(hk)')
# plt.savefig(figdir.joinpath('seawat_fine_xsection_layers_{slicetype}{slicenum}.png'.format(slicetype=slicetype,slicenum=slicenum)),dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'X UTM (m)')
