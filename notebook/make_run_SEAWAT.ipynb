# %%
import flopy
import os
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

if sys.platform.lower()=='linux':
    datadir = Path('/scratch/users/ianpg/SWIlarge/data')
    workdir = Path('/scratch/users/ianpg/SWIlarge/work')
    MPSdir = datadir.joinpath('lith/sgems/MPS')
    GISdir = datadir.joinpath('GIS')
    import mplleaflet
elif sys.platform.lower()=='darwin':
    datadir = Path('../data')
    workdir = Path('../work')
    MPSdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/lith/sgems/MPS')
    GISdir = Path('/Users/ianpg/Dropbox/temp_convenience/SWIlarge/data/GIS')

nmgwmdir_empty = datadir.joinpath('nmgwmdir_empty') #<-- removed everything but DIS
nmgwmdir_cal = datadir.joinpath('Calibrated_small') #<-- removed RCH, WEL, GLO, LST from the NAM file to load much faster
figdir = workdir.joinpath('figs')
outputdir = workdir.joinpath('output')

import config
from set_rc import *

import pandas as pd
import shapefile as sf #in case you dont have it, form anaconda prompt: pip install pyshp
from flopy.utils.gridgen import Gridgen
from flopy.utils.reference import SpatialReference
from  pyproj import Proj

p = Proj("epsg:26910")
xll=595855
yll = 4059438
rotation = -13.5
# Out:
# flopy is installed in /Users/ianpg/anaconda/envs/SWIenv/lib/python3.6/site-packages/flopy
# system: darwin

# %%
#%% Useful functions

def load_obj(dirname,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'rb') as f:
        return pickle.load(f)

def save_obj(dirname,obj,name):
    import pickle
    with open(Path(dirname).joinpath(name + '.pkl').as_posix(), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

#Create new MC_file
def create_MC_file():
    import datetime
    ts = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
    MC_dir = Path(os.path.join(m.model_ws, 'MC_expt_' + ts))
    if not MC_dir.exists():
        MC_dir.mkdir()
    m.MC_file = MC_dir.joinpath('expt.txt')
    with m.MC_file.open('w') as wf:
        wf.close
    print(m.MC_file)
    return

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

#make a line across the grid
def get_line(start, end,allrows=1,nrow=None):
    """Bresenham's Line Algorithm
    Produces a list of tuples from start and end

    >>> points1 = get_line((0, 0), (3, 4))
    >>> points2 = get_line((3, 4), (0, 0))
    >>> assert(set(points1) == set(points2))
    >>> print points1
    [(0, 0), (1, 1), (1, 2), (2, 3), (3, 4)]
    >>> print points2
    [(3, 4), (2, 3), (1, 2), (1, 1), (0, 0)]
    """
    # Setup initial conditions
    x1, y1 = start
    x2, y2 = end
    dx = x2 - x1
    dy = y2 - y1

    # Determine how steep the line is
    is_steep = abs(dy) > abs(dx)

    # Rotate line
    if is_steep:
        x1, y1 = y1, x1
        x2, y2 = y2, x2

    # Swap start and end points if necessary and store swap state
    swapped = False
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
        swapped = True

    # Recalculate differentials
    dx = x2 - x1
    dy = y2 - y1

    # Calculate error
    error = int(dx / 2.0)
    ystep = 1 if y1 < y2 else -1

    # Iterate over bounding box generating points between start and end
    y = y1
    points = []
    for x in range(x1, x2 + 1):
        if allrows==1:
            if nrow is None:
                nrow = m.nrow
            for row in range(nrow):
                coord = (y, row, x) if is_steep else (x, row, y)
                points.append(coord)
        else:
            coord = (y, x) if is_steep else (x, y)
            points.append(coord)
        error -= abs(dy)
        if error < 0:
            y += ystep
            error += dx

    # Reverse the list if the coordinates were swapped
    if swapped:
        points.reverse()
    return points


#make all cells=0 above the line from get_line()
#Calculate freshwater head based on column of saltwater above each node (rho*g*z)
def shade_above(nlay,nrow,ncol,point_list,third_dim=1):
    import numpy as np
    grd = np.ones((nlay,nrow,ncol),dtype='int')
    ocean_hf = []
    if len(point_list)==0:
        return grd,ocean_hf
    for (lay,row,col) in point_list:
        grd[lay,:,col] = -1 #assign ocean ibound to -1
        grd[:lay,:,col] = 0 #assign cells above ocean to 0
        hf = densefresh/densesalt*ocean_elev - (densesalt - densefresh)/densefresh*(henry_botm[lay] +.5*delv)
        for irow in range(nrow):
            ocean_hf.append((int(lay),int(irow),int(col),hf))
    ocean_hf = tuple(np.array(ocean_hf).T)
    ocean_hf = (ocean_hf[0].astype('int'),
                ocean_hf[1].astype('int'),
                ocean_hf[2].astype('int'),
                ocean_hf[3])
    return grd,ocean_hf

def get_ocean_right_edge(m,ocean_line_tuple,startlay=None,col=None):
    import numpy as np
    point_list = []
    if col is None:
        col = m.ncol-1
    #If there is no vertical side boundary, return bottom-right corner node
    if len(ocean_line_tuple)==0:
        if startlay is None:
            startlay = 0
    elif max(ocean_line_tuple[0])==m.nlay:
        startlay = m.nlay
    elif max(ocean_line_tuple[0])<m.nlay:
        startlay = max(ocean_line_tuple[0])
    for lay in range(startlay,m.nlay):
        for row in range(m.nrow):
            point_list.append((lay,row,col))
    point_list = tuple(np.array(point_list).T)
    return point_list

def add_pumping_wells(wel_data,ssm_data,n_wells,flx,rowcol,kper):
    itype = flopy.mt3d.Mt3dSsm.itype_dict()
    new_weldata = wel_data
    new_ssmdata = ssm_data
    wel_cells = []
    for k in range(n_wells):
        row,col = rowcol[k]
        for i in range(nper):
            if i in kper:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,-flx[k]*delv_weight[j]])
                    wel_cells.append((j,row,col))
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
            else:
                for j in range(nlay):
                    #WEL {stress_period: [lay,row,col,flux]}
                    new_weldata[i].append([j,row,col,0])
                    #SSM: {stress_period: [lay,row,col,concentration,itype]}
                    new_ssmdata[i].append([j,row,col,Cfresh,itype['WEL']]) #since it's a sink, conc. doesn't matter
                    wel_cells.append((j,row,col))
                continue
    wel_cells = tuple(np.array(list(set(wel_cells))).T)
    return new_weldata, new_ssmdata,wel_cells

#Add recharge if desired
def make_rech_array(low=1e-2,high=1e0):
    import scipy.stats as sts
    llow,lhigh = np.log10((low,high))
    rech = np.exp(sts.uniform.rvs(size=1,loc=llow,scale=lhigh-llow)[0])
    return rech/(nrow*ncol)

def add_recharge_cells(recharge_generator,const=1,*args):
    if const==1:
        rech_data = recharge_generator(*args)
    else:
        rech_data = {}
        for i in range(nper):
            rech_array = recharge_generator(*args)
        rech_data[i] = rech_array
    return rech_data

def sample_dist(distclass,size,*args):
    smp = distclass.rvs(*args,size=size)
    if size==1:
        smp=smp[-1]
    return smp

def write_sample(fname,varname,distclass,sample):
    fout= open(fname,"a")
    fout.write(varname + ',' + str(type(distclass)) + ',' + str(sample) + '\n')
    fout.close()
    return

def truncate_grf(grid,lith_props,hk_vals,log10trans=True,plotyn=False,saveyn=False):
    grid_cutoffs = []
    for q in np.cumsum(lith_props):
        grid_cutoffs.append(np.quantile(grid,q))

    if plotyn:
        h = plt.hist(grid.flatten())
        for cutoff in grid_cutoffs:
            plt.vlines(cutoff,0,14000)
        plt.show()

    outgrid = np.ones(grid.shape,dtype=np.float32)
    for i,cutoff in reversed(list(enumerate(grid_cutoffs))):
        outgrid[np.where(grid<cutoff)] = hk_vals[i]

    if plotyn:
        f,axs = plt.subplots(2,1,sharex=True)
        axs[0].imshow(grid[:,0,:])
        axs[1].imshow(outgrid[:,0,:])
        if saveyn:
            plt.savefig(m.MC_file.parent.joinpath('Truncated_GRF.png').as_posix(),resolution=300)
    if log10trans:
        return np.power(10,outgrid)
    else:
        return outgrid

def make_timestamp(YMD=True,HM=True):
    import datetime
    if YMD:
        ymd = '%Y%m%d'
    else:
        ymd = ''
    if HM:
        hm = '%H%M'
    else:
        hm = ''
    if YMD and HM:
        sep = '_'
    else:
        sep = ''
    return datetime.datetime.now().strftime('{}{}{}'.format(ymd,sep,hm))

def pec_num(delv,delc,delr,al):
    delL = (delv,delc,delr) #length in the lay,row,col directions
    pec_num = [round(d/al,2) for d in delL]
    for num,point  in zip(pec_num,('lay','row','col')):
        print('Pe = {} in the {} direction'.format(num,point))
    return pec_num

#%%

# %%
# %%time
m_nm= flopy.modflow.Modflow.load('nm_cali.nam',version='mf2k',verbose=False,check=False,model_ws=nmgwmdir_cal.as_posix())
# m = flopy.modflow.Modflow.load(nmgwmdir_uncal.joinpath('C1-12_copy.nam').as_posix(),version='mf2k',verbose=False,check=False,model_ws=outputdir.joinpath('C1').as_posix())
m_nm.exe_name = config.mf2000exe
if not m_nm.DIS.lenuni==2:
    m_nm.DIS.delr *= .3048
    m_nm.DIS.delc *= .3048
    m_nm.DIS.top *= .3048
    m_nm.DIS.botm *= .3048
m_nm.DIS.lenuni = 2
m_nm.DIS.itmuni=4
m_nm.DIS.rotation=-13.5
# m_nm.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_nm.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_nm.DIS.proj4_str = p.srs
m_nm.modelgrid.set_coord_info(xoff=xll, yoff=yll, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
# Out:
# CPU times: user 1min 31s, sys: 1.69 s, total: 1min 33s
# Wall time: 1min 45s

# %%
start_nm_yr = 1979
start_nm_mo = 10
start_nm_str = 'Oct 1979'
end_nm_yr = 2011
end_nm_mo = 9
end_nm_str = 'Sep 2011'
Lt_nm = ( (end_nm_yr + end_nm_mo/12)  - (start_nm_yr + start_nm_mo/12) )     *365
start_nm_datetime='{}/1/{}'.format(start_nm_mo,start_nm_yr)



start_m_yr = 1979
start_m_mo = 10
start_m_str = 'Oct 1979'
end_m_yr = 2011
end_m_mo = 9
end_m_str = 'Sep 2011'
Lt_m = ( (end_m_yr + end_m_mo/12)  - (start_m_yr + start_m_mo/12) )     *365
start_m_datetime='{}/1/{}'.format(start_m_mo,start_m_yr)

# %%
#Name model
modelname = 'NM'
model_ws = workdir.joinpath("NM")
#Name model
sw_exe = config.swexe #set the exe path for seawat

#Model discretization
Lz = 150.

nrow,ncol,nlay,nper = m_nm.nrow_ncol_nlay_nper

# rows = np.arange(100,102)
# rows = np.arange(164,165)
# rows = np.arange(nrow)
# rows = np.arange(m_nm.nrow-159,   m_nm.nrow-132) #SV
rows = np.arange(m_nm.nrow-114,   m_nm.nrow-74) #NM




cols = np.arange(ncol)
nrow =len(rows)
ncol = len(cols)
nlay=20


henry_top = 2
ocean_elev = 0
delv_first = 4
botm_first = henry_top-delv_first


delv = (Lz-delv_first) / (nlay-1)
delr = m_nm.dis.delr.array[0]
delc = m_nm.dis.delc.array[0]

henry_botm = np.hstack(([botm_first],np.linspace(botm_first-delv,henry_top-Lz,nlay-1)))
delv_vec = np.hstack((delv_first,np.repeat(delv,nlay-1)))
delv_weight = [x/np.sum(delv_vec) for x in delv_vec]


topo_grid = np.load(GISdir.joinpath('topo_grid.npy'))
henry_top = topo_grid[(slice(rows[0],rows[-1]+1),slice(cols[0],cols[-1]+1))]


# beachslope = .05
# ocean_col = [np.floor(ncol-1).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn
# ocean_col = [np.floor(ncol/2).astype('int'),ncol-1] #Manually done to make sure it's in the right place rn

# inland_elev = beachslope*ocean_col[0]*delr
# offshore_elev = -beachslope*(ocean_col[1]-ocean_col[0])*delr


#Period data
# nyrs= 2
# Lt = 365*nyrs #Length of time in days

perlen = list(np.repeat(365/2,int(Lt_m/(365/2))))
nper = len(perlen)
nstp = np.ones_like(perlen,dtype=np.int)

# nstp = m_nm.dis.nstp.array
# perlen = m_nm.dis.perlen.array
# nper = m_nm.nper





steady = [False for x in range(len(perlen))] #Never steady
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1.1
ssm_data = None
verbose = True

print('Model setup: \n'
      'nlay: {}\n'
      'nrow: {}\n'
      'ncol: {}\n'
      'Total cells: {}\n'
      'Total time: {} days\n'
      'nper: {}\n'.format(nlay,nrow,ncol,nlay*nrow*ncol,Lt_m,nper))
# In[4]:

#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws.as_posix(),verbose=verbose)
# SGD.ModelSGD.Seawat2SGD(m)  #convert to subclass ModelSGD
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,
                               start_datetime=start_m_datetime)

xll=595855
yll = 4059438
rotation=-13.5
# p = Proj(proj='utm',zone='10n',ellps='WGS84',units='meters', preserve_units=False)

m.DIS.lenuni = 2
m.DIS.itmuni=4
m.DIS.rotation=-13.5
# m.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m.DIS.proj4_str = p.srs
xll_m,yll_m = m_nm.modelgrid.xvertices[rows[-1]+1,0],m_nm.modelgrid.yvertices[rows[-1]+1,0]


m.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')
print(m.modelgrid)
# Out:
# Model setup:
# nlay: 20
# nrow: 40
# ncol: 345
# Total cells: 276000
# Total time: 11649.583333333361 days
# nper: 63
#
# NM.nam
# adding Package:  DIS
# xll:596908.072036354; yll:4063824.360710914; rotation:-13.5; proj4_str:+proj=utm +zone=10 +datum=NAD83 +units=m +no_defs; units:undefined; lenuni:0

# %%
m_empty = flopy.modflow.Modflow('m_empty', model_ws=model_ws.joinpath('m_empty').as_posix())


flopy.modflow.ModflowDis(m_empty, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc,
                               laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult,start_datetime=start_m_datetime)

m_empty.DIS.lenuni = 2
m_empty.DIS.itmuni=4
m_empty.DIS.rotation=-13.5
# m_empty.DIS.xul = xll + 18288.0*np.sin(13.5*180/np.pi) #upper left UTM Zone 10N
# m_empty.DIS.yul = yll + 18288.0*np.cos(13.5*180/np.pi)  #upper left UTM Zone 10N
m_empty.DIS.proj4_str = p.srs
m_empty.modelgrid.set_coord_info(xoff=xll_m, yoff=yll_m, angrot=rotation, proj4=p.srs)#,epsg='nad83-utm-zone-10n')

# %%
# %%time
gridgen_ws = model_ws.joinpath('gridgen')
if not gridgen_ws.exists():
    gridgen_ws.mkdir()
g = Gridgen(m_empty.dis, model_ws=gridgen_ws.as_posix(),exe_name=config.gridgenexe,surface_interpolation='replicate')
g.build(verbose=False)
# Out:
# CPU times: user 12.4 s, sys: 765 ms, total: 13.2 s
# Wall time: 49.2 s

# %%
f_swi_180 = GISdir.joinpath("chloride_contours",'SWI_180_lines_noz.shp').as_posix()
swi_180 = sf.Reader(f_swi_180)
yrs_180 = [ int(r[-1]) for r in swi_180.records()]


for yr in yrs_180:
    f_exp = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_180.fields[1:] # skip first deletion field
        for feature in swi_180.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

f_swi_400 = GISdir.joinpath("chloride_contours",'SWI_400_lines_noz.shp').as_posix()
swi_400 = sf.Reader(f_swi_400)
yrs_400 = [ int(r[-1]) for r in swi_400.records()]


for yr in yrs_400:
    f_exp = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    with sf.Writer(f_exp) as w:
        w.fields = swi_400.fields[1:] # skip first deletion field
        for feature in swi_400.iterShapeRecords(): # iteration on both record and shape for a feature
            if int(feature.record[-1])==yr:
                w.record(*feature.record) # * for unpacking tuple
                w.shape(feature.shape)

# %%
layer =3
yr = yrs_180[-1]
f_shp_180 = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
int_180 = g.intersect(f_shp_180,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_180.nodenumber] = 1
a180 = a.reshape((nlay,nrow,ncol),order='C')


yr = yrs_400[-1]
f_shp_400 = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
int_400 = g.intersect(f_shp_400,'polygon',layer=layer)
g.nodes = g.get_nodes()
a = np.zeros((g.nodes), dtype=np.int)
a[int_400.nodenumber] = 1
a400 = a.reshape((nlay,nrow,ncol),order='C')

# %%
df_TDS = pd.read_excel(datadir.joinpath('WQ','export_TDS_data.xlsx'))
TDSij =[]
for x,y in zip(df_TDS.X_NAD83_UTM10N.values,df_TDS.Y_NAD83_UTM10N.values):
    try:
        TDSij.append(m_empty.modelgrid.intersect(x,y))
    except:
        TDSij.append((np.nan,np.nan))
df_TDS = df_TDS.assign(rowi=np.array(TDSij)[:,0])
df_TDS = df_TDS.assign(colj=np.array(TDSij)[:,1])

# %%
def intersect_swi_contour(aquifer=180,yr_ind=None):
    if aquifer==180:
        yr = yrs_180[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_180","swi_180_{}".format(yr)).as_posix()
    elif aquifer==400:
        yr = yrs_400[yr_ind]
        f = GISdir.joinpath("chloride_contours","by_year_400","swi_400_{}".format(yr)).as_posix()
    else:
        raise('enter either 180 or 400')
    int_obj = g.intersect(f,'polygon',layer=layer)
    a = np.zeros((g.nodes), dtype=np.int)
    a[int_obj.nodenumber] = 1
    return a.reshape((nlay,nrow,ncol),order='C')


from scipy.interpolate import interp2d,RectBivariateSpline,NearestNDInterpolator,griddata
def make_surf(grid_old,m_old,m_new,method='nearest'):
    points = np.stack((m_old.modelgrid.xcellcenters.flatten(),m_old.modelgrid.ycellcenters.flatten())).T
    values = grid_old.flatten()
    grid_x=  m_new.modelgrid.xcellcenters
    grid_y=  m_new.modelgrid.ycellcenters
    return griddata(points, values, (grid_x, grid_y), method=method)

# %%
botm_orig= m_nm.DIS.botm.array[:6]
layer_mapping = np.zeros((7,nlay,nrow,ncol),dtype=bool)
for lay in range(7):
    if lay==0:
        ind_inlay = np.zeros((nlay,nrow,ncol),dtype=np.bool)
        ind_inlay[0,:,:] = True
    elif lay==6:
#         botm_orig_lay = interp_surf2newgrid(botm_orig[lay-1])
        botm_orig_lay = make_surf(botm_orig[-1],m_nm,m_empty)
        ind_inlay = m_empty.dis.botm.array<botm_orig_lay
    else:
        botm_orig_lay = make_surf(botm_orig[lay],m_nm,m_empty)
        top_orig_lay = make_surf(botm_orig[lay-1],m_nm,m_empty)
        ind_inlay =np.logical_and(m_empty.dis.botm.array>=botm_orig_lay,m_empty.dis.botm.array<top_orig_lay)
    layer_mapping[lay,:,:,:] = ind_inlay
    
    
    
layer_mapping_ind = np.zeros((nlay,nrow,ncol),dtype=int)
for lay in range(7):
    if lay==0:
        val=-50
    if lay==6:
        val=50
    else:
        val=lay
    layer_mapping_ind+=layer_mapping[lay].astype(int)*val
    
layer_mapping_ind[layer_mapping_ind<=0]= 0
layer_mapping_ind[layer_mapping_ind>=6]=6

# %%
hk_nm = m_nm.lpf.hk.array
x_nm = m_nm.modelgrid.xcellcenters
y_nm = m_nm.modelgrid.ycellcenters
z_nm = m_nm.modelgrid.zcellcenters
x_m = m_empty.modelgrid.xcellcenters
y_m = m_empty.modelgrid.ycellcenters
z_m = m_empty.modelgrid.zcellcenters

hk_new = griddata(points=(np.tile(x_nm,(m_nm.dis.nlay,1,1)).flatten(),np.tile(y_nm,(m_nm.dis.nlay,1,1)).flatten(),z_nm.flatten()),
               values=hk_nm.flatten(),
               xi=(x_m,y_m,z_m),method='nearest')
hk_new[np.isnan(hk_new)] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])
hk_new[hk_new>10000] = np.max(hk_new[np.logical_and(layer_mapping_ind==1,hk_new<10000)])



#Hydraulic conductivity field
hkSand = 1e2 #horizontal hydraulic conductivity m/day
hkClay = hkSand*.001

# heterogenous = 0 #0:homogenous,1:variogram,2:MPS

# hk = np.ones((nlay,nrow,ncol), dtype=np.float)
# hk[np.isin(layer_mapping_ind,(0,1,3,5))] = hkSand
# hk[np.isin(layer_mapping_ind,(2,4,6))] = hkClay


hk = hk_new 
#plt.figure(),plt.imshow((hk[:,0,:])),plt.colorbar(),plt.title('Sill:{}'.format(sill)),plt.show()

#Set Hydraulic properties
sy = 0.15
ss = 1e-5
por = 0.3
vka = .5 # = vk/hk
al = 20 #longitudinal dispersivity (m) from Walther et al. 2017
dmcoef = 2e-9 #m2/day

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)
#denseslp = 0 #trick for testing constant density

# %%
plt.figure()


mps180 = np.load(MPSdir.joinpath('reals','mps180_16node.npy'))
mps180[mps180==1]=hkSand
mps180[mps180==0]=hkClay
hk2 = hk.copy()
hk2[np.where(layer_mapping_ind==3)] = mps180[np.where(layer_mapping_ind==3)] 
plt.imshow(np.ma.masked_where(hk2>600,hk2)[:,0,:])
plt.gca().set_aspect(10)

# %% [markdown]
# ### BCs

# %%
def find_ocean(m,layer_mapping_ind):
    ocean_line = []

    for lay in range(m.dis.nlay):
        for row in range(m.dis.nrow):
            thislay = (lay,row,np.where(layer_mapping_ind[lay,row,:]!=0)[0][0])
            ocean_line.append(thislay)
            if lay==m.dis.nlay-1:
                pass
            else:
                nextlay = (lay+1,row,np.where(layer_mapping_ind[lay+1,row,:]!=0)[0][0])
                for col in np.arange(thislay[2],nextlay[2],-1):
                    ocean_line.append((lay,row,col))
    ocean_line = np.array(ocean_line).T


    ocean_grid = np.zeros((nlay,nrow,ncol),dtype=np.bool)
    ocean_grid[tuple(ocean_line)]=True
    ocean_grid[m.modelgrid.zvertices[1:,:,:]>ocean_elev]=False
    return ocean_line,ocean_grid

ocean_line,ocean_grid = find_ocean(m,layer_mapping_ind)

# %%
itype = flopy.mt3d.Mt3dSsm.itype_dict()
cond = 1000.

ghb_data_ocean = {}
ssm_data_ocean = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = []
    ssm_per = []
    #Ocean boundary
    for v in np.argwhere(ocean_grid):
        ghb_per.append([v[0],
                       v[1],
                       v[2],
                       #ocean_hf[3][j],
                        ocean_elev,
                       cond])
        #SSM: {stress_period: [lay,row,col,concentration,itype]}
        ssm_per.append([v[0],
                       v[1],
                       v[2],
                       Csalt,
                       itype['GHB']])
    ghb_data_ocean[kper]=ghb_per
    ssm_data_ocean[kper]=ssm_per

    
    
inds = []
nix_ghb = []
for v in ocean_line.T:
# v = ocean_line.T[-1]
    if 6 in layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]:
        inds.append((v[0],v[1],int(np.argwhere(layer_mapping_ind[v[0],v[1],v[2]:v[2]+10]==6)[0]) + v[2]))
        nix_ghb.append(v)

        
for kper in range(nper):
    for v in nix_ghb:
        try:
            ghb_data_ocean[kper].remove([v[0],v[1],v[2],0,cond])
        except:
            continue
# Out:
# kper 0
# kper 50

# %%
def find_nearest_kper_nm(kper_m):
    t_m = (start_m_yr + start_m_mo/12) + np.sum(perlen[:kper_m])
    t_vec_nm = (start_nm_yr + start_nm_mo/12) + np.cumsum(m_nm.dis.perlen.array)    
    return np.argmin(abs(t_vec_nm-t_m))
    

layers_to_map=np.arange(3,6)
z_m_vert = m_empty.modelgrid.zvertices
ghb_data_nm = m_nm.ghb.stress_period_data.data


ghb_data_inland = {}
ssm_data_inland = {}



for kper_m in range(nper):
    kper_nm = find_nearest_kper_nm(kper_m)

#     if kper>0:
#         continue
    if kper_m%10==0:
        print('kper_m',kper_m,kper_nm)

    ghb_per=[]
    ssm_per = []
    for i,row in enumerate(rows):
        for lay in layers_to_map:
            msk = np.logical_and(np.logical_and(ghb_data_nm[kper_nm]['i']==i,ghb_data_nm[kper_nm]['j']==344),ghb_data_nm[kper_nm]['k']==lay)
            bhead = ghb_data_nm[kper_nm][msk]['bhead'][0]
            lay_map = np.argwhere(np.logical_and(layer_mapping_ind[:,i,344]==lay,z_m_vert[1:,i,344]<bhead)).flatten()
            for new_lay in lay_map:
                ghb_per.append((new_lay,i,344,bhead,cond))
                ssm_per.append([new_lay,i,344,Cfresh,itype['GHB']])
    ghb_data_inland[kper_m]=ghb_per
    ssm_data_inland[kper_m]=ssm_per
# Out:
# kper_m 0 0
# kper_m 10 59
# kper_m 20 119
# kper_m 30 179
# kper_m 40 239
# kper_m 50 299
# kper_m 60 359

# %% [markdown]
#  ### STRT

# %%
yr_ind = np.argmin([np.min(abs(v - (start_m_yr + start_m_mo/12))) for v in yrs_180])
a_180 = intersect_swi_contour(aquifer=180,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_180]))
a_180 = np.tile(a_180[nonzerolay],(nlay,1,1))


yr_ind = np.argmin([np.min(abs(v - (start_m_yr + start_m_mo/12))) for v in yrs_400])
a_400 = intersect_swi_contour(aquifer=400,yr_ind=yr_ind)
nonzerolay = int(np.argwhere([v.any() for v in a_400]))
a_400 = np.tile(a_400[nonzerolay],(nlay,1,1))
salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)


salt_180 =np.logical_and(a_180==1,layer_mapping_ind==3)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_180[lay,row,:])
        if len(inds_nonzero)>0:
            salt_180[lay,row,:int(inds_nonzero[0])]=True
            
salt_400 =np.logical_and(a_400==1,layer_mapping_ind==5)
for lay in range(nlay):
    for row in range(nrow):
        inds_nonzero = np.argwhere(salt_400[lay,row,:])
        if len(inds_nonzero)>0:
            salt_400[lay,row,:int(inds_nonzero[0])]=True

# %%
for lay in nlay

# %%
lay=0
row=0

# %%
ind_max.max()-ind_ocean
# Out:
# array([[32],
#        [31],
#        [30],
#        [29]])

# %%
saltgrad_180 = np.zeros_like(a_180)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_180[lay,row,:])
        if len(ind_max)>0:
            ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_180[lay,row,ind_ocean:ind_max.max()]=tds_vec
saltgrad_400 = np.zeros_like(a_400)
for lay in range(nlay):
    for row in range(nrow):
        ind_max = np.argwhere(a_400[lay,row,:])
        if len(ind_max)>0:
            ind_ocean = np.argwhere(ocean_grid[lay,row,:]).max()
            tds_vec = np.linspace(Csalt,250/1000, ind_max.max()-ind_ocean)
            saltgrad_400[lay,row,ind_ocean:ind_max.max()]=tds_vec

# %%
plt.imshow(sconc[:,10,:])
plt.gca().set_aspect(10)
plt.colorbar()

# %%
# ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
# for v in np.argwhere(ocean_grid):
#     ibound[v[0],v[1],:v[2]]=0
# head_inland =-10.
head_inland = min([np.min(np.array(v)[:,3]) for k,v in ghb_data_inland.items()])
ibound = np.ones((nlay,nrow,ncol),dtype=np.int)
for lay in range(nlay):
    for row in range(nrow):
        col = int(np.argwhere(ocean_grid[lay,row,:])[0])
        ibound[lay,row,:col]=0
for v in inds:
    ibound[v[0],v[1],:v[2]]=0
ibound[z_m_vert[1:,:,:]>0]=0
ibound[layer_mapping_ind==6]=0

strt = np.ones_like(ibound)*head_inland

# sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
# sconc[ocean_grid] = Csalt
# # interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
# for v in ocean_line.T:
#     sconc[v[0],v[1],:v[2]]=Csalt
# sconc[np.logical_or(salt_180,salt_400)] = Csalt
    
sconc=np.ones((nlay,nrow,ncol),dtype=np.float)*Cfresh
sconc[np.isin(layer_mapping_ind,(3,1))] = saltgrad_180[np.isin(layer_mapping_ind,(3,1))]
sconc[np.isin(layer_mapping_ind,(5,1))] = saltgrad_400[np.isin(layer_mapping_ind,(5,1))]
# sconc[layer_mapping_ind==1] =Csalt
sconc[ocean_grid] = Csalt
# interface_start = np.array(get_line(ocean_line.T[0,1:],[nlay-1,int(ncol/2)],allrows=1))
for v in ocean_line.T:
    sconc[v[0],v[1],:v[2]]=Csalt
    
    
    

icbund = np.ones((nlay, nrow, ncol), dtype=np.int)
icbund[np.where(ibound==-1)] = -1

# %%
ghb_data = {}
ssm_data = {}
for kper in range(nper):
    if kper%50==0:
        print('kper',kper)
    ghb_per = ghb_data_ocean[kper]
    ssm_per = ssm_data_ocean[kper]
    for vg,vs in zip(ghb_data_inland[kper],ssm_data_inland[kper]):
        ghb_per.append(vg)
        ssm_per.append(vs)
    ghb_data[kper] = ghb_per
    ssm_data[kper] = ssm_per
# Out:
# kper 0
# kper 50

# %%
# In[9]:

#Output control
oc_data = {}
for kper in range(nper):
    oc_data[(kper,0)] = ['save head','save budget']


# In[10]:

#Create instances in flopy
bas = flopy.modflow.ModflowBas(m, ibound=ibound, strt=strt)
ghb = flopy.modflow.ModflowGhb(m, stress_period_data=ghb_data)

# rch = flopy.modflow.ModflowRch(m, rech=rech_data)
# wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)
# riv = flopy.modflow.ModflowRiv(m, stress_period_data=riv_data)
# Add LPF package to the MODFLOW model
ipakcb = 53
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb,laytyp=0,laywet=0,
                              ss=ss,sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data=oc_data,
                             compact=True)

#Create the basic MT3DMS model structure
timprs = np.cumsum(m.DIS.perlen.array)
btn = flopy.mt3d.Mt3dBtn(m,
                         laycon=lpf.laytyp, htop=henry_top,
                         dz=dis.thickness.get_value(), prsity=por, icbund=icbund,
                         sconc=sconc, nprs=1,timprs=timprs)
# adv = flopy.mt3d.Mt3dAdv(m, mixelm=-1 )
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0,nadvfd=0 )

dsp = flopy.mt3d.Mt3dDsp(m, al=al, dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=50, mxiter=1, isolve=3, cclose=1e-4)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data,mxss=len(ssm_data[0])*nper)

#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0,
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# WARNING: unit 13 of package BAS6 already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfbas.ModflowBas'> <class 'flopy.modflow.mfbas.ModflowBas'>
# replacing existing Package...
# WARNING: unit 23 of package GHB already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfghb.ModflowGhb'> <class 'flopy.modflow.mfghb.ModflowGhb'>
# replacing existing Package...
# WARNING: unit 15 of package LPF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mflpf.ModflowLpf'> <class 'flopy.modflow.mflpf.ModflowLpf'>
# replacing existing Package...
# WARNING: unit 27 of package PCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfpcg.ModflowPcg'> <class 'flopy.modflow.mfpcg.ModflowPcg'>
# replacing existing Package...
# WARNING: unit 14 of package OC already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfoc.ModflowOc'> <class 'flopy.modflow.mfoc.ModflowOc'>
# replacing existing Package...
# WARNING: unit 31 of package BTN already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtbtn.Mt3dBtn'> <class 'flopy.mt3d.mtbtn.Mt3dBtn'>
# replacing existing Package...
# WARNING: unit 32 of package ADV already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtadv.Mt3dAdv'> <class 'flopy.mt3d.mtadv.Mt3dAdv'>
# replacing existing Package...
# WARNING: unit 33 of package DSP already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtdsp.Mt3dDsp'> <class 'flopy.mt3d.mtdsp.Mt3dDsp'>
# replacing existing Package...
# WARNING: unit 35 of package GCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtgcg.Mt3dGcg'> <class 'flopy.mt3d.mtgcg.Mt3dGcg'>
# replacing existing Package...
#    explicit cevt in file
# WARNING: unit 34 of package SSM already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtssm.Mt3dSsm'> <class 'flopy.mt3d.mtssm.Mt3dSsm'>
# replacing existing Package...
# WARNING: unit 37 of package VDF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.seawat.swtvdf.SeawatVdf'> <class 'flopy.seawat.swtvdf.SeawatVdf'>
# replacing existing Package...

# %%
# %%time
runyn = True
#Write input
m.write_input()

# Try to delete the output files, to prevent accidental use of older files

f_delete = [os.path.join(model_ws,'MT3D.CNF'),
            os.path.join(model_ws,'MT3D001.MAS'),
            os.path.join(model_ws, 'MT3D001.UCN'),
            os.path.join(model_ws, modelname + '.hds'),
            os.path.join(model_ws, modelname + '.cbc')]

for f in f_delete:
    try:
        os.remove(f)
    except:
        pass

#%%
import datetime

if runyn:
    #Run model
    ts = make_timestamp()
    v = m.run_model(silent=False, report=True)
    for idx in range(-3, 0):
        print(v[1][idx])
else:
    print('Not running model!')
# In[14]:
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  GHB
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  VDF
#
# FloPy is using the following  executable to run the model: /home/groups/rknight/swtv4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: NM.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/06/30  7:37:03
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    182.50
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4394E-02  [K,I,J]    3    9  134
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2246E-07  [K,I,J]    1   34  155
#  Transport Step:    2   Step Size:  0.1422     Total Elapsed Time:  0.14323
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7609E-01  [K,I,J]    3    9  134
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1178E-02  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1274E-04  [K,I,J]    1   35  156
#  Transport Step:    3   Step Size:  0.2999     Total Elapsed Time:  0.44317
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6643E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1616E-02  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2827E-04  [K,I,J]    1   39  156
#  Transport Step:    4   Step Size:  0.4669     Total Elapsed Time:  0.91012
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6429E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1253E-02  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2659E-04  [K,I,J]    1   39  156
#  Transport Step:    5   Step Size:  0.6600     Total Elapsed Time:   1.5701
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5788E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8185E-03  [K,I,J]    1    8  153
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1927E-04  [K,I,J]    1   39  156
#  Transport Step:    6   Step Size:  0.9149     Total Elapsed Time:   2.4849
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5041E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5464E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1266E-04  [K,I,J]    1   39  156
#  Transport Step:    7   Step Size:   1.297     Total Elapsed Time:   3.7817
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4318E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3527E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8127E-05  [K,I,J]    1   39  156
#  Transport Step:    8   Step Size:   1.932     Total Elapsed Time:   5.7140
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3746E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2337E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5968E-05  [K,I,J]    1   39  156
#  Transport Step:    9   Step Size:   3.021     Total Elapsed Time:   8.7346
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3486E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1905E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1505E-04  [K,I,J]    1   34  156
#  Transport Step:   10   Step Size:   4.080     Total Elapsed Time:   12.815
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3257E-01  [K,I,J]    3   36  156
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1327E-03  [K,I,J]    1   34  156
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8551E-05  [K,I,J]    1    3  154
#  Transport Step:   11   Step Size:   4.080     Total Elapsed Time:   16.895
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2977E-01  [K,I,J]   12   12   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9138E-04  [K,I,J]    1   36  157
#  Transport Step:   12   Step Size:   4.080     Total Elapsed Time:   20.975
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2767E-01  [K,I,J]   12   12   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7440E-04  [K,I,J]    1   36  157
#  Transport Step:   13   Step Size:   4.080     Total Elapsed Time:   25.055
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2577E-01  [K,I,J]   12   12   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6485E-04  [K,I,J]    1   36  157
#  Transport Step:   14   Step Size:   4.080     Total Elapsed Time:   29.135
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2403E-01  [K,I,J]   12   12   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5797E-04  [K,I,J]    1   36  157
#  Transport Step:   15   Step Size:   4.080     Total Elapsed Time:   33.215
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2244E-01  [K,I,J]   12   12   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5230E-04  [K,I,J]    1   36  157
#  Transport Step:   16   Step Size:   4.080     Total Elapsed Time:   37.295
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2099E-01  [K,I,J]   12   12   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4737E-04  [K,I,J]    1   36  157
#  Transport Step:   17   Step Size:   4.080     Total Elapsed Time:   41.375
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1973E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4295E-04  [K,I,J]    1   36  157
#  Transport Step:   18   Step Size:   4.080     Total Elapsed Time:   45.456
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1860E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3897E-04  [K,I,J]    1   36  157
#  Transport Step:   19   Step Size:   4.080     Total Elapsed Time:   49.536
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1755E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3535E-04  [K,I,J]    1   36  157
#  Transport Step:   20   Step Size:   4.080     Total Elapsed Time:   53.616
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1658E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3205E-04  [K,I,J]    1   36  157
#  Transport Step:   21   Step Size:   4.080     Total Elapsed Time:   57.696
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1566E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2905E-04  [K,I,J]    1   36  157
#  Transport Step:   22   Step Size:   4.080     Total Elapsed Time:   61.776
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1481E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2635E-04  [K,I,J]    1   36  157
#  Transport Step:   23   Step Size:   4.080     Total Elapsed Time:   65.856
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1401E-01  [K,I,J]   12    4   25
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2433E-04  [K,I,J]    1   36  157
#  Transport Step:   24   Step Size:   4.080     Total Elapsed Time:   69.936
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1330E-01  [K,I,J]   12    4   26
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2072E-04  [K,I,J]    1   36  157
#  Transport Step:   25   Step Size:   4.080     Total Elapsed Time:   74.016
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1281E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1889E-04  [K,I,J]    1   36  157
#  Transport Step:   26   Step Size:   4.080     Total Elapsed Time:   78.096
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1239E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1698E-04  [K,I,J]    1   36  157
#  Transport Step:   27   Step Size:   4.080     Total Elapsed Time:   82.177
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1200E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1520E-04  [K,I,J]    1   36  157
#  Transport Step:   28   Step Size:   4.080     Total Elapsed Time:   86.257
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1162E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1356E-04  [K,I,J]    1   36  157
#  Transport Step:   29   Step Size:   4.080     Total Elapsed Time:   90.337
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1126E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1327E-04  [K,I,J]    1   33  155
#  Transport Step:   30   Step Size:   4.080     Total Elapsed Time:   94.417
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1091E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1315E-04  [K,I,J]    1   33  155
#  Transport Step:   31   Step Size:   4.080     Total Elapsed Time:   98.497
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1058E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1299E-04  [K,I,J]    1   33  155
#  Transport Step:   32   Step Size:   4.080     Total Elapsed Time:   102.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1026E-01  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1281E-04  [K,I,J]    1   33  155
#  Transport Step:   33   Step Size:   4.080     Total Elapsed Time:   106.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9958E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1261E-04  [K,I,J]    1   33  155
#  Transport Step:   34   Step Size:   4.080     Total Elapsed Time:   110.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9665E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1238E-04  [K,I,J]    1   33  155
#  Transport Step:   35   Step Size:   4.080     Total Elapsed Time:   114.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9383E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1213E-04  [K,I,J]    1   33  155
#  Transport Step:   36   Step Size:   4.080     Total Elapsed Time:   118.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9112E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1187E-04  [K,I,J]    1   33  155
#  Transport Step:   37   Step Size:   4.080     Total Elapsed Time:   122.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8852E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1162E-04  [K,I,J]    1   33  155
#  Transport Step:   38   Step Size:   4.080     Total Elapsed Time:   127.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8601E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1137E-04  [K,I,J]    1   33  155
#  Transport Step:   39   Step Size:   4.080     Total Elapsed Time:   131.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8360E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1111E-04  [K,I,J]    1   33  155
#  Transport Step:   40   Step Size:   4.080     Total Elapsed Time:   135.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8129E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1085E-04  [K,I,J]    1   33  155
#  Transport Step:   41   Step Size:   4.080     Total Elapsed Time:   139.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7906E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1060E-04  [K,I,J]    1   33  155
#  Transport Step:   42   Step Size:   4.080     Total Elapsed Time:   143.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7691E-02  [K,I,J]   13   16    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1034E-04  [K,I,J]    1   33  155
#  Transport Step:   43   Step Size:   4.080     Total Elapsed Time:   147.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7494E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1009E-04  [K,I,J]    1   33  155
#  Transport Step:   44   Step Size:   4.080     Total Elapsed Time:   151.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7336E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9842E-05  [K,I,J]    1   33  155
#  Transport Step:   45   Step Size:   4.080     Total Elapsed Time:   155.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7182E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9598E-05  [K,I,J]    1   33  155
#  Transport Step:   46   Step Size:   4.080     Total Elapsed Time:   159.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7033E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9358E-05  [K,I,J]    1   33  155
#  Transport Step:   47   Step Size:   4.080     Total Elapsed Time:   163.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6888E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9123E-05  [K,I,J]    1   33  155
#  Transport Step:   48   Step Size:   4.080     Total Elapsed Time:   167.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6746E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8893E-05  [K,I,J]    1   33  155
#  Transport Step:   49   Step Size:   4.080     Total Elapsed Time:   171.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6608E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8669E-05  [K,I,J]    1   33  155
#  Transport Step:   50   Step Size:   4.080     Total Elapsed Time:   176.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6474E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8451E-05  [K,I,J]    1   33  155
#  Transport Step:   51   Step Size:   4.080     Total Elapsed Time:   180.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6344E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8239E-05  [K,I,J]    1   33  155
#  Transport Step:   52   Step Size:   2.401     Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3685E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2360E-05  [K,I,J]    1   33  155
#  Transport Step:   53   Step Size:  2.8422E-14 Total Elapsed Time:   182.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    2
#
#   STRESS PERIOD    2 TIME STEP    1 FROM TIME =   182.50     TO    365.00
#
#  Transport Step:    1   Step Size:   4.080     Total Elapsed Time:   186.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1482E-01  [K,I,J]   12   13   57
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1281E-03  [K,I,J]    1   12  155
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1582E-05  [K,I,J]    1   12  155
#  Transport Step:    2   Step Size:   4.080     Total Elapsed Time:   190.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6022E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1147E-04  [K,I,J]    1   12  154
#  Transport Step:    3   Step Size:   4.080     Total Elapsed Time:   194.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5906E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1029E-04  [K,I,J]    1   12  155
#  Transport Step:    4   Step Size:   4.080     Total Elapsed Time:   198.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5790E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8863E-05  [K,I,J]    1   12  155
#  Transport Step:    5   Step Size:   4.080     Total Elapsed Time:   202.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5678E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7734E-05  [K,I,J]    1   12  155
#  Transport Step:    6   Step Size:   4.080     Total Elapsed Time:   206.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5568E-02  [K,I,J]   13   18    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6798E-05  [K,I,J]    1   12  155
#  Transport Step:    7   Step Size:   4.080     Total Elapsed Time:   211.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5482E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5997E-05  [K,I,J]    1   12  155
#  Transport Step:    8   Step Size:   4.080     Total Elapsed Time:   215.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5407E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5301E-05  [K,I,J]    1   12  155
#  Transport Step:    9   Step Size:   4.080     Total Elapsed Time:   219.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5334E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4694E-05  [K,I,J]    1   12  155
#  Transport Step:   10   Step Size:   4.080     Total Elapsed Time:   223.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5261E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4367E-05  [K,I,J]    1   21  154
#  Transport Step:   11   Step Size:   4.080     Total Elapsed Time:   227.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5189E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4295E-05  [K,I,J]    1   21  154
#  Transport Step:   12   Step Size:   4.080     Total Elapsed Time:   231.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5118E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4228E-05  [K,I,J]    1   21  154
#  Transport Step:   13   Step Size:   4.080     Total Elapsed Time:   235.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5048E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4163E-05  [K,I,J]    1   21  154
#  Transport Step:   14   Step Size:   4.080     Total Elapsed Time:   239.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4979E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4101E-05  [K,I,J]    1   21  154
#  Transport Step:   15   Step Size:   4.080     Total Elapsed Time:   243.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4911E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4041E-05  [K,I,J]    1   21  154
#  Transport Step:   16   Step Size:   4.080     Total Elapsed Time:   247.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4844E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3983E-05  [K,I,J]    1   21  154
#  Transport Step:   17   Step Size:   4.080     Total Elapsed Time:   251.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4778E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3926E-05  [K,I,J]    1   21  154
#  Transport Step:   18   Step Size:   4.080     Total Elapsed Time:   255.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4713E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3869E-05  [K,I,J]    1   21  154
#  Transport Step:   19   Step Size:   4.080     Total Elapsed Time:   260.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4649E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3814E-05  [K,I,J]    1   21  154
#  Transport Step:   20   Step Size:   4.080     Total Elapsed Time:   264.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4587E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3760E-05  [K,I,J]    1   21  154
#  Transport Step:   21   Step Size:   4.080     Total Elapsed Time:   268.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4525E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3706E-05  [K,I,J]    1   21  154
#  Transport Step:   22   Step Size:   4.080     Total Elapsed Time:   272.26
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4464E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3653E-05  [K,I,J]    1   21  154
#  Transport Step:   23   Step Size:   4.080     Total Elapsed Time:   276.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4404E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3601E-05  [K,I,J]    1   21  154
#  Transport Step:   24   Step Size:   4.080     Total Elapsed Time:   280.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4345E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3549E-05  [K,I,J]    1   21  154
#  Transport Step:   25   Step Size:   4.080     Total Elapsed Time:   284.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4287E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3498E-05  [K,I,J]    1   21  154
#  Transport Step:   26   Step Size:   4.080     Total Elapsed Time:   288.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4230E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3448E-05  [K,I,J]    1   21  154
#  Transport Step:   27   Step Size:   4.080     Total Elapsed Time:   292.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4174E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3399E-05  [K,I,J]    1   21  154
#  Transport Step:   28   Step Size:   4.080     Total Elapsed Time:   296.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4119E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3350E-05  [K,I,J]    1   21  154
#  Transport Step:   29   Step Size:   4.080     Total Elapsed Time:   300.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4065E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3302E-05  [K,I,J]    1   21  154
#  Transport Step:   30   Step Size:   4.080     Total Elapsed Time:   304.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4012E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3254E-05  [K,I,J]    1   21  154
#  Transport Step:   31   Step Size:   4.080     Total Elapsed Time:   308.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3960E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3207E-05  [K,I,J]    1   21  154
#  Transport Step:   32   Step Size:   4.080     Total Elapsed Time:   313.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3909E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3161E-05  [K,I,J]    1   21  154
#  Transport Step:   33   Step Size:   4.080     Total Elapsed Time:   317.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3859E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3116E-05  [K,I,J]    1   21  154
#  Transport Step:   34   Step Size:   4.080     Total Elapsed Time:   321.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3809E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3071E-05  [K,I,J]    1   21  154
#  Transport Step:   35   Step Size:   4.080     Total Elapsed Time:   325.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3761E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3027E-05  [K,I,J]    1   21  154
#  Transport Step:   36   Step Size:   4.080     Total Elapsed Time:   329.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3713E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2984E-05  [K,I,J]    1   21  154
#  Transport Step:   37   Step Size:   4.080     Total Elapsed Time:   333.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3666E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2941E-05  [K,I,J]    1   21  154
#  Transport Step:   38   Step Size:   4.080     Total Elapsed Time:   337.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3620E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2899E-05  [K,I,J]    1   21  154
#  Transport Step:   39   Step Size:   4.080     Total Elapsed Time:   341.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3575E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2858E-05  [K,I,J]    1   21  154
#  Transport Step:   40   Step Size:   4.080     Total Elapsed Time:   345.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3530E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2817E-05  [K,I,J]    1   21  154
#  Transport Step:   41   Step Size:   4.080     Total Elapsed Time:   349.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3487E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2777E-05  [K,I,J]    1   21  154
#  Transport Step:   42   Step Size:   4.080     Total Elapsed Time:   353.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3444E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2738E-05  [K,I,J]    1   21  154
#  Transport Step:   43   Step Size:   4.080     Total Elapsed Time:   357.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3402E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2699E-05  [K,I,J]    1   21  154
#  Transport Step:   44   Step Size:   4.080     Total Elapsed Time:   362.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3360E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2661E-05  [K,I,J]    1   21  154
#  Transport Step:   45   Step Size:   2.976     Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2428E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1206E-05  [K,I,J]    1   21  154
#  Transport Step:   46   Step Size:  5.6843E-14 Total Elapsed Time:   365.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    3
#
#   STRESS PERIOD    3 TIME STEP    1 FROM TIME =   365.00     TO    547.50
#
#  Transport Step:    1   Step Size:   4.080     Total Elapsed Time:   369.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7629E-02  [K,I,J]   11    2  100
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4209E-05  [K,I,J]    5    1  151
#  Transport Step:    2   Step Size:   4.080     Total Elapsed Time:   373.16
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3250E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3740E-05  [K,I,J]    1   21  154
#  Transport Step:    3   Step Size:   4.080     Total Elapsed Time:   377.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3212E-02  [K,I,J]   13   16    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4203E-05  [K,I,J]    1   21  154
#  Transport Step:    4   Step Size:   4.080     Total Elapsed Time:   381.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3223E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4469E-05  [K,I,J]    1   21  154
#  Transport Step:    5   Step Size:   4.080     Total Elapsed Time:   385.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3219E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4602E-05  [K,I,J]    1   21  154
#  Transport Step:    6   Step Size:   4.080     Total Elapsed Time:   389.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3206E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4651E-05  [K,I,J]    1   21  154
#  Transport Step:    7   Step Size:   4.080     Total Elapsed Time:   393.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3189E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4650E-05  [K,I,J]    1   21  154
#  Transport Step:    8   Step Size:   4.080     Total Elapsed Time:   397.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3172E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4617E-05  [K,I,J]    1   21  154
#  Transport Step:    9   Step Size:   4.080     Total Elapsed Time:   401.72
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3154E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4565E-05  [K,I,J]    1   21  154
#  Transport Step:   10   Step Size:   4.080     Total Elapsed Time:   405.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3135E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4502E-05  [K,I,J]    1   21  154
#  Transport Step:   11   Step Size:   4.080     Total Elapsed Time:   409.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3116E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4432E-05  [K,I,J]    1   21  154
#  Transport Step:   12   Step Size:   4.080     Total Elapsed Time:   413.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3097E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4358E-05  [K,I,J]    1   21  154
#  Transport Step:   13   Step Size:   4.080     Total Elapsed Time:   418.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3077E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4283E-05  [K,I,J]    1   21  154
#  Transport Step:   14   Step Size:   4.080     Total Elapsed Time:   422.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3057E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4207E-05  [K,I,J]    1   27  155
#  Transport Step:   15   Step Size:   4.080     Total Elapsed Time:   426.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3036E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4138E-05  [K,I,J]    1   27  155
#  Transport Step:   16   Step Size:   4.080     Total Elapsed Time:   430.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3016E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4069E-05  [K,I,J]    1   27  155
#  Transport Step:   17   Step Size:   4.080     Total Elapsed Time:   434.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2995E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4000E-05  [K,I,J]    1   27  155
#  Transport Step:   18   Step Size:   4.080     Total Elapsed Time:   438.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2974E-02  [K,I,J]    4   36  160
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3932E-05  [K,I,J]    1   27  155
#  Transport Step:   19   Step Size:   4.080     Total Elapsed Time:   442.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2958E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3864E-05  [K,I,J]    1   27  155
#  Transport Step:   20   Step Size:   4.080     Total Elapsed Time:   446.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2945E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3797E-05  [K,I,J]    1   27  155
#  Transport Step:   21   Step Size:   4.080     Total Elapsed Time:   450.68
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2932E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3731E-05  [K,I,J]    1   27  155
#  Transport Step:   22   Step Size:   4.080     Total Elapsed Time:   454.76
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2919E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3666E-05  [K,I,J]    1   27  155
#  Transport Step:   23   Step Size:   4.080     Total Elapsed Time:   458.84
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2906E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3602E-05  [K,I,J]    1   27  155
#  Transport Step:   24   Step Size:   4.080     Total Elapsed Time:   462.92
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2892E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3538E-05  [K,I,J]    1   27  155
#  Transport Step:   25   Step Size:   4.080     Total Elapsed Time:   467.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2878E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3476E-05  [K,I,J]    1   27  155
#  Transport Step:   26   Step Size:   4.080     Total Elapsed Time:   471.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2863E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3415E-05  [K,I,J]    1   27  155
#  Transport Step:   27   Step Size:   4.080     Total Elapsed Time:   475.16
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2848E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3355E-05  [K,I,J]    1   27  155
#  Transport Step:   28   Step Size:   4.080     Total Elapsed Time:   479.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2833E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3296E-05  [K,I,J]    1   27  155
#  Transport Step:   29   Step Size:   4.080     Total Elapsed Time:   483.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2818E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3239E-05  [K,I,J]    1   27  155
#  Transport Step:   30   Step Size:   4.080     Total Elapsed Time:   487.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2802E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3182E-05  [K,I,J]    1   27  155
#  Transport Step:   31   Step Size:   4.080     Total Elapsed Time:   491.48
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2787E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3127E-05  [K,I,J]    1   27  155
#  Transport Step:   32   Step Size:   4.080     Total Elapsed Time:   495.56
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2771E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3072E-05  [K,I,J]    1   27  155
#  Transport Step:   33   Step Size:   4.080     Total Elapsed Time:   499.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2755E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3019E-05  [K,I,J]    1   27  155
#  Transport Step:   34   Step Size:   4.080     Total Elapsed Time:   503.72
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2738E-02  [K,I,J]    4   36  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2967E-05  [K,I,J]    1   27  155
#  Transport Step:   35   Step Size:   4.080     Total Elapsed Time:   507.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2726E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2916E-05  [K,I,J]    1   27  155
#  Transport Step:   36   Step Size:   4.080     Total Elapsed Time:   511.88
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2716E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2866E-05  [K,I,J]    1   27  155
#  Transport Step:   37   Step Size:   4.080     Total Elapsed Time:   515.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2705E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2817E-05  [K,I,J]    1   27  155
#  Transport Step:   38   Step Size:   4.080     Total Elapsed Time:   520.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2695E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2769E-05  [K,I,J]    1   27  155
#  Transport Step:   39   Step Size:   4.080     Total Elapsed Time:   524.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2684E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2722E-05  [K,I,J]    1   27  155
#  Transport Step:   40   Step Size:   4.080     Total Elapsed Time:   528.20
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2674E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2676E-05  [K,I,J]    1   27  155
#  Transport Step:   41   Step Size:   4.080     Total Elapsed Time:   532.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2663E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2633E-05  [K,I,J]    1   21  154
#  Transport Step:   42   Step Size:   4.080     Total Elapsed Time:   536.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2652E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2592E-05  [K,I,J]    1   21  154
#  Transport Step:   43   Step Size:   4.080     Total Elapsed Time:   540.44
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2640E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2552E-05  [K,I,J]    1   21  154
#  Transport Step:   44   Step Size:   4.080     Total Elapsed Time:   544.52
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2629E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2513E-05  [K,I,J]    1   21  154
#  Transport Step:   45   Step Size:   2.975     Total Elapsed Time:   547.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1911E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1179E-05  [K,I,J]    1   21  154
#  Transport Step:   46   Step Size:  1.1369E-13 Total Elapsed Time:   547.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    4
#
#   STRESS PERIOD    4 TIME STEP    1 FROM TIME =   547.50     TO    730.00
#
#  Transport Step:    1   Step Size:   4.080     Total Elapsed Time:   551.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4402E-02  [K,I,J]    4   33  149
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3070E-05  [K,I,J]    3   16  156
#  Transport Step:    2   Step Size:   4.080     Total Elapsed Time:   555.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2390E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2129E-05  [K,I,J]    1   27  155
#  Transport Step:    3   Step Size:   4.080     Total Elapsed Time:   559.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2352E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1997E-05  [K,I,J]    1   27  155
#  Transport Step:    4   Step Size:   4.080     Total Elapsed Time:   563.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2332E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1898E-05  [K,I,J]    1   27  155
#  Transport Step:    5   Step Size:   4.080     Total Elapsed Time:   567.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2319E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1826E-05  [K,I,J]    1   27  155
#  Transport Step:    6   Step Size:   4.080     Total Elapsed Time:   571.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2307E-02  [K,I,J]    4   33  161
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1771E-05  [K,I,J]    1   27  155
#  Transport Step:    7   Step Size:   4.080     Total Elapsed Time:   576.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2297E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1729E-05  [K,I,J]    1   21  154
#  Transport Step:    8   Step Size:   4.080     Total Elapsed Time:   580.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2292E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1694E-05  [K,I,J]    1   21  154
#  Transport Step:    9   Step Size:   4.080     Total Elapsed Time:   584.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2286E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1682E-05  [K,I,J]    1    8  151
#  Transport Step:   10   Step Size:   4.080     Total Elapsed Time:   588.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2280E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1675E-05  [K,I,J]    1    8  151
#  Transport Step:   11   Step Size:   4.080     Total Elapsed Time:   592.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2274E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1668E-05  [K,I,J]    1    8  151
#  Transport Step:   12   Step Size:   4.080     Total Elapsed Time:   596.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2268E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1660E-05  [K,I,J]    1    8  151
#  Transport Step:   13   Step Size:   4.080     Total Elapsed Time:   600.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2262E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1653E-05  [K,I,J]    1    8  151
#  Transport Step:   14   Step Size:   4.080     Total Elapsed Time:   604.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2255E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1645E-05  [K,I,J]    1    8  151
#  Transport Step:   15   Step Size:   4.080     Total Elapsed Time:   608.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2249E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1637E-05  [K,I,J]    1    8  151
#  Transport Step:   16   Step Size:   4.080     Total Elapsed Time:   612.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2242E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1629E-05  [K,I,J]    1    8  151
#  Transport Step:   17   Step Size:   4.080     Total Elapsed Time:   616.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2236E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1621E-05  [K,I,J]    1    8  151
#  Transport Step:   18   Step Size:   4.080     Total Elapsed Time:   620.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2229E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1613E-05  [K,I,J]    1    8  151
#  Transport Step:   19   Step Size:   4.080     Total Elapsed Time:   625.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2222E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1605E-05  [K,I,J]    1    8  151
#  Transport Step:   20   Step Size:   4.080     Total Elapsed Time:   629.10
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2215E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1597E-05  [K,I,J]    1    8  151
#  Transport Step:   21   Step Size:   4.080     Total Elapsed Time:   633.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2208E-02  [K,I,J]    4   33  162
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1589E-05  [K,I,J]    1    8  151
#  Transport Step:   22   Step Size:   4.080     Total Elapsed Time:   637.26
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2201E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1581E-05  [K,I,J]    1    8  151
#  Transport Step:   23   Step Size:   4.080     Total Elapsed Time:   641.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2197E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1573E-05  [K,I,J]    1    8  151
#  Transport Step:   24   Step Size:   4.080     Total Elapsed Time:   645.42
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2193E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1565E-05  [K,I,J]    1    8  151
#  Transport Step:   25   Step Size:   4.080     Total Elapsed Time:   649.50
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2189E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1557E-05  [K,I,J]    1    8  151
#  Transport Step:   26   Step Size:   4.080     Total Elapsed Time:   653.58
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2184E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1549E-05  [K,I,J]    1    8  151
#  Transport Step:   27   Step Size:   4.080     Total Elapsed Time:   657.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2180E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1541E-05  [K,I,J]    1    8  151
#  Transport Step:   28   Step Size:   4.080     Total Elapsed Time:   661.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2176E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1532E-05  [K,I,J]    1    8  151
#  Transport Step:   29   Step Size:   4.080     Total Elapsed Time:   665.82
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2171E-02  [K,I,J]    5   37  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1524E-05  [K,I,J]    1    8  151
#  Transport Step:   30   Step Size:   4.080     Total Elapsed Time:   669.90
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2168E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1516E-05  [K,I,J]    1    8  151
#  Transport Step:   31   Step Size:   4.080     Total Elapsed Time:   673.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2165E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1508E-05  [K,I,J]    1    8  151
#  Transport Step:   32   Step Size:   4.080     Total Elapsed Time:   678.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2161E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1499E-05  [K,I,J]    1    8  151
#  Transport Step:   33   Step Size:   4.080     Total Elapsed Time:   682.14
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2158E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1491E-05  [K,I,J]    1    8  151
#  Transport Step:   34   Step Size:   4.080     Total Elapsed Time:   686.22
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2155E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1483E-05  [K,I,J]    1    8  151
#  Transport Step:   35   Step Size:   4.080     Total Elapsed Time:   690.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2151E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1474E-05  [K,I,J]    1    8  151
#  Transport Step:   36   Step Size:   4.080     Total Elapsed Time:   694.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2147E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1466E-05  [K,I,J]    1    8  151
#  Transport Step:   37   Step Size:   4.080     Total Elapsed Time:   698.46
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2144E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1458E-05  [K,I,J]    1    8  151
#  Transport Step:   38   Step Size:   4.080     Total Elapsed Time:   702.54
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2140E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1449E-05  [K,I,J]    1    8  151
#  Transport Step:   39   Step Size:   4.080     Total Elapsed Time:   706.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2136E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1441E-05  [K,I,J]    1    8  151
#  Transport Step:   40   Step Size:   4.080     Total Elapsed Time:   710.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2132E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1433E-05  [K,I,J]    1    8  151
#  Transport Step:   41   Step Size:   4.080     Total Elapsed Time:   714.78
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2127E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1424E-05  [K,I,J]    1    8  151
#  Transport Step:   42   Step Size:   4.080     Total Elapsed Time:   718.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2123E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1416E-05  [K,I,J]    1    8  151
#  Transport Step:   43   Step Size:   4.080     Total Elapsed Time:   722.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2119E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1407E-05  [K,I,J]    1    8  151
#  Transport Step:   44   Step Size:   4.080     Total Elapsed Time:   727.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2114E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1399E-05  [K,I,J]    1    8  151
#  Transport Step:   45   Step Size:   2.976     Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1540E-02  [K,I,J]    5   35  163
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6890E-06  [K,I,J]    1    8  151
#  Transport Step:   46   Step Size:  1.1369E-13 Total Elapsed Time:   730.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    5
#
# ...
#  Transport Step:    8   Step Size:   4.080     Total Elapsed Time:   1310.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1409E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7602E-06  [K,I,J]    1   29  166
#  Transport Step:    9   Step Size:   4.080     Total Elapsed Time:   1314.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1406E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7576E-06  [K,I,J]    1   29  166
#  Transport Step:   10   Step Size:   4.080     Total Elapsed Time:   1318.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1402E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7556E-06  [K,I,J]    1   29  166
#  Transport Step:   11   Step Size:   4.080     Total Elapsed Time:   1322.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1398E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7540E-06  [K,I,J]    1   29  166
#  Transport Step:   12   Step Size:   4.080     Total Elapsed Time:   1326.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1395E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7527E-06  [K,I,J]    1   29  166
#  Transport Step:   13   Step Size:   4.080     Total Elapsed Time:   1330.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1391E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7515E-06  [K,I,J]    1   29  166
#  Transport Step:   14   Step Size:   4.080     Total Elapsed Time:   1334.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1387E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7505E-06  [K,I,J]    1   29  166
#  Transport Step:   15   Step Size:   4.080     Total Elapsed Time:   1338.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1384E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7495E-06  [K,I,J]    1   29  166
#  Transport Step:   16   Step Size:   4.080     Total Elapsed Time:   1342.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1380E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7486E-06  [K,I,J]    1   29  166
#  Transport Step:   17   Step Size:   4.080     Total Elapsed Time:   1346.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1377E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7477E-06  [K,I,J]    1   29  166
#  Transport Step:   18   Step Size:   4.080     Total Elapsed Time:   1350.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1373E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7468E-06  [K,I,J]    1   29  166
#  Transport Step:   19   Step Size:   4.080     Total Elapsed Time:   1355.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1369E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7459E-06  [K,I,J]    1   29  166
#  Transport Step:   20   Step Size:   4.080     Total Elapsed Time:   1359.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1365E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7449E-06  [K,I,J]    1   29  166
#  Transport Step:   21   Step Size:   4.080     Total Elapsed Time:   1363.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1362E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7440E-06  [K,I,J]    1   29  166
#  Transport Step:   22   Step Size:   4.080     Total Elapsed Time:   1367.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1358E-02  [K,I,J]    6   32  166
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7429E-06  [K,I,J]    1   29  166
#  Transport Step:   23   Step Size:   4.080     Total Elapsed Time:   1371.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1355E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7419E-06  [K,I,J]    1   29  166
#  Transport Step:   24   Step Size:   4.080     Total Elapsed Time:   1375.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1352E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7408E-06  [K,I,J]    1   29  166
#  Transport Step:   25   Step Size:   4.080     Total Elapsed Time:   1379.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1350E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7396E-06  [K,I,J]    1   29  166
#  Transport Step:   26   Step Size:   4.080     Total Elapsed Time:   1383.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1347E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7384E-06  [K,I,J]    1   29  166
#  Transport Step:   27   Step Size:   4.080     Total Elapsed Time:   1387.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1345E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7372E-06  [K,I,J]    1   29  166
#  Transport Step:   28   Step Size:   4.080     Total Elapsed Time:   1391.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1342E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7359E-06  [K,I,J]    1   29  166
#  Transport Step:   29   Step Size:   4.080     Total Elapsed Time:   1395.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1339E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7345E-06  [K,I,J]    1   29  166
#  Transport Step:   30   Step Size:   4.080     Total Elapsed Time:   1399.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1337E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7331E-06  [K,I,J]    1   29  166
#  Transport Step:   31   Step Size:   4.080     Total Elapsed Time:   1404.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1334E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7317E-06  [K,I,J]    1   29  166
#  Transport Step:   32   Step Size:   4.080     Total Elapsed Time:   1408.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1331E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7302E-06  [K,I,J]    1   29  166
#  Transport Step:   33   Step Size:   4.080     Total Elapsed Time:   1412.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1329E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7295E-06  [K,I,J]    1   29  167
#  Transport Step:   34   Step Size:   4.080     Total Elapsed Time:   1416.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1326E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7295E-06  [K,I,J]    1   29  167
#  Transport Step:   35   Step Size:   4.080     Total Elapsed Time:   1420.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1323E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7295E-06  [K,I,J]    1   29  167
#  Transport Step:   36   Step Size:   4.080     Total Elapsed Time:   1424.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1320E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7295E-06  [K,I,J]    1   29  167
#  Transport Step:   37   Step Size:   4.080     Total Elapsed Time:   1428.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1317E-02  [K,I,J]    7   33  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7294E-06  [K,I,J]    1   29  167
#  Transport Step:   38   Step Size:   4.080     Total Elapsed Time:   1432.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1315E-02  [K,I,J]    7   32  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7293E-06  [K,I,J]    1   29  167
#  Transport Step:   39   Step Size:   4.080     Total Elapsed Time:   1436.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1313E-02  [K,I,J]    7   32  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7291E-06  [K,I,J]    1   29  167
#  Transport Step:   40   Step Size:   4.080     Total Elapsed Time:   1440.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1311E-02  [K,I,J]    7   32  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7289E-06  [K,I,J]    1   29  167
#  Transport Step:   41   Step Size:   4.080     Total Elapsed Time:   1444.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1308E-02  [K,I,J]    7   32  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7286E-06  [K,I,J]    1   29  167
#  Transport Step:   42   Step Size:   4.080     Total Elapsed Time:   1448.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1306E-02  [K,I,J]    7   32  165
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7283E-06  [K,I,J]    1   29  167
#  Transport Step:   43   Step Size:   4.080     Total Elapsed Time:   1452.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1304E-02  [K,I,J]    4   32  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7279E-06  [K,I,J]    1   29  167
#  Transport Step:   44   Step Size:   4.080     Total Elapsed Time:   1457.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1302E-02  [K,I,J]    4   32  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7275E-06  [K,I,J]    1   29  167
#  Transport Step:   45   Step Size:   2.977     Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9489E-03  [K,I,J]    4   32  172
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3061E-06  [K,I,J]    1   29  167
#  Transport Step:   46   Step Size:  2.2737E-13 Total Elapsed Time:   1460.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#
#  STRESS PERIOD NO.    9
#
#   STRESS PERIOD    9 TIME STEP    1 FROM TIME =   1460.0     TO    1642.5
#
#  Transport Step:    1   Step Size:   4.080     Total Elapsed Time:   1464.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2254E-02  [K,I,J]    2    8  169
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1835E-05  [K,I,J]    6   38  176
#  Transport Step:    2   Step Size:   4.080     Total Elapsed Time:   1468.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1217E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5547E-06  [K,I,J]    1   29  167
#  Transport Step:    3   Step Size:   4.080     Total Elapsed Time:   1472.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1211E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5328E-06  [K,I,J]    1   29  167
#  Transport Step:    4   Step Size:   4.080     Total Elapsed Time:   1476.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1208E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5234E-06  [K,I,J]    1   29  167
#  Transport Step:    5   Step Size:   4.080     Total Elapsed Time:   1480.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1207E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5193E-06  [K,I,J]    1   29  167
#  Transport Step:    6   Step Size:   4.080     Total Elapsed Time:   1484.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1205E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5172E-06  [K,I,J]    1   29  167
#  Transport Step:    7   Step Size:   4.080     Total Elapsed Time:   1488.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1204E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5159E-06  [K,I,J]    1   29  167
#  Transport Step:    8   Step Size:   4.080     Total Elapsed Time:   1492.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1203E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5151E-06  [K,I,J]    1   29  167
#  Transport Step:    9   Step Size:   4.080     Total Elapsed Time:   1496.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1202E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5144E-06  [K,I,J]    1   29  167
#  Transport Step:   10   Step Size:   4.080     Total Elapsed Time:   1500.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1201E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5139E-06  [K,I,J]    1   29  167
#  Transport Step:   11   Step Size:   4.080     Total Elapsed Time:   1504.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1201E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5135E-06  [K,I,J]    1   29  167
#  Transport Step:   12   Step Size:   4.080     Total Elapsed Time:   1509.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1200E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5132E-06  [K,I,J]    1   29  167
#  Transport Step:   13   Step Size:   4.080     Total Elapsed Time:   1513.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1198E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5129E-06  [K,I,J]    1   29  167
#  Transport Step:   14   Step Size:   4.080     Total Elapsed Time:   1517.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1197E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5127E-06  [K,I,J]    1   29  167
#  Transport Step:   15   Step Size:   4.080     Total Elapsed Time:   1521.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1196E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5125E-06  [K,I,J]    1   29  167
#  Transport Step:   16   Step Size:   4.080     Total Elapsed Time:   1525.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1195E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5123E-06  [K,I,J]    1   29  167
#  Transport Step:   17   Step Size:   4.080     Total Elapsed Time:   1529.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1194E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5121E-06  [K,I,J]    1   29  167
#  Transport Step:   18   Step Size:   4.080     Total Elapsed Time:   1533.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1193E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5118E-06  [K,I,J]    1   29  167
#  Transport Step:   19   Step Size:   4.080     Total Elapsed Time:   1537.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1192E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5116E-06  [K,I,J]    1   29  167
#  Transport Step:   20   Step Size:   4.080     Total Elapsed Time:   1541.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1191E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5114E-06  [K,I,J]    1   29  167
#  Transport Step:   21   Step Size:   4.080     Total Elapsed Time:   1545.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1190E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5112E-06  [K,I,J]    1   29  167
#  Transport Step:   22   Step Size:   4.080     Total Elapsed Time:   1549.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1189E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5109E-06  [K,I,J]    1   29  167
#  Transport Step:   23   Step Size:   4.080     Total Elapsed Time:   1553.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1188E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5106E-06  [K,I,J]    1   29  167
#  Transport Step:   24   Step Size:   4.080     Total Elapsed Time:   1557.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1187E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5103E-06  [K,I,J]    1   29  167
#  Transport Step:   25   Step Size:   4.080     Total Elapsed Time:   1562.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1186E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5100E-06  [K,I,J]    1   29  167
#  Transport Step:   26   Step Size:   4.080     Total Elapsed Time:   1566.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1185E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5097E-06  [K,I,J]    1   29  167
#  Transport Step:   27   Step Size:   4.080     Total Elapsed Time:   1570.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1184E-02  [K,I,J]    4   35  174
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5093E-06  [K,I,J]    1   29  167
#  Transport Step:   28   Step Size:   4.080     Total Elapsed Time:   1574.2

# %%
m.exe_name = '/home/groups/rknight/swtv4'

# %%
config.gridgenexe
# Out:
# '/home/groups/rknight/gridgen'
