# %%
import pymake
import os

os.chdir('/usr/local/bin/MODFLOW/')

def test_build_gridgen():
    pymake.build_apps('gridgen')
    return


test_build_gridgen()
# Out:
# gridgen will be built for the "darwin" operating system
#
# gridgen will be placed in the directory:
#     "."
#
# gridgen will be built using "single" precision floats.
#
# gridgen will be built as a "release" application.
#
# gridgen fortran code will be built with "None".
# gridgen c/c++ code will be built with "g++".
#
# gridgen will use the following predefined syslibs:
#     -lc
#
# gridgen will be built for "intel64" architecture.
#
# downloading file:         True
# verified download:        True
# download timeout:         30 sec.
# cleaning extracted files: True
#
# extra files are not being read
#
# Attempting to download the file:
#     https://water.usgs.gov/water-resources/software/GRIDGEN/gridgen.1.0.02.zip
#  download attempt: 1
#    file size: 4,360,843 bytes
#      downloaded   204,800 bytes of 4,360,843 bytes (   4.6963%)
#      downloaded   409,600 bytes of 4,360,843 bytes (   9.3927%)
#      downloaded   614,400 bytes of 4,360,843 bytes (  14.0890%)
# ...

# %%
# Out:
# '/usr/local/bin/MODFLOW'
